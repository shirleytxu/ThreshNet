# %% [markdown]
# # 1: IMPORTING LIBRARIES AND DATASET

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import zipfile
import cv2
from skimage import io

import tensorflow as tf
from tensorflow.python.keras import Sequential
from tensorflow.keras import layers, optimizers
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
import tensorflow.keras.backend as K

import random
import glob
from sklearn.preprocessing import StandardScaler, normalize
from IPython.display import display

# %%
data = pd.read_csv('../input/lgg-mri-segmentation/kaggle_3m/data.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Patient                    110 non-null    object
#  1   RNASeqCluster              92 non-null     float64
#  2   MethylationCluster         109 non-null    float64
#  3   miRNACluster               110 non-null    int64
#  4   CNCluster                  108 non-null    float64
#  5   RPPACluster                98 non-null     float64
#  6   OncosignCluster            105 non-null    float64
#  7   COCCluster                 110 non-null    int64
#  8   histological_type          109 non-null    float64
#  9   neoplasm_histologic_grade  109 non-null    float64
#  10  tumor_tissue_site          109 non-null    float64
#  11  laterality                 109 non-null    float64
#  12  tumor_location             109 non-null    float64
#  13  gender                     109 non-null    float64
#  14  age_at_initial_pathologic  109 non-null    float64
#  15  race                       108 non-null    float64
#  16  ethnicity                  102 non-null    float64
#  17  death01                    109 non-null    float64
# dtypes: float64(15), int64(2), object(1)
# memory usage: 15.6+ KB

# %%
data.head(10)
# Out:
#         Patient  RNASeqCluster  MethylationCluster  miRNACluster  CNCluster  \
# 0  TCGA_CS_4941            2.0                 4.0             2        2.0
# 1  TCGA_CS_4942            1.0                 5.0             2        1.0
# 2  TCGA_CS_4943            1.0                 5.0             2        1.0
# 3  TCGA_CS_4944            NaN                 5.0             2        1.0
# 4  TCGA_CS_5393            4.0                 5.0             2        1.0
# 5  TCGA_CS_5395            2.0                 4.0             2        2.0
# 6  TCGA_CS_5396            3.0                 3.0             2        3.0
# 7  TCGA_CS_5397            NaN                 4.0             1        2.0
# 8  TCGA_CS_6186            2.0                 4.0             1        2.0
# 9  TCGA_CS_6188            2.0                 4.0             3        2.0
#
#    RPPACluster  OncosignCluster  COCCluster  histological_type  \
# 0          NaN              3.0           2                1.0
# 1          1.0              2.0           1                1.0
# 2          2.0              2.0           1                1.0
# 3          2.0              1.0           1                1.0
# 4          2.0              3.0           1                1.0
# 5          NaN              3.0           2                3.0
# 6          2.0              2.0           3                3.0
# 7          3.0              3.0           2                1.0
# 8          1.0              3.0           2                2.0
# 9          3.0              3.0           2                1.0
#
#    neoplasm_histologic_grade  tumor_tissue_site  laterality  tumor_location  \
# 0                        2.0                1.0         3.0             2.0
# 1                        2.0                1.0         3.0             2.0
# 2                        2.0                1.0         1.0             2.0
# 3                        1.0                1.0         3.0             6.0
# 4                        2.0                1.0         1.0             6.0
# 5                        1.0                1.0         3.0             5.0
# 6                        2.0                1.0         3.0             2.0
# 7                        2.0                1.0         1.0             6.0
# 8                        2.0                1.0         3.0             2.0
# 9                        2.0                1.0         3.0             6.0
#
#    gender  age_at_initial_pathologic  race  ethnicity  death01
# 0     2.0                       67.0   3.0        2.0      1.0
# 1     1.0                       44.0   2.0        NaN      1.0
# 2     2.0                       37.0   3.0        NaN      0.0
# 3     2.0                       50.0   3.0        NaN      0.0
# 4     2.0                       39.0   3.0        NaN      0.0
# 5     2.0                       43.0   2.0        NaN      1.0
# 6     1.0                       53.0   3.0        2.0      0.0
# 7     1.0                       54.0   3.0        2.0      1.0
# 8     2.0                       58.0   3.0        2.0      1.0
# 9     2.0                       48.0   3.0        2.0      0.0

# %%
data_map = []
for sub_dir_path in glob.glob("/kaggle/input/lgg-mri-segmentation/kaggle_3m/"+"*"):
    #if os.path.isdir(sub_path_dir):
    try:
        dir_name = sub_dir_path.split('/')[-1]
        for filename in os.listdir(sub_dir_path):
            image_path = sub_dir_path + '/' + filename
            data_map.extend([dir_name, image_path])
    except Exception as e:
        print(e)
# Out:
# [Errno 20] Not a directory: '/kaggle/input/lgg-mri-segmentation/kaggle_3m/README.md'
# [Errno 20] Not a directory: '/kaggle/input/lgg-mri-segmentation/kaggle_3m/data.csv'

# %%
df = pd.DataFrame({"patient_id" : data_map[::2],
                   "path" : data_map[1::2]})
df.head()
# Out:
#               patient_id                                               path
# 0  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...

# %%
df_imgs = df[~df['path'].str.contains("mask")]
df_masks = df[df['path'].str.contains("mask")]

# File path line length images for later sorting
BASE_LEN = 89 # len(/kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_6404_19850629/TCGA_DU_6404_19850629_ <-!!!43.tif)
END_IMG_LEN = 4 # len(/kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_6404_19850629/TCGA_DU_6404_19850629_43 !!!->.tif)
END_MASK_LEN = 9 # (/kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_6404_19850629/TCGA_DU_6404_19850629_43 !!!->_mask.tif)

# Data sorting
imgs = sorted(df_imgs["path"].values, key=lambda x : int(x[BASE_LEN:-END_IMG_LEN]))
masks = sorted(df_masks["path"].values, key=lambda x : int(x[BASE_LEN:-END_MASK_LEN]))

# Sorting check
idx = random.randint(0, len(imgs)-1)
print("Path to the Image:", imgs[idx], "\nPath to the Mask:", masks[idx])
# Out:
# Path to the Image: /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7302_19911203/TCGA_DU_7302_19911203_1.tif
# Path to the Mask: /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7302_19911203/TCGA_DU_7302_19911203_1_mask.tif

# %% [markdown]
# ### creating final datset

# %%
# Final dataframe
brain_df = pd.DataFrame({"patient_id": df_imgs.patient_id.values,
                         "image_path": imgs,
                         "mask_path": masks
                        })
def pos_neg_diagnosis(mask_path):
    value = np.max(cv2.imread(mask_path))
    if value > 0 : 
        return 1
    else:
        return 0
    
brain_df['mask'] = brain_df['mask_path'].apply(lambda x: pos_neg_diagnosis(x))
brain_df
# Out:
#                  patient_id  \
# 0     TCGA_DU_7010_19860307
# 1     TCGA_DU_7010_19860307
# 2     TCGA_DU_7010_19860307
# 3     TCGA_DU_7010_19860307
# 4     TCGA_DU_7010_19860307
# ...                     ...
# 3924  TCGA_DU_7306_19930512
# 3925  TCGA_DU_7306_19930512
# 3926  TCGA_DU_7306_19930512
# 3927  TCGA_DU_7306_19930512
# 3928  TCGA_DU_7306_19930512
#
#                                              image_path  \
# 0     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# ...                                                 ...
# 3924  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3925  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3926  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3927  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3928  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                               mask_path  mask
# 0     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 1     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 2     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 4     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# ...                                                 ...   ...
# 3924  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3925  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3926  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3927  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3928  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
#
# [3929 rows x 4 columns]

# %% [markdown]
# # 2: DATA VISUALIZATION

# %%
brain_df['mask'].value_counts()
# Out:
# 0    2556
# 1    1373
# Name: mask, dtype: int64

# %%
import plotly.graph_objects as go  # using plotly to create interactive plots

fig = go.Figure([go.Bar(x=brain_df['mask'].value_counts().index, 
                        y=brain_df['mask'].value_counts(), 
                        width=[.4, .4]
                       )
                ])
fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)',
                  marker_line_width=4, opacity=0.4
                 )
fig.update_layout(title_text="Mask Count Plot",
                  width=700,
                  height=550,
                  yaxis=dict(
                             title_text="Count",
                             tickmode="array",
                             titlefont=dict(size=20)
                           )
                 )
fig.update_yaxes(automargin=True)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="3f3bd6ba-e097-492f-8d11-1f6ee29d9800" class="plotly-graph-div" style="height:550px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f3bd6ba-e097-492f-8d11-1f6ee29d9800")) {                    Plotly.newPlot(                        "3f3bd6ba-e097-492f-8d11-1f6ee29d9800",                        [{"marker": {"color": "rgb(158,202,225)", "line": {"color": "rgb(8,48,107)", "width": 4}}, "opacity": 0.4, "type": "bar", "width": [0.4, 0.4], "x": [0, 1], "y": [2556, 1373]}],                        {"height": 550, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"co ...

# %%
for i in range(len(brain_df)):
    if cv2.imread(brain_df.mask_path[i]).max() > 0:
        break

plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.imshow(cv2.imread(brain_df.mask_path[i]));
plt.title('Tumor Location')

plt.subplot(1,2,2)
plt.imshow(cv2.imread(brain_df.image_path[i]));

# %%
cv2.imread(brain_df.mask_path[i]).max(), cv2.imread(brain_df.mask_path[i]).min()
# Out:
# (255, 0)

# %%
# Basic visualizations: Visualize the images (MRI and Mask) in the dataset separately 

fig, axs = plt.subplots(6,2, figsize=(16,26))
count = 0
for x in range(6):
  i = random.randint(0, len(brain_df)) # select a random index
  axs[count][0].title.set_text("Brain MRI") # set title
  axs[count][0].imshow(cv2.imread(brain_df.image_path[i])) # show MRI 
  axs[count][1].title.set_text("Mask - " + str(brain_df['mask'][i])) # plot title on the mask (0 or 1)
  axs[count][1].imshow(cv2.imread(brain_df.mask_path[i])) # Show corresponding mask
  count += 1

fig.tight_layout()

# %%
count = 0
i = 0
fig,axs = plt.subplots(12,3, figsize=(20,50))
for mask in brain_df['mask']:
    if (mask==1):
        img = io.imread(brain_df.image_path[i])
        axs[count][0].title.set_text("Brain MRI")
        axs[count][0].imshow(img)
        
        mask = io.imread(brain_df.mask_path[i])
        axs[count][1].title.set_text("Mask")
        axs[count][1].imshow(mask, cmap='gray')
        
        img[mask==255] = (0,255,150)  # change pixel color at the position of mask
        axs[count][2].title.set_text("MRI with Mask")
        axs[count][2].imshow(img)
        count +=1
    i += 1
    if (count==12):
        break
        
fig.tight_layout()

# %% [markdown]
# # 5: CRETING TEST, TRAIN & VAL SET

# %%
brain_df_train = brain_df.drop(columns=['patient_id'])
# Convert the data in mask column to string format, to use categorical mode in flow_from_dataframe
brain_df_train['mask'] = brain_df_train['mask'].apply(lambda x: str(x))
brain_df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3929 entries, 0 to 3928
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   image_path  3929 non-null   object
#  1   mask_path   3929 non-null   object
#  2   mask        3929 non-null   object
# dtypes: object(3)
# memory usage: 92.2+ KB

# %%
from sklearn.model_selection import train_test_split
SEED = 123456
import os
import random as rn
import numpy as np

os.environ['PYTHONHASHSEED']=str(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
rn.seed(SEED)

train, test = train_test_split(brain_df_train, test_size=0.15, random_state = 123456)

# %%
from keras_preprocessing.image import ImageDataGenerator

#datagen = ImageDataGenerator(rescale=1./255., validation_split=0.1)
datagen = ImageDataGenerator(rescale=1./255., validation_split=0.1, rotation_range = 15, horizontal_flip = True, vertical_flip = True)

train_generator = datagen.flow_from_dataframe(train,
                                              directory='./',
                                              x_col='image_path',
                                              y_col='mask',
                                              subset='training',
                                              class_mode='categorical',
                                              batch_size=16,
                                              shuffle=True,
                                              target_size=(256,256)
                                             )
valid_generator = datagen.flow_from_dataframe(train,
                                              directory='./',
                                              x_col='image_path',
                                              y_col='mask',
                                              subset='validation',
                                              class_mode='categorical',
                                              batch_size=16,
                                              shuffle=True,
                                              target_size=(256,256)
                                             )
test_datagen = ImageDataGenerator(rescale=1./255.)
test_generator = test_datagen.flow_from_dataframe(test,
                                                  directory='./',
                                                  x_col='image_path',
                                                  y_col='mask',
                                                  class_mode='categorical',
                                                  batch_size=16,
                                                  shuffle=False,
                                                  target_size=(256,256)
                                                 )
# Out:
# Found 3006 validated image filenames belonging to 2 classes.
# Found 333 validated image filenames belonging to 2 classes.
# Found 590 validated image filenames belonging to 2 classes.

# %% [markdown]
# # 6: TRAIN A CLASSIFIER MODEL TO DETECT IF TUMOR EXISTS OR NOT

# %% [markdown]
# # 7: CLASSIFIACTION MODEL EVALUATION

# %%
# Train resnet101
# run a different model using the same dataset and data split
import tensorflow.keras.applications as applications
from keras import applications
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications import ResNet101
from tensorflow.keras.applications import VGG16

clf_model = ResNet101(weights='imagenet', include_top=False, input_tensor=Input(shape=(256,256,3)))
# clf_model.summary()

for layer in clf_model.layers:
    layers.trainable = False

head = clf_model.output
head = AveragePooling2D(pool_size=(4,4))(head)
head = Flatten(name='Flatten')(head)
head = Dense(256, activation='relu')(head)
head = Dropout(0.3)(head)
head = Dense(256, activation='relu')(head)
head = Dropout(0.3)(head)
head = Dense(2, activation='softmax')(head)

model = Model(clf_model.input, head)
model.compile(loss = 'categorical_crossentropy', 
              optimizer='adam', 
              metrics=[tf.keras.metrics.FalseNegatives()]
             )
# model.summary()
    
earlystopping = EarlyStopping(monitor='val_loss', 
                              mode='min', 
                              verbose=1, 
                              patience=15
                             )
checkpointer = ModelCheckpoint(filepath="clf-resnet101-weights.hdf5", 
                               verbose=1, 
                               save_best_only=True
                              )
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=10,
                              min_delta=0.0001,
                              factor=0.2
                             )
callbacks = [checkpointer, earlystopping, reduce_lr]

h = model.fit(train_generator, 
              steps_per_epoch= train_generator.n // train_generator.batch_size, 
              epochs = 50, 
              validation_data= valid_generator, 
              validation_steps= valid_generator.n // valid_generator.batch_size, 
              callbacks=[checkpointer, earlystopping])

# saving model achitecture in json file
# model_json = model.to_json()
# with open("clf-resnet50-model.json", "w") as json_file:
#    json_file.write(model_json)

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(h.history['loss']);
plt.plot(h.history['val_loss']);
plt.title("Classification Model LOSS");
plt.ylabel("loss");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

plt.subplot(1,2,2)
plt.plot(h.history['false_negatives']);
plt.plot(h.history['val_false_negatives']);
plt.title("Classification Model False Negatives");
plt.ylabel("False Negatives");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

_, false_neg = model.evaluate(test_generator)
print("Test False Negatives : ".format(false_neg))

prediction = model.predict(test_generator)

pred = np.argmax(prediction, axis=1)
#pred = np.asarray(pred).astype('str')
original = np.asarray(test['mask']).astype('int')

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
accuracy = accuracy_score(original, pred)
print(accuracy)

cm = confusion_matrix(original, pred)

report = classification_report(original, pred, labels = [0,1])
print(report)
plt.figure(figsize = (5,5))
sns.heatmap(cm, annot=True);
model.save("resnet101")

for i in range(len(original)):
    if original[i] == 1 and pred[i] == 0:
        print("false negative", i)
    if original[i] == 0 and pred[i] == 1:
        print("false positive", i)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171450368/171446536 [==============================] - 2s 0us/step
# Epoch 1/50
# 187/187 [==============================] - ETA: 0s - loss: 0.9124 - false_negatives: 1033.0000
# Epoch 00001: val_loss improved from inf to 0.67449, saving model to clf-resnet101-weights.hdf5
# 187/187 [==============================] - 89s 474ms/step - loss: 0.9124 - false_negatives: 1033.0000 - val_loss: 0.6745 - val_false_negatives: 118.0000
# Epoch 2/50
# 187/187 [==============================] - ETA: 0s - loss: 0.5736 - false_negatives: 870.0000
# Epoch 00002: val_loss did not improve from 0.67449
# 187/187 [==============================] - 68s 365ms/step - loss: 0.5736 - false_negatives: 870.0000 - val_loss: 4.9655 - val_false_negatives: 199.0000
# Epoch 3/50
# 187/187 [==============================] - ETA: 0s - loss: 0.4755 - false_negatives: 682.0000
# Epoch 00003: val_loss did not improve from 0.67449
# 187/187 [==============================] - 69s 368ms/step - loss: 0.4755 - false_negatives: 682.0000 - val_loss: 0.6833 - val_false_negatives: 118.0000
# Epoch 4/50
# 187/187 [==============================] - ETA: 0s - loss: 0.4180 - false_negatives: 562.0000
# Epoch 00004: val_loss improved from 0.67449 to 0.65841, saving model to clf-resnet101-weights.hdf5
# 187/187 [==============================] - 72s 387ms/step - loss: 0.4180 - false_negatives: 562.0000 - val_loss: 0.6584 - val_false_negatives: 118.0000
# Epoch 5/50
# 187/187 [==============================] - ETA: 0s - loss: 0.4119 - false_negatives: 559.0000
# Epoch 00005: val_loss improved from 0.65841 to 0.45893, saving model to clf-resnet101-weights.hdf5
# 187/187 [==============================] - 72s 385ms/step - loss: 0.4119 - false_negatives: 559.0000 - val_loss: 0.4589 - val_false_negatives: 61.0000
# Epoch 6/50
# 187/187 [==============================] - ETA: 0s - loss: 0.3526 - false_negatives: 456.0000
# Epoch 00006: val_loss improved from 0.45893 to 0.31055, saving model to clf-resnet101-weights.hdf5
# 187/187 [==============================] - 72s 385ms/step - loss: 0.3526 - false_negatives: 456.0000 - val_loss: 0.3105 - val_false_negatives: 40.0000
# Epoch 7/50
# 187/187 [==============================] - ETA: 0s - loss: 0.3165 - false_negatives: 391.0000
# Epoch 00007: val_loss did not improve from 0.31055
# 187/187 [==============================] - 75s 401ms/step - loss: 0.3165 - false_negatives: 391.0000 - val_loss: 0.8591 - val_false_negatives: 83.0000
# Epoch 8/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2842 - false_negatives: 334.0000
# Epoch 00008: val_loss improved from 0.31055 to 0.23395, saving model to clf-resnet101-weights.hdf5
# 187/187 [==============================] - 75s 399ms/step - loss: 0.2842 - false_negatives: 334.0000 - val_loss: 0.2340 - val_false_negatives: 27.0000
# Epoch 9/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2729 - false_negatives: 309.0000
# Epoch 00009: val_loss did not improve from 0.23395
# 187/187 [==============================] - 71s 380ms/step - loss: 0.2729 - false_negatives: 309.0000 - val_loss: 0.3346 - val_false_negatives: 44.0000
# Epoch 10/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2943 - false_negatives: 322.0000
# Epoch 00010: val_loss did not improve from 0.23395
# 187/187 [==============================] - 70s 372ms/step - loss: 0.2943 - false_negatives: 322.0000 - val_loss: 0.4425 - val_false_negatives: 53.0000
# Epoch 11/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2391 - false_negatives: 253.0000
# Epoch 00011: val_loss did not improve from 0.23395
# 187/187 [==============================] - 70s 374ms/step - loss: 0.2391 - false_negatives: 253.0000 - val_loss: 0.3000 - val_false_negatives: 26.0000
# Epoch 12/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2344 - false_negatives: 254.0000
# Epoch 00012: val_loss did not improve from 0.23395
# 187/187 [==============================] - 72s 383ms/step - loss: 0.2344 - false_negatives: 254.0000 - val_loss: 1.0683 - val_false_negatives: 108.0000
# Epoch 13/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2293 - false_negatives: 241.0000
# Epoch 00013: val_loss improved from 0.23395 to 0.11504, saving model to clf-resnet101-weights.hdf5
# 187/187 [==============================] - 75s 399ms/step - loss: 0.2293 - false_negatives: 241.0000 - val_loss: 0.1150 - val_false_negatives: 11.0000
# Epoch 14/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2067 - false_negatives: 215.0000
# Epoch 00014: val_loss did not improve from 0.11504
# 187/187 [==============================] - 71s 378ms/step - loss: 0.2067 - false_negatives: 215.0000 - val_loss: 0.2555 - val_false_negatives: 28.0000
# Epoch 15/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2306 - false_negatives: 264.0000
# Epoch 00015: val_loss did not improve from 0.11504
# 187/187 [==============================] - 70s 376ms/step - loss: 0.2306 - false_negatives: 264.0000 - val_loss: 0.4092 - val_false_negatives: 53.0000
# Epoch 16/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1956 - false_negatives: 193.0000
# Epoch 00016: val_loss did not improve from 0.11504
# 187/187 [==============================] - 71s 379ms/step - loss: 0.1956 - false_negatives: 193.0000 - val_loss: 0.1861 - val_false_negatives: 21.0000
# Epoch 17/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1865 - false_negatives: 178.0000
# Epoch 00017: val_loss did not improve from 0.11504
# 187/187 [==============================] - 72s 383ms/step - loss: 0.1865 - false_negatives: 178.0000 - val_loss: 0.1219 - val_false_negatives: 9.0000
# Epoch 18/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2301 - false_negatives: 250.0000
# Epoch 00018: val_loss did not improve from 0.11504
# 187/187 [==============================] - 70s 377ms/step - loss: 0.2301 - false_negatives: 250.0000 - val_loss: 0.2331 - val_false_negatives: 26.0000
# Epoch 19/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1843 - false_negatives: 197.0000
# Epoch 00019: val_loss did not improve from 0.11504
# 187/187 [==============================] - 70s 372ms/step - loss: 0.1843 - false_negatives: 197.0000 - val_loss: 0.1944 - val_false_negatives: 21.0000
# Epoch 20/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1854 - false_negatives: 197.0000
# Epoch 00020: val_loss did not improve from 0.11504
# 187/187 [==============================] - 71s 380ms/step - loss: 0.1854 - false_negatives: 197.0000 - val_loss: 0.1241 - val_false_negatives: 13.0000
# Epoch 21/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2059 - false_negatives: 224.0000
# Epoch 00021: val_loss did not improve from 0.11504
# 187/187 [==============================] - 72s 385ms/step - loss: 0.2059 - false_negatives: 224.0000 - val_loss: 0.1192 - val_false_negatives: 16.0000
# Epoch 22/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1858 - false_negatives: 185.0000
# Epoch 00022: val_loss did not improve from 0.11504
# 187/187 [==============================] - 74s 396ms/step - loss: 0.1858 - false_negatives: 185.0000 - val_loss: 0.3225 - val_false_negatives: 42.0000
# Epoch 23/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1780 - false_negatives: 184.0000
# Epoch 00023: val_loss did not improve from 0.11504
# 187/187 [==============================] - 72s 383ms/step - loss: 0.1780 - false_negatives: 184.0000 - val_loss: 0.7526 - val_false_negatives: 87.0000
# Epoch 24/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2318 - false_negatives: 251.0000
# Epoch 00024: val_loss did not improve from 0.11504
# 187/187 [==============================] - 72s 384ms/step - loss: 0.2318 - false_negatives: 251.0000 - val_loss: 0.1926 - val_false_negatives: 21.0000
# Epoch 25/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2207 - false_negatives: 221.0000
# Epoch 00025: val_loss did not improve from 0.11504
# 187/187 [==============================] - 74s 393ms/step - loss: 0.2207 - false_negatives: 221.0000 - val_loss: 0.2680 - val_false_negatives: 29.0000
# Epoch 26/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2144 - false_negatives: 208.0000
# Epoch 00026: val_loss did not improve from 0.11504
# 187/187 [==============================] - 74s 398ms/step - loss: 0.2144 - false_negatives: 208.0000 - val_loss: 0.2387 - val_false_negatives: 38.0000
# Epoch 27/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2177 - false_negatives: 228.0000
# Epoch 00027: val_loss did not improve from 0.11504
# 187/187 [==============================] - 96s 516ms/step - loss: 0.2177 - false_negatives: 228.0000 - val_loss: 0.2160 - val_false_negatives: 27.0000
# Epoch 28/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1996 - false_negatives: 198.0000
# Epoch 00028: val_loss did not improve from 0.11504
# 187/187 [==============================] - 75s 399ms/step - loss: 0.1996 - false_negatives: 198.0000 - val_loss: 0.3770 - val_false_negatives: 67.0000
# Epoch 00028: early stopping
# 37/37 [==============================] - 5s 136ms/step - loss: 0.3657 - false_negatives: 131.0000
# Test False Negatives :
# 0.7779661016949152
#               precision    recall  f1-score   support
#
#            0       0.96      0.70      0.81       399
#            1       0.60      0.94      0.73       191
#
#     accuracy                           0.78       590
#    macro avg       0.78      0.82      0.77       590
# weighted avg       0.84      0.78      0.79       590
#
# false positive 2
# false positive 5
# false positive 8
# false positive 10
# false positive 13
# false positive 16
# false positive 21
# false positive 22
# false positive 26
# false positive 28
# false positive 33
# false positive 35
# false positive 40
# false positive 41
# false positive 54
# false positive 56
# false positive 59
# false positive 60
# false positive 61
# false positive 66
# false positive 67
# false positive 68
# false positive 74
# false positive 82
# false positive 93
# false positive 94
# false negative 99
# false positive 109
# false positive 111
# false positive 123
# false positive 126
# false positive 128
# false positive 134
# false positive 135
# false positive 145
# false positive 147
# false negative 152
# false positive 165
# false positive 166
# false positive 170
# false negative 174
# false positive 183
# false positive 185
# false positive 186
# false positive 187
# false negative 192
# false positive 193
# false positive 198
# false positive 199
# false positive 210
# false positive 221
# false positive 222
# false positive 233
# false positive 240
# false positive 241
# false positive 244
# false negative 248
# false positive 249
# false negative 256
# false positive 261
# false positive 267
# false positive 270
# false positive 274
# false positive 277
# false positive 278
# false positive 302
# false positive 308
# false positive 310
# false positive 314
# false positive 318
# false positive 320
# false positive 327
# false negative 335
# false negative 338
# false positive 342
# false positive 348
# false positive 360
# false positive 368
# false positive 370
# false positive 380
# false positive 381
# false positive 391
# false positive 395
# false positive 399
# false positive 400
# false positive 405
# false positive 406
# false positive 414
# false positive 416
# false positive 424
# false positive 426
# false positive 427
# false positive 443
# false negative 447
# false positive 453
# false positive 460
# false positive 462
# false positive 464
# false positive 467
# false negative 477
# false positive 478
# false positive 485
# false positive 487
# false positive 492
# false positive 494
# false positive 495
# false positive 502
# false positive 505
# false positive 507
# false positive 508
# false positive 510
# false positive 514
# false negative 517
# false positive 520
# false positive 527
# false positive 530
# false positive 531
# false positive 532
# false positive 533
# false positive 538
# false positive 546
# false positive 548
# false positive 554
# false positive 556
# false positive 558
# false positive 566
# false positive 567
# false positive 573
# false positive 578
# false positive 583
# false positive 587

# %%
# Train resnet50
# run a different model using the same dataset and data split
import tensorflow.keras.applications as applications
from keras import applications
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications import ResNet101
from tensorflow.keras.applications import VGG16

clf_model = ResNet50(weights='imagenet', include_top=False, input_tensor=Input(shape=(256,256,3)))
# clf_model.summary()

for layer in clf_model.layers:
    layers.trainable = False

head = clf_model.output
head = AveragePooling2D(pool_size=(2,2))(head)
head = Flatten(name='Flatten')(head)
head = Dense(256, activation='relu')(head)
head = Dropout(0.3)(head)
head = Dense(256, activation='relu')(head)
head = Dropout(0.3)(head)
head = Dense(2, activation='softmax')(head)

model = Model(clf_model.input, head)
model.compile(loss = 'categorical_crossentropy', 
              optimizer='adam', 
              metrics=[tf.keras.metrics.FalseNegatives()]
             )
# model.summary()

earlystopping = EarlyStopping(monitor='val_loss', 
                              mode='min', 
                              verbose=1, 
                              patience=15
                             )
checkpointer = ModelCheckpoint(filepath="clf-resnet50-weights.hdf5", 
                               verbose=1, 
                               save_best_only=True
                              )
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=10,
                              min_delta=0.0001,
                              factor=0.2
                             )
callbacks = [checkpointer, earlystopping, reduce_lr]

h = model.fit(train_generator, 
              steps_per_epoch= train_generator.n // train_generator.batch_size, 
              epochs = 50, 
              validation_data= valid_generator, 
              validation_steps= valid_generator.n // valid_generator.batch_size, 
              callbacks=[checkpointer, earlystopping])

# saving model achitecture in json file
# model_json = model.to_json()
# with open("clf-resnet50-model.json", "w") as json_file:
#    json_file.write(model_json)

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(h.history['loss']);
plt.plot(h.history['val_loss']);
plt.title("Classification Model LOSS");
plt.ylabel("loss");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

plt.subplot(1,2,2)
plt.plot(h.history['false_negatives_1']);
plt.plot(h.history['val_false_negatives_1']);
plt.title("Classification Model False Negatives");
plt.ylabel("False Negatives");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

_, false_neg = model.evaluate(test_generator)
print("Test False Negatives : ".format(false_neg))

prediction = model.predict(test_generator)

pred = np.argmax(prediction, axis=1)
#pred = np.asarray(pred).astype('str')
original = np.asarray(test['mask']).astype('int')

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
accuracy = accuracy_score(original, pred)
print(accuracy)

cm = confusion_matrix(original, pred)

report = classification_report(original, pred, labels = [0,1])
print(report)
plt.figure(figsize = (5,5))
sns.heatmap(cm, annot=True);
model.save("resnet50")

for i in range(len(original)):
    if original[i] == 1 and pred[i] == 0:
        print("false negative", i)
    if original[i] == 0 and pred[i] == 1:
        print("false positive", i)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# Epoch 1/50
# 187/187 [==============================] - ETA: 0s - loss: 1.0631 - false_negatives_1: 950.0000
# Epoch 00001: val_loss improved from inf to 0.66989, saving model to clf-resnet50-weights.hdf5
# 187/187 [==============================] - 71s 377ms/step - loss: 1.0631 - false_negatives_1: 950.0000 - val_loss: 0.6699 - val_false_negatives_1: 120.0000
# Epoch 2/50
# 187/187 [==============================] - ETA: 0s - loss: 0.4872 - false_negatives_1: 730.0000
# Epoch 00002: val_loss did not improve from 0.66989
# 187/187 [==============================] - 68s 365ms/step - loss: 0.4872 - false_negatives_1: 730.0000 - val_loss: 0.6774 - val_false_negatives_1: 117.0000
# Epoch 3/50
# 187/187 [==============================] - ETA: 0s - loss: 0.4481 - false_negatives_1: 662.0000
# Epoch 00003: val_loss improved from 0.66989 to 0.66802, saving model to clf-resnet50-weights.hdf5
# 187/187 [==============================] - 69s 369ms/step - loss: 0.4481 - false_negatives_1: 662.0000 - val_loss: 0.6680 - val_false_negatives_1: 116.0000
# Epoch 4/50
# 187/187 [==============================] - ETA: 0s - loss: 0.4337 - false_negatives_1: 630.0000
# Epoch 00004: val_loss did not improve from 0.66802
# 187/187 [==============================] - 68s 365ms/step - loss: 0.4337 - false_negatives_1: 630.0000 - val_loss: 0.6731 - val_false_negatives_1: 117.0000
# Epoch 5/50
# 187/187 [==============================] - ETA: 0s - loss: 0.4475 - false_negatives_1: 718.0000
# Epoch 00005: val_loss did not improve from 0.66802
# 187/187 [==============================] - 69s 367ms/step - loss: 0.4475 - false_negatives_1: 718.0000 - val_loss: 0.6699 - val_false_negatives_1: 118.0000
# Epoch 6/50
# 187/187 [==============================] - ETA: 0s - loss: 0.3956 - false_negatives_1: 563.0000
# Epoch 00006: val_loss improved from 0.66802 to 0.46814, saving model to clf-resnet50-weights.hdf5
# 187/187 [==============================] - 72s 385ms/step - loss: 0.3956 - false_negatives_1: 563.0000 - val_loss: 0.4681 - val_false_negatives_1: 68.0000
# Epoch 7/50
# 187/187 [==============================] - ETA: 0s - loss: 0.3574 - false_negatives_1: 464.0000
# Epoch 00007: val_loss improved from 0.46814 to 0.31374, saving model to clf-resnet50-weights.hdf5
# 187/187 [==============================] - 95s 508ms/step - loss: 0.3574 - false_negatives_1: 464.0000 - val_loss: 0.3137 - val_false_negatives_1: 43.0000
# Epoch 8/50
# 187/187 [==============================] - ETA: 0s - loss: 0.3425 - false_negatives_1: 475.0000
# Epoch 00008: val_loss did not improve from 0.31374
# 187/187 [==============================] - 67s 356ms/step - loss: 0.3425 - false_negatives_1: 475.0000 - val_loss: 0.8242 - val_false_negatives_1: 54.0000
# Epoch 9/50
# 187/187 [==============================] - ETA: 0s - loss: 0.3340 - false_negatives_1: 411.0000
# Epoch 00009: val_loss improved from 0.31374 to 0.23643, saving model to clf-resnet50-weights.hdf5
# 187/187 [==============================] - 68s 365ms/step - loss: 0.3340 - false_negatives_1: 411.0000 - val_loss: 0.2364 - val_false_negatives_1: 36.0000
# Epoch 10/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2872 - false_negatives_1: 347.0000
# Epoch 00010: val_loss did not improve from 0.23643
# 187/187 [==============================] - 67s 357ms/step - loss: 0.2872 - false_negatives_1: 347.0000 - val_loss: 0.7172 - val_false_negatives_1: 72.0000
# Epoch 11/50
# 187/187 [==============================] - ETA: 0s - loss: 0.3122 - false_negatives_1: 387.0000
# Epoch 00011: val_loss did not improve from 0.23643
# 187/187 [==============================] - 66s 354ms/step - loss: 0.3122 - false_negatives_1: 387.0000 - val_loss: 0.2789 - val_false_negatives_1: 36.0000
# Epoch 12/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2567 - false_negatives_1: 308.0000
# Epoch 00012: val_loss improved from 0.23643 to 0.21230, saving model to clf-resnet50-weights.hdf5
# 187/187 [==============================] - 68s 366ms/step - loss: 0.2567 - false_negatives_1: 308.0000 - val_loss: 0.2123 - val_false_negatives_1: 29.0000
# Epoch 13/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2559 - false_negatives_1: 296.0000
# Epoch 00013: val_loss did not improve from 0.21230
# 187/187 [==============================] - 69s 367ms/step - loss: 0.2559 - false_negatives_1: 296.0000 - val_loss: 0.2973 - val_false_negatives_1: 43.0000
# Epoch 14/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2493 - false_negatives_1: 309.0000
# Epoch 00014: val_loss did not improve from 0.21230
# 187/187 [==============================] - 66s 354ms/step - loss: 0.2493 - false_negatives_1: 309.0000 - val_loss: 0.2820 - val_false_negatives_1: 30.0000
# Epoch 15/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2408 - false_negatives_1: 278.0000
# Epoch 00015: val_loss did not improve from 0.21230
# 187/187 [==============================] - 66s 353ms/step - loss: 0.2408 - false_negatives_1: 278.0000 - val_loss: 0.2604 - val_false_negatives_1: 26.0000
# Epoch 16/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2643 - false_negatives_1: 278.0000
# Epoch 00016: val_loss improved from 0.21230 to 0.20816, saving model to clf-resnet50-weights.hdf5
# 187/187 [==============================] - 67s 360ms/step - loss: 0.2643 - false_negatives_1: 278.0000 - val_loss: 0.2082 - val_false_negatives_1: 22.0000
# Epoch 17/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2278 - false_negatives_1: 248.0000
# Epoch 00017: val_loss improved from 0.20816 to 0.15413, saving model to clf-resnet50-weights.hdf5
# 187/187 [==============================] - 68s 365ms/step - loss: 0.2278 - false_negatives_1: 248.0000 - val_loss: 0.1541 - val_false_negatives_1: 18.0000
# Epoch 18/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2095 - false_negatives_1: 217.0000
# Epoch 00018: val_loss did not improve from 0.15413
# 187/187 [==============================] - 66s 352ms/step - loss: 0.2095 - false_negatives_1: 217.0000 - val_loss: 0.2231 - val_false_negatives_1: 30.0000
# Epoch 19/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2268 - false_negatives_1: 241.0000
# Epoch 00019: val_loss did not improve from 0.15413
# 187/187 [==============================] - 65s 349ms/step - loss: 0.2268 - false_negatives_1: 241.0000 - val_loss: 0.2286 - val_false_negatives_1: 28.0000
# Epoch 20/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2206 - false_negatives_1: 237.0000
# Epoch 00020: val_loss improved from 0.15413 to 0.14066, saving model to clf-resnet50-weights.hdf5
# 187/187 [==============================] - 67s 358ms/step - loss: 0.2206 - false_negatives_1: 237.0000 - val_loss: 0.1407 - val_false_negatives_1: 16.0000
# Epoch 21/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1996 - false_negatives_1: 208.0000
# Epoch 00021: val_loss did not improve from 0.14066
# 187/187 [==============================] - 65s 350ms/step - loss: 0.1996 - false_negatives_1: 208.0000 - val_loss: 0.1701 - val_false_negatives_1: 19.0000
# Epoch 22/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2004 - false_negatives_1: 209.0000
# Epoch 00022: val_loss did not improve from 0.14066
# 187/187 [==============================] - 66s 350ms/step - loss: 0.2004 - false_negatives_1: 209.0000 - val_loss: 0.2837 - val_false_negatives_1: 34.0000
# Epoch 23/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2164 - false_negatives_1: 226.0000
# Epoch 00023: val_loss did not improve from 0.14066
# 187/187 [==============================] - 65s 346ms/step - loss: 0.2164 - false_negatives_1: 226.0000 - val_loss: 0.1902 - val_false_negatives_1: 25.0000
# Epoch 24/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1936 - false_negatives_1: 194.0000
# Epoch 00024: val_loss improved from 0.14066 to 0.12674, saving model to clf-resnet50-weights.hdf5
# 187/187 [==============================] - 66s 355ms/step - loss: 0.1936 - false_negatives_1: 194.0000 - val_loss: 0.1267 - val_false_negatives_1: 15.0000
# Epoch 25/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1718 - false_negatives_1: 171.0000
# Epoch 00025: val_loss did not improve from 0.12674
# 187/187 [==============================] - 65s 348ms/step - loss: 0.1718 - false_negatives_1: 171.0000 - val_loss: 0.1750 - val_false_negatives_1: 24.0000
# Epoch 26/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1884 - false_negatives_1: 193.0000
# Epoch 00026: val_loss did not improve from 0.12674
# 187/187 [==============================] - 68s 363ms/step - loss: 0.1884 - false_negatives_1: 193.0000 - val_loss: 0.1497 - val_false_negatives_1: 16.0000
# Epoch 27/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1631 - false_negatives_1: 172.0000
# Epoch 00027: val_loss improved from 0.12674 to 0.09370, saving model to clf-resnet50-weights.hdf5
# 187/187 [==============================] - 69s 371ms/step - loss: 0.1631 - false_negatives_1: 172.0000 - val_loss: 0.0937 - val_false_negatives_1: 12.0000
# Epoch 28/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1672 - false_negatives_1: 162.0000
# Epoch 00028: val_loss did not improve from 0.09370
# 187/187 [==============================] - 65s 347ms/step - loss: 0.1672 - false_negatives_1: 162.0000 - val_loss: 0.4405 - val_false_negatives_1: 62.0000
# Epoch 29/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1925 - false_negatives_1: 194.0000
# Epoch 00029: val_loss did not improve from 0.09370
# 187/187 [==============================] - 65s 349ms/step - loss: 0.1925 - false_negatives_1: 194.0000 - val_loss: 0.2891 - val_false_negatives_1: 20.0000
# Epoch 30/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1904 - false_negatives_1: 181.0000
# Epoch 00030: val_loss did not improve from 0.09370
# 187/187 [==============================] - 67s 361ms/step - loss: 0.1904 - false_negatives_1: 181.0000 - val_loss: 0.3958 - val_false_negatives_1: 49.0000
# Epoch 31/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1956 - false_negatives_1: 208.0000
# Epoch 00031: val_loss did not improve from 0.09370
# 187/187 [==============================] - 67s 360ms/step - loss: 0.1956 - false_negatives_1: 208.0000 - val_loss: 0.1616 - val_false_negatives_1: 20.0000
# Epoch 32/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1658 - false_negatives_1: 179.0000
# Epoch 00032: val_loss did not improve from 0.09370
# 187/187 [==============================] - 65s 348ms/step - loss: 0.1658 - false_negatives_1: 179.0000 - val_loss: 0.2340 - val_false_negatives_1: 19.0000
# Epoch 33/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1606 - false_negatives_1: 163.0000
# Epoch 00033: val_loss did not improve from 0.09370
# 187/187 [==============================] - 65s 346ms/step - loss: 0.1606 - false_negatives_1: 163.0000 - val_loss: 0.1319 - val_false_negatives_1: 17.0000
# Epoch 34/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1498 - false_negatives_1: 148.0000
# Epoch 00034: val_loss did not improve from 0.09370
# 187/187 [==============================] - 64s 341ms/step - loss: 0.1498 - false_negatives_1: 148.0000 - val_loss: 0.4001 - val_false_negatives_1: 31.0000
# Epoch 35/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2017 - false_negatives_1: 196.0000
# Epoch 00035: val_loss did not improve from 0.09370
# 187/187 [==============================] - 64s 342ms/step - loss: 0.2017 - false_negatives_1: 196.0000 - val_loss: 0.4842 - val_false_negatives_1: 29.0000
# Epoch 36/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1776 - false_negatives_1: 168.0000
# Epoch 00036: val_loss did not improve from 0.09370
# 187/187 [==============================] - 65s 346ms/step - loss: 0.1776 - false_negatives_1: 168.0000 - val_loss: 0.2437 - val_false_negatives_1: 26.0000
# Epoch 37/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1683 - false_negatives_1: 169.0000
# Epoch 00037: val_loss did not improve from 0.09370
# 187/187 [==============================] - 63s 339ms/step - loss: 0.1683 - false_negatives_1: 169.0000 - val_loss: 0.3104 - val_false_negatives_1: 50.0000
# Epoch 38/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1539 - false_negatives_1: 146.0000
# Epoch 00038: val_loss did not improve from 0.09370
# 187/187 [==============================] - 62s 332ms/step - loss: 0.1539 - false_negatives_1: 146.0000 - val_loss: 0.2339 - val_false_negatives_1: 27.0000
# Epoch 39/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1575 - false_negatives_1: 168.0000
# Epoch 00039: val_loss did not improve from 0.09370
# 187/187 [==============================] - 61s 324ms/step - loss: 0.1575 - false_negatives_1: 168.0000 - val_loss: 0.3149 - val_false_negatives_1: 37.0000
# Epoch 40/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1489 - false_negatives_1: 165.0000
# Epoch 00040: val_loss did not improve from 0.09370
# 187/187 [==============================] - 62s 329ms/step - loss: 0.1489 - false_negatives_1: 165.0000 - val_loss: 0.2191 - val_false_negatives_1: 27.0000
# Epoch 41/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1499 - false_negatives_1: 152.0000
# Epoch 00041: val_loss did not improve from 0.09370
# 187/187 [==============================] - 61s 326ms/step - loss: 0.1499 - false_negatives_1: 152.0000 - val_loss: 0.1653 - val_false_negatives_1: 16.0000
# Epoch 42/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1375 - false_negatives_1: 129.0000
# Epoch 00042: val_loss did not improve from 0.09370
# 187/187 [==============================] - 63s 339ms/step - loss: 0.1375 - false_negatives_1: 129.0000 - val_loss: 0.2088 - val_false_negatives_1: 16.0000
# Epoch 00042: early stopping
# 37/37 [==============================] - 2s 49ms/step - loss: 0.1503 - false_negatives_1: 24.0000
# Test False Negatives :
# 0.9593220338983051
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       399
#            1       0.99      0.88      0.93       191
#
#     accuracy                           0.96       590
#    macro avg       0.97      0.94      0.95       590
# weighted avg       0.96      0.96      0.96       590
#
# false negative 27
# false negative 46
# false negative 65
# false negative 103
# false negative 106
# false negative 118
# false negative 131
# false negative 202
# false positive 210
# false negative 251
# false negative 255
# false negative 256
# false negative 298
# false negative 333
# false negative 335
# false negative 344
# false negative 374
# false negative 451
# false negative 457
# false negative 472
# false negative 477
# false negative 486
# false positive 535
# false negative 569

# %%
# Train resnet50_2
# run a different model using the same dataset and data split
import tensorflow.keras.applications as applications
from keras import applications
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications import ResNet101
from tensorflow.keras.applications import VGG16

clf_model = ResNet50(weights='imagenet', include_top=False, input_tensor=Input(shape=(256,256,3)))
# clf_model.summary()

for layer in clf_model.layers:
    layers.trainable = False
    
head = clf_model.output
head = AveragePooling2D(pool_size=(4,4))(head)
head = Flatten(name='Flatten')(head)
head = Dense(256, activation='relu')(head)
head = Dropout(0.3)(head)
head = Dense(128, activation='relu')(head)
head = Dropout(0.2)(head)
head = Dense(2, activation='softmax')(head)

model = Model(clf_model.input, head)
model.compile(loss = 'categorical_crossentropy', 
              optimizer='adagrad', 
              metrics=[tf.keras.metrics.FalseNegatives()]
             )
# model.summary()

earlystopping = EarlyStopping(monitor='val_loss', 
                              mode='min', 
                              verbose=1, 
                              patience=15
                             )
checkpointer = ModelCheckpoint(filepath="clf-resnet50_2-weights.hdf5", 
                               verbose=1, 
                               save_best_only=True
                              )
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=10,
                              min_delta=0.0001,
                              factor=0.2
                             )
callbacks = [checkpointer, earlystopping, reduce_lr]

h = model.fit(train_generator, 
              steps_per_epoch= train_generator.n // train_generator.batch_size, 
              epochs = 50, 
              validation_data= valid_generator, 
              validation_steps= valid_generator.n // valid_generator.batch_size, 
              callbacks=[checkpointer, earlystopping])

# saving model achitecture in json file
# model_json = model.to_json()
# with open("clf-resnet50-model.json", "w") as json_file:
#    json_file.write(model_json)

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(h.history['loss']);
plt.plot(h.history['val_loss']);
plt.title("Classification Model LOSS");
plt.ylabel("loss");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

plt.subplot(1,2,2)
plt.plot(h.history['false_negatives_2']);
plt.plot(h.history['val_false_negatives_2']);
plt.title("Classification Model False Negatives");
plt.ylabel("False Negatives");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

_, false_neg = model.evaluate(test_generator)
print("Test False Negatives : ".format(false_neg))

prediction = model.predict(test_generator)

pred = np.argmax(prediction, axis=1)
#pred = np.asarray(pred).astype('str')
original = np.asarray(test['mask']).astype('int')

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
accuracy = accuracy_score(original, pred)
print(accuracy)

cm = confusion_matrix(original, pred)

report = classification_report(original, pred, labels = [0,1])
print(report)
plt.figure(figsize = (5,5))
sns.heatmap(cm, annot=True);
model.save("resnet50_2")


for i in range(len(original)):
    if original[i] == 1 and pred[i] == 0:
        print("false negative", i)
    if original[i] == 0 and pred[i] == 1:
        print("false positive", i)
# Out:
# Epoch 1/50
# 187/187 [==============================] - ETA: 0s - loss: 0.4943 - false_negatives_2: 748.0000
# Epoch 00001: val_loss improved from inf to 0.73836, saving model to clf-resnet50_2-weights.hdf5
# 187/187 [==============================] - 66s 354ms/step - loss: 0.4943 - false_negatives_2: 748.0000 - val_loss: 0.7384 - val_false_negatives_2: 118.0000
# Epoch 2/50
# 187/187 [==============================] - ETA: 0s - loss: 0.3359 - false_negatives_2: 458.0000
# Epoch 00002: val_loss did not improve from 0.73836
# 187/187 [==============================] - 65s 347ms/step - loss: 0.3359 - false_negatives_2: 458.0000 - val_loss: 1.0020 - val_false_negatives_2: 117.0000
# Epoch 3/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2525 - false_negatives_2: 309.0000
# Epoch 00003: val_loss improved from 0.73836 to 0.70095, saving model to clf-resnet50_2-weights.hdf5
# 187/187 [==============================] - 62s 330ms/step - loss: 0.2525 - false_negatives_2: 309.0000 - val_loss: 0.7010 - val_false_negatives_2: 114.0000
# Epoch 4/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2095 - false_negatives_2: 248.0000
# Epoch 00004: val_loss improved from 0.70095 to 0.51981, saving model to clf-resnet50_2-weights.hdf5
# 187/187 [==============================] - 66s 351ms/step - loss: 0.2095 - false_negatives_2: 248.0000 - val_loss: 0.5198 - val_false_negatives_2: 80.0000
# Epoch 5/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1698 - false_negatives_2: 193.0000
# Epoch 00005: val_loss improved from 0.51981 to 0.29200, saving model to clf-resnet50_2-weights.hdf5
# 187/187 [==============================] - 66s 352ms/step - loss: 0.1698 - false_negatives_2: 193.0000 - val_loss: 0.2920 - val_false_negatives_2: 40.0000
# Epoch 6/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1462 - false_negatives_2: 163.0000
# Epoch 00006: val_loss improved from 0.29200 to 0.18953, saving model to clf-resnet50_2-weights.hdf5
# 187/187 [==============================] - 68s 362ms/step - loss: 0.1462 - false_negatives_2: 163.0000 - val_loss: 0.1895 - val_false_negatives_2: 22.0000
# Epoch 7/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1339 - false_negatives_2: 159.0000
# Epoch 00007: val_loss improved from 0.18953 to 0.14492, saving model to clf-resnet50_2-weights.hdf5
# 187/187 [==============================] - 68s 361ms/step - loss: 0.1339 - false_negatives_2: 159.0000 - val_loss: 0.1449 - val_false_negatives_2: 18.0000
# Epoch 8/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1219 - false_negatives_2: 145.0000
# Epoch 00008: val_loss improved from 0.14492 to 0.14100, saving model to clf-resnet50_2-weights.hdf5
# 187/187 [==============================] - 68s 363ms/step - loss: 0.1219 - false_negatives_2: 145.0000 - val_loss: 0.1410 - val_false_negatives_2: 18.0000
# Epoch 9/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1005 - false_negatives_2: 108.0000
# Epoch 00009: val_loss improved from 0.14100 to 0.13900, saving model to clf-resnet50_2-weights.hdf5
# 187/187 [==============================] - 68s 363ms/step - loss: 0.1005 - false_negatives_2: 108.0000 - val_loss: 0.1390 - val_false_negatives_2: 17.0000
# Epoch 10/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0863 - false_negatives_2: 86.0000
# Epoch 00010: val_loss improved from 0.13900 to 0.09874, saving model to clf-resnet50_2-weights.hdf5
# 187/187 [==============================] - 67s 360ms/step - loss: 0.0863 - false_negatives_2: 86.0000 - val_loss: 0.0987 - val_false_negatives_2: 12.0000
# Epoch 11/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0924 - false_negatives_2: 91.0000
# Epoch 00011: val_loss did not improve from 0.09874
# 187/187 [==============================] - 67s 358ms/step - loss: 0.0924 - false_negatives_2: 91.0000 - val_loss: 0.1136 - val_false_negatives_2: 11.0000
# Epoch 12/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0718 - false_negatives_2: 73.0000
# Epoch 00012: val_loss did not improve from 0.09874
# 187/187 [==============================] - 67s 357ms/step - loss: 0.0718 - false_negatives_2: 73.0000 - val_loss: 0.1327 - val_false_negatives_2: 15.0000
# Epoch 13/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0736 - false_negatives_2: 81.0000
# Epoch 00013: val_loss did not improve from 0.09874
# 187/187 [==============================] - 69s 372ms/step - loss: 0.0736 - false_negatives_2: 81.0000 - val_loss: 0.1304 - val_false_negatives_2: 14.0000
# Epoch 14/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0675 - false_negatives_2: 73.0000
# Epoch 00014: val_loss did not improve from 0.09874
# 187/187 [==============================] - 71s 378ms/step - loss: 0.0675 - false_negatives_2: 73.0000 - val_loss: 0.1266 - val_false_negatives_2: 13.0000
# Epoch 15/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0538 - false_negatives_2: 57.0000
# Epoch 00015: val_loss improved from 0.09874 to 0.09771, saving model to clf-resnet50_2-weights.hdf5
# 187/187 [==============================] - 70s 377ms/step - loss: 0.0538 - false_negatives_2: 57.0000 - val_loss: 0.0977 - val_false_negatives_2: 10.0000
# Epoch 16/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0414 - false_negatives_2: 47.0000
# Epoch 00016: val_loss did not improve from 0.09771
# 187/187 [==============================] - 71s 377ms/step - loss: 0.0414 - false_negatives_2: 47.0000 - val_loss: 0.1355 - val_false_negatives_2: 14.0000
# Epoch 17/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0476 - false_negatives_2: 49.0000
# Epoch 00017: val_loss did not improve from 0.09771
# 187/187 [==============================] - 71s 378ms/step - loss: 0.0476 - false_negatives_2: 49.0000 - val_loss: 0.1003 - val_false_negatives_2: 12.0000
# Epoch 18/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0418 - false_negatives_2: 43.0000
# Epoch 00018: val_loss did not improve from 0.09771
# 187/187 [==============================] - 70s 373ms/step - loss: 0.0418 - false_negatives_2: 43.0000 - val_loss: 0.1227 - val_false_negatives_2: 11.0000
# Epoch 19/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0426 - false_negatives_2: 45.0000
# Epoch 00019: val_loss improved from 0.09771 to 0.09147, saving model to clf-resnet50_2-weights.hdf5
# 187/187 [==============================] - 71s 381ms/step - loss: 0.0426 - false_negatives_2: 45.0000 - val_loss: 0.0915 - val_false_negatives_2: 10.0000
# Epoch 20/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0360 - false_negatives_2: 32.0000
# Epoch 00020: val_loss did not improve from 0.09147
# 187/187 [==============================] - 71s 379ms/step - loss: 0.0360 - false_negatives_2: 32.0000 - val_loss: 0.1181 - val_false_negatives_2: 11.0000
# Epoch 21/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0327 - false_negatives_2: 40.0000
# Epoch 00021: val_loss did not improve from 0.09147
# 187/187 [==============================] - 71s 380ms/step - loss: 0.0327 - false_negatives_2: 40.0000 - val_loss: 0.1602 - val_false_negatives_2: 17.0000
# Epoch 22/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0321 - false_negatives_2: 33.0000
# Epoch 00022: val_loss did not improve from 0.09147
# 187/187 [==============================] - 70s 376ms/step - loss: 0.0321 - false_negatives_2: 33.0000 - val_loss: 0.1506 - val_false_negatives_2: 10.0000
# Epoch 23/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0324 - false_negatives_2: 29.0000
# Epoch 00023: val_loss improved from 0.09147 to 0.08842, saving model to clf-resnet50_2-weights.hdf5
# 187/187 [==============================] - 70s 377ms/step - loss: 0.0324 - false_negatives_2: 29.0000 - val_loss: 0.0884 - val_false_negatives_2: 10.0000
# Epoch 24/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0330 - false_negatives_2: 39.0000
# Epoch 00024: val_loss did not improve from 0.08842
# 187/187 [==============================] - 73s 389ms/step - loss: 0.0330 - false_negatives_2: 39.0000 - val_loss: 0.0892 - val_false_negatives_2: 10.0000
# Epoch 25/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0251 - false_negatives_2: 23.0000
# Epoch 00025: val_loss did not improve from 0.08842
# 187/187 [==============================] - 72s 384ms/step - loss: 0.0251 - false_negatives_2: 23.0000 - val_loss: 0.1328 - val_false_negatives_2: 12.0000
# Epoch 26/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0210 - false_negatives_2: 21.0000
# Epoch 00026: val_loss improved from 0.08842 to 0.07729, saving model to clf-resnet50_2-weights.hdf5
# 187/187 [==============================] - 72s 385ms/step - loss: 0.0210 - false_negatives_2: 21.0000 - val_loss: 0.0773 - val_false_negatives_2: 9.0000
# Epoch 27/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0172 - false_negatives_2: 16.0000
# Epoch 00027: val_loss did not improve from 0.07729
# 187/187 [==============================] - 72s 385ms/step - loss: 0.0172 - false_negatives_2: 16.0000 - val_loss: 0.1445 - val_false_negatives_2: 13.0000
# Epoch 28/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0200 - false_negatives_2: 23.0000
# Epoch 00028: val_loss did not improve from 0.07729
# 187/187 [==============================] - 71s 381ms/step - loss: 0.0200 - false_negatives_2: 23.0000 - val_loss: 0.0900 - val_false_negatives_2: 9.0000
# Epoch 29/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0192 - false_negatives_2: 19.0000
# Epoch 00029: val_loss did not improve from 0.07729
# 187/187 [==============================] - 71s 379ms/step - loss: 0.0192 - false_negatives_2: 19.0000 - val_loss: 0.1436 - val_false_negatives_2: 11.0000
# Epoch 30/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0243 - false_negatives_2: 24.0000
# Epoch 00030: val_loss did not improve from 0.07729
# 187/187 [==============================] - 72s 386ms/step - loss: 0.0243 - false_negatives_2: 24.0000 - val_loss: 0.1484 - val_false_negatives_2: 13.0000
# Epoch 31/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0227 - false_negatives_2: 21.0000
# Epoch 00031: val_loss did not improve from 0.07729
# 187/187 [==============================] - 74s 395ms/step - loss: 0.0227 - false_negatives_2: 21.0000 - val_loss: 0.1664 - val_false_negatives_2: 15.0000
# Epoch 32/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0173 - false_negatives_2: 16.0000
# Epoch 00032: val_loss did not improve from 0.07729
# 187/187 [==============================] - 73s 390ms/step - loss: 0.0173 - false_negatives_2: 16.0000 - val_loss: 0.0841 - val_false_negatives_2: 9.0000
# Epoch 33/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0168 - false_negatives_2: 13.0000
# Epoch 00033: val_loss did not improve from 0.07729
# 187/187 [==============================] - 71s 382ms/step - loss: 0.0168 - false_negatives_2: 13.0000 - val_loss: 0.1084 - val_false_negatives_2: 11.0000
# Epoch 34/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0165 - false_negatives_2: 18.0000
# Epoch 00034: val_loss did not improve from 0.07729
# 187/187 [==============================] - 71s 382ms/step - loss: 0.0165 - false_negatives_2: 18.0000 - val_loss: 0.1489 - val_false_negatives_2: 12.0000
# Epoch 35/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0170 - false_negatives_2: 18.0000
# Epoch 00035: val_loss did not improve from 0.07729
# 187/187 [==============================] - 72s 387ms/step - loss: 0.0170 - false_negatives_2: 18.0000 - val_loss: 0.1025 - val_false_negatives_2: 10.0000
# Epoch 36/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0164 - false_negatives_2: 16.0000
# Epoch 00036: val_loss did not improve from 0.07729
# 187/187 [==============================] - 72s 384ms/step - loss: 0.0164 - false_negatives_2: 16.0000 - val_loss: 0.1784 - val_false_negatives_2: 12.0000
# Epoch 37/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0133 - false_negatives_2: 13.0000
# Epoch 00037: val_loss did not improve from 0.07729
# 187/187 [==============================] - 72s 386ms/step - loss: 0.0133 - false_negatives_2: 13.0000 - val_loss: 0.1504 - val_false_negatives_2: 12.0000
# Epoch 38/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0138 - false_negatives_2: 15.0000
# Epoch 00038: val_loss did not improve from 0.07729
# 187/187 [==============================] - 72s 386ms/step - loss: 0.0138 - false_negatives_2: 15.0000 - val_loss: 0.1158 - val_false_negatives_2: 11.0000
# Epoch 39/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0095 - false_negatives_2: 11.0000
# Epoch 00039: val_loss did not improve from 0.07729
# 187/187 [==============================] - 72s 384ms/step - loss: 0.0095 - false_negatives_2: 11.0000 - val_loss: 0.1426 - val_false_negatives_2: 11.0000
# Epoch 40/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0086 - false_negatives_2: 9.0000
# Epoch 00040: val_loss did not improve from 0.07729
# 187/187 [==============================] - 74s 395ms/step - loss: 0.0086 - false_negatives_2: 9.0000 - val_loss: 0.1028 - val_false_negatives_2: 8.0000
# Epoch 41/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0169 - false_negatives_2: 16.0000
# Epoch 00041: val_loss did not improve from 0.07729
# 187/187 [==============================] - 72s 385ms/step - loss: 0.0169 - false_negatives_2: 16.0000 - val_loss: 0.0893 - val_false_negatives_2: 9.0000
# Epoch 00041: early stopping
# 37/37 [==============================] - 2s 56ms/step - loss: 0.0778 - false_negatives_2: 8.0000
# Test False Negatives :
# 0.9864406779661017
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       399
#            1       0.98      0.98      0.98       191
#
#     accuracy                           0.99       590
#    macro avg       0.98      0.98      0.98       590
# weighted avg       0.99      0.99      0.99       590
#
# false negative 106
# false positive 208
# false positive 210
# false negative 256
# false negative 335
# false positive 376
# false negative 477
# false positive 583

# %%
# Train resnet50_3
# run a different model using the same dataset and data split
import tensorflow.keras.applications as applications
from keras import applications
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications import ResNet101
from tensorflow.keras.applications import VGG16

clf_model = ResNet50(weights='imagenet', include_top=False, input_tensor=Input(shape=(256,256,3)))
# clf_model.summary()

for layer in clf_model.layers:
    layers.trainable = False
    
head = clf_model.output
#head = AveragePooling2D(pool_size=(2,2))(head)
head = Flatten(name='Flatten')(head)
head = Dense(256, activation='relu')(head)
head = Dropout(0.2)(head)
head = Dense(256, activation='relu')(head)
head = Dropout(0.2)(head)
head = Dense(2, activation='softmax')(head)

model = Model(clf_model.input, head)
model.compile(loss = 'categorical_crossentropy', 
              optimizer='adam', 
              metrics=[tf.keras.metrics.FalseNegatives()]
             )
# model.summary()

earlystopping = EarlyStopping(monitor='val_loss', 
                              mode='min', 
                              verbose=1, 
                              patience=15
                             )
checkpointer = ModelCheckpoint(filepath="clf-resnet50_3-weights.hdf5", 
                               verbose=1, 
                               save_best_only=True
                              )
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=10,
                              min_delta=0.0001,
                              factor=0.2
                             )
callbacks = [checkpointer, earlystopping, reduce_lr]

h = model.fit(train_generator, 
              steps_per_epoch= train_generator.n // train_generator.batch_size, 
              epochs = 50, 
              validation_data= valid_generator, 
              validation_steps= valid_generator.n // valid_generator.batch_size, 
              callbacks=[checkpointer, earlystopping])

# saving model achitecture in json file
#model_json = model.to_json()
#with open("clf-resnet50-model.json", "w") as json_file:
#    json_file.write(model_json)

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(h.history['loss']);
plt.plot(h.history['val_loss']);
plt.title("Classification Model LOSS");
plt.ylabel("loss");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

plt.subplot(1,2,2)
plt.plot(h.history['false_negatives_3']);
plt.plot(h.history['val_false_negatives_3']);
plt.title("Classification Model False Negatives");
plt.ylabel("False Negatives");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

_, false_neg = model.evaluate(test_generator)
print("Test False Negatives : ".format(false_neg))

prediction = model.predict(test_generator)

pred = np.argmax(prediction, axis=1)
#pred = np.asarray(pred).astype('str')
original = np.asarray(test['mask']).astype('int')

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
accuracy = accuracy_score(original, pred)
print(accuracy)

cm = confusion_matrix(original, pred)

report = classification_report(original, pred, labels = [0,1])
print(report)
plt.figure(figsize = (5,5))
sns.heatmap(cm, annot=True);
model.save("resnet50_3")


for i in range(len(original)):
    if original[i] == 1 and pred[i] == 0:
        print("false negative", i)
    if original[i] == 0 and pred[i] == 1:
        print("false positive", i)
# Out:
# Epoch 1/50
# 187/187 [==============================] - ETA: 0s - loss: 2.6053 - false_negatives_3: 1038.0000
# Epoch 00001: val_loss improved from inf to 0.67817, saving model to clf-resnet50_3-weights.hdf5
# 187/187 [==============================] - 76s 405ms/step - loss: 2.6053 - false_negatives_3: 1038.0000 - val_loss: 0.6782 - val_false_negatives_3: 115.0000
# Epoch 2/50
# 187/187 [==============================] - ETA: 0s - loss: 0.5054 - false_negatives_3: 731.0000
# Epoch 00002: val_loss did not improve from 0.67817
# 187/187 [==============================] - 76s 404ms/step - loss: 0.5054 - false_negatives_3: 731.0000 - val_loss: 0.9995 - val_false_negatives_3: 199.0000
# Epoch 3/50
# 187/187 [==============================] - ETA: 0s - loss: 0.4935 - false_negatives_3: 639.0000
# Epoch 00003: val_loss improved from 0.67817 to 0.62582, saving model to clf-resnet50_3-weights.hdf5
# 187/187 [==============================] - 76s 406ms/step - loss: 0.4935 - false_negatives_3: 639.0000 - val_loss: 0.6258 - val_false_negatives_3: 129.0000
# Epoch 4/50
# 187/187 [==============================] - ETA: 0s - loss: 0.5641 - false_negatives_3: 600.0000
# Epoch 00004: val_loss did not improve from 0.62582
# 187/187 [==============================] - 68s 363ms/step - loss: 0.5641 - false_negatives_3: 600.0000 - val_loss: 13.4917 - val_false_negatives_3: 119.0000
# Epoch 5/50
# 187/187 [==============================] - ETA: 0s - loss: 0.5508 - false_negatives_3: 598.0000
# Epoch 00005: val_loss did not improve from 0.62582
# 187/187 [==============================] - 73s 391ms/step - loss: 0.5508 - false_negatives_3: 598.0000 - val_loss: 0.6651 - val_false_negatives_3: 87.0000
# Epoch 6/50
# 187/187 [==============================] - ETA: 0s - loss: 0.5502 - false_negatives_3: 586.0000
# Epoch 00006: val_loss improved from 0.62582 to 0.49228, saving model to clf-resnet50_3-weights.hdf5
# 187/187 [==============================] - 69s 369ms/step - loss: 0.5502 - false_negatives_3: 586.0000 - val_loss: 0.4923 - val_false_negatives_3: 88.0000
# Epoch 7/50
# 187/187 [==============================] - ETA: 0s - loss: 0.4462 - false_negatives_3: 570.0000
# Epoch 00007: val_loss improved from 0.49228 to 0.40342, saving model to clf-resnet50_3-weights.hdf5
# 187/187 [==============================] - 78s 416ms/step - loss: 0.4462 - false_negatives_3: 570.0000 - val_loss: 0.4034 - val_false_negatives_3: 69.0000
# Epoch 8/50
# 187/187 [==============================] - ETA: 0s - loss: 0.3593 - false_negatives_3: 469.0000
# Epoch 00008: val_loss did not improve from 0.40342
# 187/187 [==============================] - 67s 358ms/step - loss: 0.3593 - false_negatives_3: 469.0000 - val_loss: 0.5434 - val_false_negatives_3: 49.0000
# Epoch 9/50
# 187/187 [==============================] - ETA: 0s - loss: 0.3763 - false_negatives_3: 433.0000
# Epoch 00009: val_loss improved from 0.40342 to 0.31728, saving model to clf-resnet50_3-weights.hdf5
# 187/187 [==============================] - 75s 403ms/step - loss: 0.3763 - false_negatives_3: 433.0000 - val_loss: 0.3173 - val_false_negatives_3: 57.0000
# Epoch 10/50
# 187/187 [==============================] - ETA: 0s - loss: 0.4088 - false_negatives_3: 424.0000
# Epoch 00010: val_loss did not improve from 0.31728
# 187/187 [==============================] - 66s 351ms/step - loss: 0.4088 - false_negatives_3: 424.0000 - val_loss: 0.3934 - val_false_negatives_3: 56.0000
# Epoch 11/50
# 187/187 [==============================] - ETA: 0s - loss: 0.4328 - false_negatives_3: 428.0000
# Epoch 00011: val_loss did not improve from 0.31728
# 187/187 [==============================] - 74s 395ms/step - loss: 0.4328 - false_negatives_3: 428.0000 - val_loss: 0.5299 - val_false_negatives_3: 51.0000
# Epoch 12/50
# 187/187 [==============================] - ETA: 0s - loss: 0.3987 - false_negatives_3: 421.0000
# Epoch 00012: val_loss did not improve from 0.31728
# 187/187 [==============================] - 66s 355ms/step - loss: 0.3987 - false_negatives_3: 421.0000 - val_loss: 0.8384 - val_false_negatives_3: 48.0000
# Epoch 13/50
# 187/187 [==============================] - ETA: 0s - loss: 0.3432 - false_negatives_3: 373.0000
# Epoch 00013: val_loss improved from 0.31728 to 0.22410, saving model to clf-resnet50_3-weights.hdf5
# 187/187 [==============================] - 74s 397ms/step - loss: 0.3432 - false_negatives_3: 373.0000 - val_loss: 0.2241 - val_false_negatives_3: 34.0000
# Epoch 14/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2757 - false_negatives_3: 304.0000
# Epoch 00014: val_loss improved from 0.22410 to 0.20459, saving model to clf-resnet50_3-weights.hdf5
# 187/187 [==============================] - 69s 369ms/step - loss: 0.2757 - false_negatives_3: 304.0000 - val_loss: 0.2046 - val_false_negatives_3: 34.0000
# Epoch 15/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2687 - false_negatives_3: 295.0000
# Epoch 00015: val_loss did not improve from 0.20459
# 187/187 [==============================] - 72s 388ms/step - loss: 0.2687 - false_negatives_3: 295.0000 - val_loss: 0.2714 - val_false_negatives_3: 40.0000
# Epoch 16/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2563 - false_negatives_3: 270.0000
# Epoch 00016: val_loss did not improve from 0.20459
# 187/187 [==============================] - 67s 356ms/step - loss: 0.2563 - false_negatives_3: 270.0000 - val_loss: 0.3747 - val_false_negatives_3: 69.0000
# Epoch 17/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2316 - false_negatives_3: 263.0000
# Epoch 00017: val_loss did not improve from 0.20459
# 187/187 [==============================] - 75s 401ms/step - loss: 0.2316 - false_negatives_3: 263.0000 - val_loss: 0.2777 - val_false_negatives_3: 27.0000
# Epoch 18/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2249 - false_negatives_3: 258.0000
# Epoch 00018: val_loss did not improve from 0.20459
# 187/187 [==============================] - 66s 352ms/step - loss: 0.2249 - false_negatives_3: 258.0000 - val_loss: 0.2438 - val_false_negatives_3: 22.0000
# Epoch 19/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2144 - false_negatives_3: 238.0000
# Epoch 00019: val_loss improved from 0.20459 to 0.16927, saving model to clf-resnet50_3-weights.hdf5
# 187/187 [==============================] - 73s 393ms/step - loss: 0.2144 - false_negatives_3: 238.0000 - val_loss: 0.1693 - val_false_negatives_3: 21.0000
# Epoch 20/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2277 - false_negatives_3: 242.0000
# Epoch 00020: val_loss did not improve from 0.16927
# 187/187 [==============================] - 65s 350ms/step - loss: 0.2277 - false_negatives_3: 242.0000 - val_loss: 0.2880 - val_false_negatives_3: 36.0000
# Epoch 21/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1993 - false_negatives_3: 233.0000
# Epoch 00021: val_loss improved from 0.16927 to 0.14942, saving model to clf-resnet50_3-weights.hdf5
# 187/187 [==============================] - 74s 396ms/step - loss: 0.1993 - false_negatives_3: 233.0000 - val_loss: 0.1494 - val_false_negatives_3: 20.0000
# Epoch 22/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2194 - false_negatives_3: 229.0000
# Epoch 00022: val_loss did not improve from 0.14942
# 187/187 [==============================] - 66s 352ms/step - loss: 0.2194 - false_negatives_3: 229.0000 - val_loss: 0.2033 - val_false_negatives_3: 23.0000
# Epoch 23/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2514 - false_negatives_3: 259.0000
# Epoch 00023: val_loss did not improve from 0.14942
# 187/187 [==============================] - 75s 402ms/step - loss: 0.2514 - false_negatives_3: 259.0000 - val_loss: 0.2362 - val_false_negatives_3: 29.0000
# Epoch 24/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2278 - false_negatives_3: 251.0000
# Epoch 00024: val_loss did not improve from 0.14942
# 187/187 [==============================] - 67s 356ms/step - loss: 0.2278 - false_negatives_3: 251.0000 - val_loss: 0.2045 - val_false_negatives_3: 24.0000
# Epoch 25/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2070 - false_negatives_3: 216.0000
# Epoch 00025: val_loss did not improve from 0.14942
# 187/187 [==============================] - 75s 399ms/step - loss: 0.2070 - false_negatives_3: 216.0000 - val_loss: 0.2009 - val_false_negatives_3: 23.0000
# Epoch 26/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1996 - false_negatives_3: 219.0000
# Epoch 00026: val_loss did not improve from 0.14942
# 187/187 [==============================] - 73s 390ms/step - loss: 0.1996 - false_negatives_3: 219.0000 - val_loss: 0.3316 - val_false_negatives_3: 36.0000
# Epoch 27/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2883 - false_negatives_3: 289.0000
# Epoch 00027: val_loss did not improve from 0.14942
# 187/187 [==============================] - 67s 358ms/step - loss: 0.2883 - false_negatives_3: 289.0000 - val_loss: 0.3308 - val_false_negatives_3: 34.0000
# Epoch 28/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2081 - false_negatives_3: 227.0000
# Epoch 00028: val_loss did not improve from 0.14942
# 187/187 [==============================] - 75s 404ms/step - loss: 0.2081 - false_negatives_3: 227.0000 - val_loss: 0.2097 - val_false_negatives_3: 16.0000
# Epoch 29/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1963 - false_negatives_3: 213.0000
# Epoch 00029: val_loss did not improve from 0.14942
# 187/187 [==============================] - 66s 354ms/step - loss: 0.1963 - false_negatives_3: 213.0000 - val_loss: 0.1634 - val_false_negatives_3: 21.0000
# Epoch 30/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1709 - false_negatives_3: 198.0000
# Epoch 00030: val_loss did not improve from 0.14942
# 187/187 [==============================] - 74s 393ms/step - loss: 0.1709 - false_negatives_3: 198.0000 - val_loss: 0.2132 - val_false_negatives_3: 20.0000
# Epoch 31/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2254 - false_negatives_3: 233.0000
# Epoch 00031: val_loss did not improve from 0.14942
# 187/187 [==============================] - 66s 351ms/step - loss: 0.2254 - false_negatives_3: 233.0000 - val_loss: 0.2388 - val_false_negatives_3: 32.0000
# Epoch 32/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1982 - false_negatives_3: 200.0000
# Epoch 00032: val_loss improved from 0.14942 to 0.13242, saving model to clf-resnet50_3-weights.hdf5
# 187/187 [==============================] - 77s 414ms/step - loss: 0.1982 - false_negatives_3: 200.0000 - val_loss: 0.1324 - val_false_negatives_3: 17.0000
# Epoch 33/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1674 - false_negatives_3: 184.0000
# Epoch 00033: val_loss did not improve from 0.13242
# 187/187 [==============================] - 67s 357ms/step - loss: 0.1674 - false_negatives_3: 184.0000 - val_loss: 0.1711 - val_false_negatives_3: 24.0000
# Epoch 34/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1944 - false_negatives_3: 211.0000
# Epoch 00034: val_loss did not improve from 0.13242
# 187/187 [==============================] - 76s 408ms/step - loss: 0.1944 - false_negatives_3: 211.0000 - val_loss: 0.3237 - val_false_negatives_3: 24.0000
# Epoch 35/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1704 - false_negatives_3: 173.0000
# Epoch 00035: val_loss did not improve from 0.13242
# 187/187 [==============================] - 66s 350ms/step - loss: 0.1704 - false_negatives_3: 173.0000 - val_loss: 0.3333 - val_false_negatives_3: 28.0000
# Epoch 36/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1707 - false_negatives_3: 169.0000
# Epoch 00036: val_loss did not improve from 0.13242
# 187/187 [==============================] - 76s 408ms/step - loss: 0.1707 - false_negatives_3: 169.0000 - val_loss: 0.4451 - val_false_negatives_3: 39.0000
# Epoch 37/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1540 - false_negatives_3: 163.0000
# Epoch 00037: val_loss did not improve from 0.13242
# 187/187 [==============================] - 67s 357ms/step - loss: 0.1540 - false_negatives_3: 163.0000 - val_loss: 0.1490 - val_false_negatives_3: 20.0000
# Epoch 38/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1454 - false_negatives_3: 151.0000
# Epoch 00038: val_loss did not improve from 0.13242
# 187/187 [==============================] - 70s 374ms/step - loss: 0.1454 - false_negatives_3: 151.0000 - val_loss: 0.1622 - val_false_negatives_3: 18.0000
# Epoch 39/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1505 - false_negatives_3: 155.0000
# Epoch 00039: val_loss did not improve from 0.13242
# 187/187 [==============================] - 62s 331ms/step - loss: 0.1505 - false_negatives_3: 155.0000 - val_loss: 0.1613 - val_false_negatives_3: 13.0000
# Epoch 40/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1504 - false_negatives_3: 151.0000
# Epoch 00040: val_loss did not improve from 0.13242
# 187/187 [==============================] - 68s 362ms/step - loss: 0.1504 - false_negatives_3: 151.0000 - val_loss: 0.2626 - val_false_negatives_3: 28.0000
# Epoch 41/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1704 - false_negatives_3: 160.0000
# Epoch 00041: val_loss did not improve from 0.13242
# 187/187 [==============================] - 61s 325ms/step - loss: 0.1704 - false_negatives_3: 160.0000 - val_loss: 0.2661 - val_false_negatives_3: 30.0000
# Epoch 42/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2256 - false_negatives_3: 227.0000
# Epoch 00042: val_loss did not improve from 0.13242
# 187/187 [==============================] - 67s 358ms/step - loss: 0.2256 - false_negatives_3: 227.0000 - val_loss: 0.2585 - val_false_negatives_3: 22.0000
# Epoch 43/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2194 - false_negatives_3: 190.0000
# Epoch 00043: val_loss did not improve from 0.13242
# 187/187 [==============================] - 59s 317ms/step - loss: 0.2194 - false_negatives_3: 190.0000 - val_loss: 0.4244 - val_false_negatives_3: 41.0000
# Epoch 44/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1751 - false_negatives_3: 181.0000
# Epoch 00044: val_loss did not improve from 0.13242
# 187/187 [==============================] - 59s 316ms/step - loss: 0.1751 - false_negatives_3: 181.0000 - val_loss: 0.1539 - val_false_negatives_3: 14.0000
# Epoch 45/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1438 - false_negatives_3: 153.0000
# Epoch 00045: val_loss did not improve from 0.13242
# 187/187 [==============================] - 66s 351ms/step - loss: 0.1438 - false_negatives_3: 153.0000 - val_loss: 0.3916 - val_false_negatives_3: 43.0000
# Epoch 46/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1722 - false_negatives_3: 164.0000
# Epoch 00046: val_loss did not improve from 0.13242
# 187/187 [==============================] - 60s 318ms/step - loss: 0.1722 - false_negatives_3: 164.0000 - val_loss: 0.5048 - val_false_negatives_3: 50.0000
# Epoch 47/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1501 - false_negatives_3: 164.0000
# Epoch 00047: val_loss did not improve from 0.13242
# 187/187 [==============================] - 65s 350ms/step - loss: 0.1501 - false_negatives_3: 164.0000 - val_loss: 0.1561 - val_false_negatives_3: 24.0000
# Epoch 00047: early stopping
# 37/37 [==============================] - 2s 47ms/step - loss: 0.1174 - false_negatives_3: 33.0000
# Test False Negatives :
# 0.9440677966101695
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       399
#            1       0.92      0.91      0.91       191
#
#     accuracy                           0.94       590
#    macro avg       0.94      0.94      0.94       590
# weighted avg       0.94      0.94      0.94       590
#
# false negative 27
# false positive 71
# false negative 131
# false positive 157
# false negative 174
# false positive 181
# false negative 202
# false positive 210
# false positive 224
# false positive 239
# false negative 251
# false negative 255
# false negative 256
# false positive 269
# false positive 282
# false positive 314
# false negative 333
# false negative 335
# false positive 337
# false negative 344
# false positive 349
# false negative 374
# false positive 376
# false negative 407
# false negative 409
# false positive 414
# false negative 447
# false negative 451
# false positive 453
# false negative 477
# false positive 536
# false negative 555
# false positive 583

# %%
# Train resnet101_2
# run a different model using the same dataset and data split
import tensorflow.keras.applications as applications
from keras import applications
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications import ResNet101
from tensorflow.keras.applications import VGG16

clf_model = ResNet101(weights='imagenet', include_top=False, input_tensor=Input(shape=(256,256,3)))
# clf_model.summary()

for layer in clf_model.layers:
    layers.trainable = False

head = clf_model.output
#head = AveragePooling2D(pool_size=(4,4))(head)
head = Flatten(name='Flatten')(head)
head = Dense(256, activation='relu')(head)
head = Dropout(0.3)(head)
head = Dense(128, activation='relu')(head)
head = Dropout(0.2)(head)
head = Dense(2, activation='softmax')(head)

model = Model(clf_model.input, head)
model.compile(loss = 'categorical_crossentropy', 
              optimizer='adagrad', 
              metrics=[tf.keras.metrics.FalseNegatives()]
             )
# model.summary()

earlystopping = EarlyStopping(monitor='val_loss', 
                              mode='min', 
                              verbose=1, 
                              patience=15
                             )
checkpointer = ModelCheckpoint(filepath="clf-resnet101_2-weights.hdf5", 
                               verbose=1, 
                               save_best_only=True
                              )
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=10,
                              min_delta=0.0001,
                              factor=0.2
                             )
callbacks = [checkpointer, earlystopping, reduce_lr]

h = model.fit(train_generator, 
              steps_per_epoch= train_generator.n // train_generator.batch_size, 
              epochs = 50, 
              validation_data= valid_generator, 
              validation_steps= valid_generator.n // valid_generator.batch_size, 
              callbacks=[checkpointer, earlystopping])

# saving model achitecture in json file
#model_json = model.to_json()
#with open("clf-resnet101_2-model.json", "w") as json_file:
#    json_file.write(model_json)

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(h.history['loss']);
plt.plot(h.history['val_loss']);
plt.title("Classification Model LOSS");
plt.ylabel("loss");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

plt.subplot(1,2,2)
plt.plot(h.history['false_negatives_4']);
plt.plot(h.history['val_false_negatives_4']);
plt.title("Classification Model False Negatives");
plt.ylabel("False Negatives");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

_, false_neg = model.evaluate(test_generator)
print("Test False Negatives : ".format(false_neg))

prediction = model.predict(test_generator)

pred = np.argmax(prediction, axis=1)
#pred = np.asarray(pred).astype('str')
original = np.asarray(test['mask']).astype('int')

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
accuracy = accuracy_score(original, pred)
print(accuracy)

cm = confusion_matrix(original, pred)

report = classification_report(original, pred, labels = [0,1])
print(report)
plt.figure(figsize = (5,5))
sns.heatmap(cm, annot=True);
model.save("resnet101_2")

for i in range(len(original)):
    if original[i] == 1 and pred[i] == 0:
        print("false negative", i)
    if original[i] == 0 and pred[i] == 1:
        print("false positive", i)
# Out:
# Epoch 1/50
# 187/187 [==============================] - ETA: 0s - loss: 0.6262 - false_negatives_4: 729.0000
# Epoch 00001: val_loss improved from inf to 2.07082, saving model to clf-resnet101_2-weights.hdf5
# 187/187 [==============================] - 71s 379ms/step - loss: 0.6262 - false_negatives_4: 729.0000 - val_loss: 2.0708 - val_false_negatives_4: 118.0000
# Epoch 2/50
# 187/187 [==============================] - ETA: 0s - loss: 0.3187 - false_negatives_4: 432.0000
# Epoch 00002: val_loss improved from 2.07082 to 1.65615, saving model to clf-resnet101_2-weights.hdf5
# 187/187 [==============================] - 76s 405ms/step - loss: 0.3187 - false_negatives_4: 432.0000 - val_loss: 1.6561 - val_false_negatives_4: 117.0000
# Epoch 3/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2324 - false_negatives_4: 270.0000
# Epoch 00003: val_loss improved from 1.65615 to 1.32772, saving model to clf-resnet101_2-weights.hdf5
# 187/187 [==============================] - 68s 364ms/step - loss: 0.2324 - false_negatives_4: 270.0000 - val_loss: 1.3277 - val_false_negatives_4: 117.0000
# Epoch 4/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1850 - false_negatives_4: 220.0000
# Epoch 00004: val_loss improved from 1.32772 to 0.43954, saving model to clf-resnet101_2-weights.hdf5
# 187/187 [==============================] - 73s 393ms/step - loss: 0.1850 - false_negatives_4: 220.0000 - val_loss: 0.4395 - val_false_negatives_4: 56.0000
# Epoch 5/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1448 - false_negatives_4: 154.0000
# Epoch 00005: val_loss improved from 0.43954 to 0.23881, saving model to clf-resnet101_2-weights.hdf5
# 187/187 [==============================] - 68s 365ms/step - loss: 0.1448 - false_negatives_4: 154.0000 - val_loss: 0.2388 - val_false_negatives_4: 34.0000
# Epoch 6/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1232 - false_negatives_4: 134.0000
# Epoch 00006: val_loss improved from 0.23881 to 0.14580, saving model to clf-resnet101_2-weights.hdf5
# 187/187 [==============================] - 73s 390ms/step - loss: 0.1232 - false_negatives_4: 134.0000 - val_loss: 0.1458 - val_false_negatives_4: 16.0000
# Epoch 7/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1092 - false_negatives_4: 118.0000
# Epoch 00007: val_loss improved from 0.14580 to 0.11633, saving model to clf-resnet101_2-weights.hdf5
# 187/187 [==============================] - 67s 358ms/step - loss: 0.1092 - false_negatives_4: 118.0000 - val_loss: 0.1163 - val_false_negatives_4: 10.0000
# Epoch 8/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0904 - false_negatives_4: 107.0000
# Epoch 00008: val_loss did not improve from 0.11633
# 187/187 [==============================] - 71s 381ms/step - loss: 0.0904 - false_negatives_4: 107.0000 - val_loss: 0.1498 - val_false_negatives_4: 15.0000
# Epoch 9/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0870 - false_negatives_4: 94.0000
# Epoch 00009: val_loss improved from 0.11633 to 0.09353, saving model to clf-resnet101_2-weights.hdf5
# 187/187 [==============================] - 67s 358ms/step - loss: 0.0870 - false_negatives_4: 94.0000 - val_loss: 0.0935 - val_false_negatives_4: 9.0000
# Epoch 10/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0757 - false_negatives_4: 77.0000
# Epoch 00010: val_loss improved from 0.09353 to 0.07424, saving model to clf-resnet101_2-weights.hdf5
# 187/187 [==============================] - 74s 394ms/step - loss: 0.0757 - false_negatives_4: 77.0000 - val_loss: 0.0742 - val_false_negatives_4: 6.0000
# Epoch 11/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0630 - false_negatives_4: 68.0000
# Epoch 00011: val_loss did not improve from 0.07424
# 187/187 [==============================] - 66s 352ms/step - loss: 0.0630 - false_negatives_4: 68.0000 - val_loss: 0.1118 - val_false_negatives_4: 14.0000
# Epoch 12/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0582 - false_negatives_4: 64.0000
# Epoch 00012: val_loss did not improve from 0.07424
# 187/187 [==============================] - 76s 404ms/step - loss: 0.0582 - false_negatives_4: 64.0000 - val_loss: 0.1562 - val_false_negatives_4: 17.0000
# Epoch 13/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0486 - false_negatives_4: 50.0000
# Epoch 00013: val_loss did not improve from 0.07424
# 187/187 [==============================] - 68s 363ms/step - loss: 0.0486 - false_negatives_4: 50.0000 - val_loss: 0.1314 - val_false_negatives_4: 9.0000
# Epoch 14/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0426 - false_negatives_4: 48.0000
# Epoch 00014: val_loss did not improve from 0.07424
# 187/187 [==============================] - 73s 389ms/step - loss: 0.0426 - false_negatives_4: 48.0000 - val_loss: 0.1888 - val_false_negatives_4: 15.0000
# Epoch 15/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0441 - false_negatives_4: 45.0000
# Epoch 00015: val_loss did not improve from 0.07424
# 187/187 [==============================] - 66s 352ms/step - loss: 0.0441 - false_negatives_4: 45.0000 - val_loss: 0.1269 - val_false_negatives_4: 14.0000
# Epoch 16/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0417 - false_negatives_4: 45.0000
# Epoch 00016: val_loss did not improve from 0.07424
# 187/187 [==============================] - 76s 406ms/step - loss: 0.0417 - false_negatives_4: 45.0000 - val_loss: 0.1140 - val_false_negatives_4: 8.0000
# Epoch 17/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0381 - false_negatives_4: 36.0000
# Epoch 00017: val_loss did not improve from 0.07424
# 187/187 [==============================] - 68s 362ms/step - loss: 0.0381 - false_negatives_4: 36.0000 - val_loss: 0.1800 - val_false_negatives_4: 12.0000
# Epoch 18/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0441 - false_negatives_4: 47.0000
# Epoch 00018: val_loss did not improve from 0.07424
# 187/187 [==============================] - 73s 391ms/step - loss: 0.0441 - false_negatives_4: 47.0000 - val_loss: 0.1244 - val_false_negatives_4: 8.0000
# Epoch 19/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0307 - false_negatives_4: 35.0000
# Epoch 00019: val_loss did not improve from 0.07424
# 187/187 [==============================] - 66s 352ms/step - loss: 0.0307 - false_negatives_4: 35.0000 - val_loss: 0.1682 - val_false_negatives_4: 13.0000
# Epoch 20/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0329 - false_negatives_4: 33.0000
# Epoch 00020: val_loss did not improve from 0.07424
# 187/187 [==============================] - 73s 388ms/step - loss: 0.0329 - false_negatives_4: 33.0000 - val_loss: 0.1039 - val_false_negatives_4: 10.0000
# Epoch 21/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0379 - false_negatives_4: 36.0000
# Epoch 00021: val_loss did not improve from 0.07424
# 187/187 [==============================] - 66s 353ms/step - loss: 0.0379 - false_negatives_4: 36.0000 - val_loss: 0.1497 - val_false_negatives_4: 12.0000
# Epoch 22/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0310 - false_negatives_4: 35.0000
# Epoch 00022: val_loss did not improve from 0.07424
# 187/187 [==============================] - 72s 387ms/step - loss: 0.0310 - false_negatives_4: 35.0000 - val_loss: 0.0928 - val_false_negatives_4: 8.0000
# Epoch 23/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0257 - false_negatives_4: 28.0000
# Epoch 00023: val_loss did not improve from 0.07424
# 187/187 [==============================] - 66s 354ms/step - loss: 0.0257 - false_negatives_4: 28.0000 - val_loss: 0.1514 - val_false_negatives_4: 13.0000
# Epoch 24/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0230 - false_negatives_4: 29.0000
# Epoch 00024: val_loss did not improve from 0.07424
# 187/187 [==============================] - 74s 394ms/step - loss: 0.0230 - false_negatives_4: 29.0000 - val_loss: 0.1754 - val_false_negatives_4: 12.0000
# Epoch 25/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0220 - false_negatives_4: 25.0000
# Epoch 00025: val_loss did not improve from 0.07424
# 187/187 [==============================] - 66s 355ms/step - loss: 0.0220 - false_negatives_4: 25.0000 - val_loss: 0.1524 - val_false_negatives_4: 15.0000
# Epoch 00025: early stopping
# 37/37 [==============================] - 3s 75ms/step - loss: 0.1384 - false_negatives_4: 21.0000
# Test False Negatives :
# 0.964406779661017
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       399
#            1       0.95      0.94      0.94       191
#
#     accuracy                           0.96       590
#    macro avg       0.96      0.96      0.96       590
# weighted avg       0.96      0.96      0.96       590
#
# false negative 27
# false negative 65
# false positive 71
# false positive 127
# false positive 210
# false positive 246
# false negative 255
# false negative 256
# false positive 310
# false negative 321
# false negative 335
# false positive 337
# false negative 344
# false positive 373
# false positive 425
# false negative 451
# false negative 477
# false negative 486
# false negative 499
# false positive 535
# false positive 583
