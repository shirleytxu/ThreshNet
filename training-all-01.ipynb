# %% [markdown]
# # 1: IMPORTING LIBRARIES AND DATASET

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import zipfile
import cv2
from skimage import io

import tensorflow as tf
from tensorflow.python.keras import Sequential
from tensorflow.keras import layers, optimizers
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
import tensorflow.keras.backend as K

import random
import glob
from sklearn.preprocessing import StandardScaler, normalize
from IPython.display import display

# %%
data = pd.read_csv('../input/lgg-mri-segmentation/kaggle_3m/data.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Patient                    110 non-null    object
#  1   RNASeqCluster              92 non-null     float64
#  2   MethylationCluster         109 non-null    float64
#  3   miRNACluster               110 non-null    int64
#  4   CNCluster                  108 non-null    float64
#  5   RPPACluster                98 non-null     float64
#  6   OncosignCluster            105 non-null    float64
#  7   COCCluster                 110 non-null    int64
#  8   histological_type          109 non-null    float64
#  9   neoplasm_histologic_grade  109 non-null    float64
#  10  tumor_tissue_site          109 non-null    float64
#  11  laterality                 109 non-null    float64
#  12  tumor_location             109 non-null    float64
#  13  gender                     109 non-null    float64
#  14  age_at_initial_pathologic  109 non-null    float64
#  15  race                       108 non-null    float64
#  16  ethnicity                  102 non-null    float64
#  17  death01                    109 non-null    float64
# dtypes: float64(15), int64(2), object(1)
# memory usage: 15.6+ KB

# %%
data.head(10)
# Out:
#         Patient  RNASeqCluster  MethylationCluster  miRNACluster  CNCluster  \
# 0  TCGA_CS_4941            2.0                 4.0             2        2.0
# 1  TCGA_CS_4942            1.0                 5.0             2        1.0
# 2  TCGA_CS_4943            1.0                 5.0             2        1.0
# 3  TCGA_CS_4944            NaN                 5.0             2        1.0
# 4  TCGA_CS_5393            4.0                 5.0             2        1.0
# 5  TCGA_CS_5395            2.0                 4.0             2        2.0
# 6  TCGA_CS_5396            3.0                 3.0             2        3.0
# 7  TCGA_CS_5397            NaN                 4.0             1        2.0
# 8  TCGA_CS_6186            2.0                 4.0             1        2.0
# 9  TCGA_CS_6188            2.0                 4.0             3        2.0
#
#    RPPACluster  OncosignCluster  COCCluster  histological_type  \
# 0          NaN              3.0           2                1.0
# 1          1.0              2.0           1                1.0
# 2          2.0              2.0           1                1.0
# 3          2.0              1.0           1                1.0
# 4          2.0              3.0           1                1.0
# 5          NaN              3.0           2                3.0
# 6          2.0              2.0           3                3.0
# 7          3.0              3.0           2                1.0
# 8          1.0              3.0           2                2.0
# 9          3.0              3.0           2                1.0
#
#    neoplasm_histologic_grade  tumor_tissue_site  laterality  tumor_location  \
# 0                        2.0                1.0         3.0             2.0
# 1                        2.0                1.0         3.0             2.0
# 2                        2.0                1.0         1.0             2.0
# 3                        1.0                1.0         3.0             6.0
# 4                        2.0                1.0         1.0             6.0
# 5                        1.0                1.0         3.0             5.0
# 6                        2.0                1.0         3.0             2.0
# 7                        2.0                1.0         1.0             6.0
# 8                        2.0                1.0         3.0             2.0
# 9                        2.0                1.0         3.0             6.0
#
#    gender  age_at_initial_pathologic  race  ethnicity  death01
# 0     2.0                       67.0   3.0        2.0      1.0
# 1     1.0                       44.0   2.0        NaN      1.0
# 2     2.0                       37.0   3.0        NaN      0.0
# 3     2.0                       50.0   3.0        NaN      0.0
# 4     2.0                       39.0   3.0        NaN      0.0
# 5     2.0                       43.0   2.0        NaN      1.0
# 6     1.0                       53.0   3.0        2.0      0.0
# 7     1.0                       54.0   3.0        2.0      1.0
# 8     2.0                       58.0   3.0        2.0      1.0
# 9     2.0                       48.0   3.0        2.0      0.0

# %%
data_map = []
for sub_dir_path in glob.glob("/kaggle/input/lgg-mri-segmentation/kaggle_3m/"+"*"):
    #if os.path.isdir(sub_path_dir):
    try:
        dir_name = sub_dir_path.split('/')[-1]
        for filename in os.listdir(sub_dir_path):
            image_path = sub_dir_path + '/' + filename
            data_map.extend([dir_name, image_path])
    except Exception as e:
        print(e)
# Out:
# [Errno 20] Not a directory: '/kaggle/input/lgg-mri-segmentation/kaggle_3m/README.md'
# [Errno 20] Not a directory: '/kaggle/input/lgg-mri-segmentation/kaggle_3m/data.csv'

# %%
df = pd.DataFrame({"patient_id" : data_map[::2],
                   "path" : data_map[1::2]})
df.head()
# Out:
#               patient_id                                               path
# 0  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...

# %%
df_imgs = df[~df['path'].str.contains("mask")]
df_masks = df[df['path'].str.contains("mask")]

# File path line length images for later sorting
BASE_LEN = 89 # len(/kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_6404_19850629/TCGA_DU_6404_19850629_ <-!!!43.tif)
END_IMG_LEN = 4 # len(/kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_6404_19850629/TCGA_DU_6404_19850629_43 !!!->.tif)
END_MASK_LEN = 9 # (/kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_6404_19850629/TCGA_DU_6404_19850629_43 !!!->_mask.tif)

# Data sorting
imgs = sorted(df_imgs["path"].values, key=lambda x : int(x[BASE_LEN:-END_IMG_LEN]))
masks = sorted(df_masks["path"].values, key=lambda x : int(x[BASE_LEN:-END_MASK_LEN]))

# Sorting check
idx = random.randint(0, len(imgs)-1)
print("Path to the Image:", imgs[idx], "\nPath to the Mask:", masks[idx])
# Out:
# Path to the Image: /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_CS_5397_20010315/TCGA_CS_5397_20010315_15.tif
# Path to the Mask: /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_CS_5397_20010315/TCGA_CS_5397_20010315_15_mask.tif

# %% [markdown]
# ### creating final datset

# %%
# Final dataframe
brain_df = pd.DataFrame({"patient_id": df_imgs.patient_id.values,
                         "image_path": imgs,
                         "mask_path": masks
                        })
def pos_neg_diagnosis(mask_path):
    value = np.max(cv2.imread(mask_path))
    if value > 0 : 
        return 1
    else:
        return 0
    
brain_df['mask'] = brain_df['mask_path'].apply(lambda x: pos_neg_diagnosis(x))
brain_df
# Out:
#                  patient_id  \
# 0     TCGA_DU_7010_19860307
# 1     TCGA_DU_7010_19860307
# 2     TCGA_DU_7010_19860307
# 3     TCGA_DU_7010_19860307
# 4     TCGA_DU_7010_19860307
# ...                     ...
# 3924  TCGA_DU_7306_19930512
# 3925  TCGA_DU_7306_19930512
# 3926  TCGA_DU_7306_19930512
# 3927  TCGA_DU_7306_19930512
# 3928  TCGA_DU_7306_19930512
#
#                                              image_path  \
# 0     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# ...                                                 ...
# 3924  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3925  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3926  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3927  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3928  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                               mask_path  mask
# 0     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 1     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 2     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 4     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# ...                                                 ...   ...
# 3924  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3925  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3926  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3927  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3928  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
#
# [3929 rows x 4 columns]

# %% [markdown]
# # 2: DATA VISUALIZATION

# %%
brain_df['mask'].value_counts()
# Out:
# 0    2556
# 1    1373
# Name: mask, dtype: int64

# %%
import plotly.graph_objects as go  # using plotly to create interactive plots

fig = go.Figure([go.Bar(x=brain_df['mask'].value_counts().index, 
                        y=brain_df['mask'].value_counts(), 
                        width=[.4, .4]
                       )
                ])
fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)',
                  marker_line_width=4, opacity=0.4
                 )
fig.update_layout(title_text="Mask Count Plot",
                  width=700,
                  height=550,
                  yaxis=dict(
                             title_text="Count",
                             tickmode="array",
                             titlefont=dict(size=20)
                           )
                 )
fig.update_yaxes(automargin=True)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="2d565500-d8d6-4fd2-82d6-de25bb7137f2" class="plotly-graph-div" style="height:550px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2d565500-d8d6-4fd2-82d6-de25bb7137f2")) {                    Plotly.newPlot(                        "2d565500-d8d6-4fd2-82d6-de25bb7137f2",                        [{"marker": {"color": "rgb(158,202,225)", "line": {"color": "rgb(8,48,107)", "width": 4}}, "opacity": 0.4, "type": "bar", "width": [0.4, 0.4], "x": [0, 1], "y": [2556, 1373]}],                        {"height": 550, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"co ...

# %%
for i in range(len(brain_df)):
    if cv2.imread(brain_df.mask_path[i]).max() > 0:
        break

plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.imshow(cv2.imread(brain_df.mask_path[i]));
plt.title('Tumor Location')

plt.subplot(1,2,2)
plt.imshow(cv2.imread(brain_df.image_path[i]));

# %%
cv2.imread(brain_df.mask_path[i]).max(), cv2.imread(brain_df.mask_path[i]).min()
# Out:
# (255, 0)

# %%
# Basic visualizations: Visualize the images (MRI and Mask) in the dataset separately 

fig, axs = plt.subplots(6,2, figsize=(16,26))
count = 0
for x in range(6):
  i = random.randint(0, len(brain_df)) # select a random index
  axs[count][0].title.set_text("Brain MRI") # set title
  axs[count][0].imshow(cv2.imread(brain_df.image_path[i])) # show MRI 
  axs[count][1].title.set_text("Mask - " + str(brain_df['mask'][i])) # plot title on the mask (0 or 1)
  axs[count][1].imshow(cv2.imread(brain_df.mask_path[i])) # Show corresponding mask
  count += 1

fig.tight_layout()

# %%
count = 0
i = 0
fig,axs = plt.subplots(12,3, figsize=(20,50))
for mask in brain_df['mask']:
    if (mask==1):
        img = io.imread(brain_df.image_path[i])
        axs[count][0].title.set_text("Brain MRI")
        axs[count][0].imshow(img)
        
        mask = io.imread(brain_df.mask_path[i])
        axs[count][1].title.set_text("Mask")
        axs[count][1].imshow(mask, cmap='gray')
        
        img[mask==255] = (0,255,150)  # change pixel color at the position of mask
        axs[count][2].title.set_text("MRI with Mask")
        axs[count][2].imshow(img)
        count +=1
    i += 1
    if (count==12):
        break
        
fig.tight_layout()

# %% [markdown]
# # 5: CRETING TEST, TRAIN & VAL SET

# %%
brain_df_train = brain_df.drop(columns=['patient_id'])
# Convert the data in mask column to string format, to use categorical mode in flow_from_dataframe
brain_df_train['mask'] = brain_df_train['mask'].apply(lambda x: str(x))
brain_df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3929 entries, 0 to 3928
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   image_path  3929 non-null   object
#  1   mask_path   3929 non-null   object
#  2   mask        3929 non-null   object
# dtypes: object(3)
# memory usage: 92.2+ KB

# %%
from sklearn.model_selection import train_test_split
SEED = 123456
import os
import random as rn
import numpy as np

os.environ['PYTHONHASHSEED']=str(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
rn.seed(SEED)

train, test = train_test_split(brain_df_train, test_size=0.15, random_state = 123456)

# %%
from keras_preprocessing.image import ImageDataGenerator

#datagen = ImageDataGenerator(rescale=1./255., validation_split=0.1)
datagen = ImageDataGenerator(rescale=1./255., validation_split=0.1, rotation_range = 15, horizontal_flip = True, vertical_flip = True)

train_generator = datagen.flow_from_dataframe(train,
                                              directory='./',
                                              x_col='image_path',
                                              y_col='mask',
                                              subset='training',
                                              class_mode='categorical',
                                              batch_size=16,
                                              shuffle=True,
                                              target_size=(256,256)
                                             )
valid_generator = datagen.flow_from_dataframe(train,
                                              directory='./',
                                              x_col='image_path',
                                              y_col='mask',
                                              subset='validation',
                                              class_mode='categorical',
                                              batch_size=16,
                                              shuffle=True,
                                              target_size=(256,256)
                                             )
test_datagen = ImageDataGenerator(rescale=1./255.)
test_generator = test_datagen.flow_from_dataframe(test,
                                                  directory='./',
                                                  x_col='image_path',
                                                  y_col='mask',
                                                  class_mode='categorical',
                                                  batch_size=16,
                                                  shuffle=False,
                                                  target_size=(256,256)
                                                 )
# Out:
# Found 3006 validated image filenames belonging to 2 classes.
# Found 333 validated image filenames belonging to 2 classes.
# Found 590 validated image filenames belonging to 2 classes.

# %% [markdown]
# # 6: TRAIN A CLASSIFIER MODEL TO DETECT IF TUMOR EXISTS OR NOT

# %% [markdown]
# # 7: CLASSIFIACTION MODEL EVALUATION

# %%
# Train ResNet152
# run a different model using the same dataset and data split
import numpy as np
import keras
from keras import backend as K
from keras.layers.core import Dense, Activation
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator 
from keras.preprocessing import image
from keras.models import Model
from keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt 

import tensorflow.keras.applications as applications
from keras import applications
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications import ResNet152


clf_model = ResNet152(weights='imagenet', include_top=False, input_tensor=Input(shape=(256,256,3)))
# clf_model.summary()

for layer in clf_model.layers:
    layers.trainable = False
    
head = clf_model.output
head = AveragePooling2D(pool_size=(4,4))(head)
head = Flatten(name='Flatten')(head)
head = Dense(256, activation='relu')(head)
head = Dropout(0.1)(head)
head = Dense(256, activation='relu')(head)
head = Dropout(0.1)(head)
head = Dense(256, activation='relu')(head)
head = Dropout(0.1)(head)
head = Dense(2, activation='softmax')(head)

model = Model(clf_model.input, head)
model.compile(loss = 'categorical_crossentropy', 
              optimizer='adam', 
              metrics= ["accuracy"]
             )
# model.summary()

earlystopping = EarlyStopping(monitor='val_loss', 
                              mode='min', 
                              verbose=1, 
                              patience=15
                             )
checkpointer = ModelCheckpoint(filepath="clf-ResNet152-weights.hdf5", 
                               verbose=1, 
                               save_best_only=True
                              )
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=10,
                              min_delta=0.0001,
                              factor=0.2
                             )
callbacks = [checkpointer, earlystopping, reduce_lr]

h = model.fit(train_generator, 
              steps_per_epoch= train_generator.n // train_generator.batch_size, 
              epochs = 50, 
              validation_data= valid_generator, 
              validation_steps= valid_generator.n // valid_generator.batch_size, 
              callbacks=[checkpointer, earlystopping])

# saving model achitecture in json file
# model_json = model.to_json()
# with open("clf-resnet50-model.json", "w") as json_file:
#    json_file.write(model_json)

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(h.history['loss']);
plt.plot(h.history['val_loss']);
plt.title("Classification Model LOSS");
plt.ylabel("loss");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

plt.subplot(1,2,2)
plt.plot(h.history['accuracy']);
plt.plot(h.history['val_accuracy']);
plt.title("Classification Model Acc");
plt.ylabel("Accuracy");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

_, acc = model.evaluate(test_generator)
print("Test accuracy : {} %".format(acc*100))

prediction = model.predict(test_generator)

pred = np.argmax(prediction, axis=1)
#pred = np.asarray(pred).astype('str')
original = np.asarray(test['mask']).astype('int')

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
accuracy = accuracy_score(original, pred)
print(accuracy)

cm = confusion_matrix(original, pred)

report = classification_report(original, pred, labels = [0,1])
print(report)
plt.figure(figsize = (5,5))
sns.heatmap(cm, annot=True);
model.save("ResNet152")

for i in range(len(original)):
    if original[i] == 1 and pred[i] == 0:
        print("false negative", i)
    if original[i] == 0 and pred[i] == 1:
        print("false positive", i)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234700800/234698864 [==============================] - 5s 0us/step
# Epoch 1/50
# 187/187 [==============================] - ETA: 0s - loss: 0.6429 - accuracy: 0.6866
# Epoch 00001: val_loss improved from inf to 268.35330, saving model to clf-ResNet152-weights.hdf5
# 187/187 [==============================] - 98s 527ms/step - loss: 0.6429 - accuracy: 0.6866 - val_loss: 268.3533 - val_accuracy: 0.6344
# Epoch 2/50
# 187/187 [==============================] - ETA: 0s - loss: 0.5244 - accuracy: 0.7227
# Epoch 00002: val_loss improved from 268.35330 to 0.87020, saving model to clf-ResNet152-weights.hdf5
# 187/187 [==============================] - 79s 420ms/step - loss: 0.5244 - accuracy: 0.7227 - val_loss: 0.8702 - val_accuracy: 0.3719
# Epoch 3/50
# 187/187 [==============================] - ETA: 0s - loss: 0.4834 - accuracy: 0.7395
# Epoch 00003: val_loss did not improve from 0.87020
# 187/187 [==============================] - 74s 397ms/step - loss: 0.4834 - accuracy: 0.7395 - val_loss: 5.0888 - val_accuracy: 0.3688
# Epoch 4/50
# 187/187 [==============================] - ETA: 0s - loss: 0.4693 - accuracy: 0.7602
# Epoch 00004: val_loss did not improve from 0.87020
# 187/187 [==============================] - 75s 403ms/step - loss: 0.4693 - accuracy: 0.7602 - val_loss: 0.9545 - val_accuracy: 0.3719
# Epoch 5/50
# 187/187 [==============================] - ETA: 0s - loss: 0.4695 - accuracy: 0.7559
# Epoch 00005: val_loss improved from 0.87020 to 0.67630, saving model to clf-ResNet152-weights.hdf5
# 187/187 [==============================] - 77s 411ms/step - loss: 0.4695 - accuracy: 0.7559 - val_loss: 0.6763 - val_accuracy: 0.6219
# Epoch 6/50
# 187/187 [==============================] - ETA: 0s - loss: 0.4299 - accuracy: 0.7990
# Epoch 00006: val_loss did not improve from 0.67630
# 187/187 [==============================] - 75s 403ms/step - loss: 0.4299 - accuracy: 0.7990 - val_loss: 5.3242 - val_accuracy: 0.4844
# Epoch 7/50
# 187/187 [==============================] - ETA: 0s - loss: 0.3696 - accuracy: 0.8341
# Epoch 00007: val_loss improved from 0.67630 to 0.41629, saving model to clf-ResNet152-weights.hdf5
# 187/187 [==============================] - 77s 412ms/step - loss: 0.3696 - accuracy: 0.8341 - val_loss: 0.4163 - val_accuracy: 0.8781
# Epoch 8/50
# 187/187 [==============================] - ETA: 0s - loss: 0.3242 - accuracy: 0.8559
# Epoch 00008: val_loss improved from 0.41629 to 0.36354, saving model to clf-ResNet152-weights.hdf5
# 187/187 [==============================] - 77s 413ms/step - loss: 0.3242 - accuracy: 0.8559 - val_loss: 0.3635 - val_accuracy: 0.8531
# Epoch 9/50
# 187/187 [==============================] - ETA: 0s - loss: 0.3176 - accuracy: 0.8666
# Epoch 00009: val_loss improved from 0.36354 to 0.34953, saving model to clf-ResNet152-weights.hdf5
# 187/187 [==============================] - 78s 416ms/step - loss: 0.3176 - accuracy: 0.8666 - val_loss: 0.3495 - val_accuracy: 0.8000
# Epoch 10/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2772 - accuracy: 0
50
# 187/187 [==============================] - ETA: 0s - loss: 0.1271 - accuracy: 0.9572
# Epoch 00040: val_loss did not improve from 0.06421
# 187/187 [==============================] - 85s 454ms/step - loss: 0.1271 - accuracy: 0.9572 - val_loss: 0.1085 - val_accuracy: 0.9625
# Epoch 41/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1207 - accuracy: 0.9639
# Epoch 00041: val_loss did not improve from 0.06421
# 187/187 [==============================] - 88s 469ms/step - loss: 0.1207 - accuracy: 0.9639 - val_loss: 0.1218 - val_accuracy: 0.9594
# Epoch 42/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1211 - accuracy: 0.9602
# Epoch 00042: val_loss did not improve from 0.06421
# 187/187 [==============================] - 86s 457ms/step - loss: 0.1211 - accuracy: 0.9602 - val_loss: 0.1025 - val_accuracy: 0.9656
# Epoch 43/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1189 - accuracy: 0.9592
# Epoch 00043: val_loss did not improve from 0.06421
# 187/187 [==============================] - 87s 466ms/step - loss: 0.1189 - accuracy: 0.9592 - val_loss: 0.1174 - val_accuracy: 0.9531
# Epoch 44/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1216 - accuracy: 0.9585
# Epoch 00044: val_loss did not improve from 0.06421
# 187/187 [==============================] - 88s 472ms/step - loss: 0.1216 - accuracy: 0.9585 - val_loss: 0.1222 - val_accuracy: 0.9594
# Epoch 45/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1272 - accuracy: 0.9572
# Epoch 00045: val_loss did not improve from 0.06421
# 187/187 [==============================] - 85s 455ms/step - loss: 0.1272 - accuracy: 0.9572 - val_loss: 0.2448 - val_accuracy: 0.9375
# Epoch 46/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1327 - accuracy: 0.9579
# Epoch 00046: val_loss did not improve from 0.06421
# 187/187 [==============================] - 88s 472ms/step - loss: 0.1327 - accuracy: 0.9579 - val_loss: 0.1421 - val_accuracy: 0.9406
# Epoch 47/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1163 - accuracy: 0.9552
# Epoch 00047: val_loss did not improve from 0.06421
# 187/187 [==============================] - 85s 455ms/step - loss: 0.1163 - accuracy: 0.9552 - val_loss: 0.1155 - val_accuracy: 0.9688
# Epoch 48/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1400 - accuracy: 0.9555
# Epoch 00048: val_loss did not improve from 0.06421
# 187/187 [==============================] - 86s 462ms/step - loss: 0.1400 - accuracy: 0.9555 - val_loss: 0.2212 - val_accuracy: 0.8875
# Epoch 49/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1420 - accuracy: 0.9498
# Epoch 00049: val_loss did not improve from 0.06421
# 187/187 [==============================] - 88s 470ms/step - loss: 0.1420 - accuracy: 0.9498 - val_loss: 0.2096 - val_accuracy: 0.9688
# Epoch 50/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1092 - accuracy: 0.9639
# Epoch 00050: val_loss did not improve from 0.06421
# 187/187 [==============================] - 88s 468ms/step - loss: 0.1092 - accuracy: 0.9639 - val_loss: 0.1365 - val_accuracy: 0.9625
# 37/37 [==============================] - 7s 182ms/step - loss: 0.1558 - accuracy: 0.9559
# Test accuracy : 95.59321999549866 %
# 0.9559322033898305
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97       399
#            1       0.92      0.94      0.93       191
#
#     accuracy                           0.96       590
#    macro avg       0.95      0.95      0.95       590
# weighted avg       0.96      0.96      0.96       590
#
# false negative 27
# false positive 67
# false positive 74
# false positive 145
# false negative 152
# false positive 157
# false positive 199
# false positive 210
# false positive 221
# false positive 239
# false negative 255
# false positive 259
# false positive 314
# false negative 333
# false negative 335
# false positive 337
# false negative 344
# false positive 346
# false positive 371
# false negative 374
# false negative 451
# false positive 461
# false negative 477
# false negative 518
# false positive 535
# false negative 569

# %%
# Train ResNet152_2
# run a different model using the same dataset and data split
import numpy as np
import keras
from keras import backend as K
from keras.layers.core import Dense, Activation
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator 
from keras.preprocessing import image
from keras.models import Model
from keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt 

import tensorflow.keras.applications as applications
from keras import applications
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications import ResNet152


clf_model = ResNet152(weights='imagenet', include_top=False, input_tensor=Input(shape=(256,256,3)))
# clf_model.summary()

for layer in clf_model.layers:
    layers.trainable = False
    
head = clf_model.output
head = AveragePooling2D(pool_size=(2,2))(head)
head = Flatten(name='Flatten')(head)
head = Dense(256, activation='relu')(head)
head = Dropout(0.1)(head)
head = Dense(256, activation='relu')(head)
head = Dropout(0.1)(head)
head = Dense(256, activation='relu')(head)
head = Dropout(0.1)(head)
head = Dense(2, activation='softmax')(head)

model = Model(clf_model.input, head)
model.compile(loss = 'categorical_crossentropy', 
              optimizer='adam', 
              metrics= ["accuracy"]
             )
# model.summary()

earlystopping = EarlyStopping(monitor='val_loss', 
                              mode='min', 
                              verbose=1, 
                              patience=30
                             )
checkpointer = ModelCheckpoint(filepath="clf-ResNet152_2-weights.hdf5", 
                               verbose=1, 
                               save_best_only=True
                              )
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=10,
                              min_delta=0.0001,
                              factor=0.2
                             )
callbacks = [checkpointer, earlystopping, reduce_lr]

h = model.fit(train_generator, 
              steps_per_epoch= train_generator.n // train_generator.batch_size, 
              epochs = 50, 
              validation_data= valid_generator, 
              validation_steps= valid_generator.n // valid_generator.batch_size, 
              callbacks=[checkpointer, earlystopping])

# saving model achitecture in json file
# model_json = model.to_json()
# with open("clf-resnet50-model.json", "w") as json_file:
#    json_file.write(model_json)

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(h.history['loss']);
plt.plot(h.history['val_loss']);
plt.title("Classification Model LOSS");
plt.ylabel("loss");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

plt.subplot(1,2,2)
plt.plot(h.history['accuracy']);
plt.plot(h.history['val_accuracy']);
plt.title("Classification Model Acc");
plt.ylabel("Accuracy");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

_, acc = model.evaluate(test_generator)
print("Test accuracy : {} %".format(acc*100))

prediction = model.predict(test_generator)

pred = np.argmax(prediction, axis=1)
#pred = np.asarray(pred).astype('str')
original = np.asarray(test['mask']).astype('int')

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
accuracy = accuracy_score(original, pred)
print(accuracy)

cm = confusion_matrix(original, pred)

report = classification_report(original, pred, labels = [0,1])
print(report)
plt.figure(figsize = (5,5))
sns.heatmap(cm, annot=True);
model.save("ResNet152_2")

for i in range(len(original)):
    if original[i] == 1 and pred[i] == 0:
        print("false negative", i)
    if original[i] == 0 and pred[i] == 1:
        print("false positive", i)
# Out:
# Epoch 1/50
# 187/187 [==============================] - ETA: 0s - loss: 0.7568 - accuracy: 0.6739
# Epoch 00001: val_loss improved from inf to 18.72886, saving model to clf-ResNet152_2-weights.hdf5
# 187/187 [==============================] - 99s 528ms/step - loss: 0.7568 - accuracy: 0.6739 - val_loss: 18.7289 - val_accuracy: 0.6281
# Epoch 2/50
# 187/187 [==============================] - ETA: 0s - loss: 0.4874 - accuracy: 0.7809
# Epoch 00002: val_loss did not improve from 18.72886
# 187/187 [==============================] - 89s 474ms/step - loss: 0.4874 - accuracy: 0.7809 - val_loss: 51.8490 - val_accuracy: 0.6313
# Epoch 3/50
# 187/187 [==============================] - ETA: 0s - loss: 0.4226 - accuracy: 0.8144
# Epoch 00003: val_loss did not improve from 18.72886
# 187/187 [==============================] - 86s 458ms/step - loss: 0.4226 - accuracy: 0.8144 - val_loss: 46.8405 - val_accuracy: 0.6313
# Epoch 4/50
# 187/187 [==============================] - ETA: 0s - loss: 0.5557 - accuracy: 0.7375
# Epoch 00004: val_loss improved from 18.72886 to 0.87781, saving model to clf-ResNet152_2-weights.hdf5
# 187/187 [==============================] - 91s 486ms/step - loss: 0.5557 - accuracy: 0.7375 - val_loss: 0.8778 - val_accuracy: 0.4938
# Epoch 5/50
# 187/187 [==============================] - ETA: 0s - loss: 0.5686 - accuracy: 0.6997
# Epoch 00005: val_loss did not improve from 0.87781
# 187/187 [==============================] - 86s 460ms/step - loss: 0.5686 - accuracy: 0.6997 - val_loss: 11.2739 - val_accuracy: 0.6250
# Epoch 6/50
# 187/187 [==============================] - ETA: 0s - loss: 0.4964 - accuracy: 0.7405
# Epoch 00006: val_loss did not improve from 0.87781
# 187/187 [==============================] - 85s 455ms/step - loss: 0.4964 - accuracy: 0.7405 - val_loss: 1.7257 - val_accuracy: 0.6438
# Epoch 7/50
# 187/187 [==============================] - ETA: 0s - loss: 0.4784 - accuracy: 0.7495
# Epoch 00007: val_loss improved from 0.87781 to 0.45543, saving model to clf-ResNet152_2-weights.hdf5
# 187/187 [==============================] - 93s 498ms/step - loss: 0.4784 - accuracy: 0.7495 - val_loss: 0.4554 - val_accuracy: 0.7531
# Epoch 8/50
# 187/187 [==============================] - ETA: 0s - loss: 0.4561 - accuracy: 0.7833
# Epoch 00008: val_loss did not improve from 0.45543
# 187/187 [==============================] - 85s 452ms/step - loss: 0.4561 - accuracy: 0.7833 - val_loss: 2.7915 - val_accuracy: 0.7156
# Epoch 9/50
# 187/187 [==============================] - ETA: 0s - loss: 0.4331 - accuracy: 0.7776
# Epoch 00009: val_loss improved from 0.45543 to 0.44292, saving model to clf-ResNet152_2-weights.hdf5
# 187/187 [==============================] - 89s 477ms/step - loss: 0.4331 - accuracy: 0.7776 - val_loss: 0.4429 - val_accuracy: 0.7906
# Epoch 10/50
# 187/187 [==============================] - ETA: 0s - loss: 0.4297 - accuracy: 0.7833
# Epoch 00010: val_loss did not improve from 0.44292
# 187/187 [==============================] - 84s 449ms/step - loss: 0.4297 - accuracy: 0.7833 - val_loss: 1.2558 - val_accuracy: 0.7375
# Epoch 11/50
# 187/187 [==============================] - ETA: 0s - loss: 0.4463 - accuracy: 0.7532
# Epoch 00011: val_loss did not improve from 0.44292
# 187/187 [==============================] - 88s 473ms/step - loss: 0.4463 - accuracy: 0.7532 - val_loss: 1.5536 - val_accuracy: 0.6625
# Epoch 12/50
# 187/187 [==============================] - ETA: 0s - loss: 0.4408 - accuracy: 0.7722
# Epoch 00012: val_loss did not improve from 0.44292
# 187/187 [==============================] - 85s 455ms/step - loss: 0.4408 - accuracy: 0.7722 - val_loss: 0.6500 - val_accuracy: 0.7250
# Epoch 13/50
# 187/187 [==============================] - ETA: 0s - loss: 0.3970 - accuracy: 0.7987
# Epoch 00013: val_loss did not improve from 0.44292
# 187/187 [==============================] - 84s 450ms/step - loss: 0.3970 - accuracy: 0.7987 - val_loss: 0.8205 - val_accuracy: 0.8031
# Epoch 14/50
# 187/187 [==============================] - ETA: 0s - loss: 0.
50
# 187/187 [==============================] - ETA: 0s - loss: 0.1640 - accuracy: 0.9452
# Epoch 00044: val_loss did not improve from 0.09910
# 187/187 [==============================] - 87s 465ms/step - loss: 0.1640 - accuracy: 0.9452 - val_loss: 0.3234 - val_accuracy: 0.9219
# Epoch 45/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2472 - accuracy: 0.9181
# Epoch 00045: val_loss did not improve from 0.09910
# 187/187 [==============================] - 88s 471ms/step - loss: 0.2472 - accuracy: 0.9181 - val_loss: 0.1274 - val_accuracy: 0.9531
# Epoch 46/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1669 - accuracy: 0.9515
# Epoch 00046: val_loss did not improve from 0.09910
# 187/187 [==============================] - 86s 462ms/step - loss: 0.1669 - accuracy: 0.9515 - val_loss: 0.1036 - val_accuracy: 0.9688
# Epoch 47/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1562 - accuracy: 0.9475
# Epoch 00047: val_loss improved from 0.09910 to 0.09624, saving model to clf-ResNet152_2-weights.hdf5
# 187/187 [==============================] - 92s 493ms/step - loss: 0.1562 - accuracy: 0.9475 - val_loss: 0.0962 - val_accuracy: 0.9594
# Epoch 48/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1596 - accuracy: 0.9488
# Epoch 00048: val_loss improved from 0.09624 to 0.09393, saving model to clf-ResNet152_2-weights.hdf5
# 187/187 [==============================] - 95s 509ms/step - loss: 0.1596 - accuracy: 0.9488 - val_loss: 0.0939 - val_accuracy: 0.9719
# Epoch 49/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2656 - accuracy: 0.9007
# Epoch 00049: val_loss did not improve from 0.09393
# 187/187 [==============================] - 87s 465ms/step - loss: 0.2656 - accuracy: 0.9007 - val_loss: 0.4580 - val_accuracy: 0.7312
# Epoch 50/50
# 187/187 [==============================] - ETA: 0s - loss: 0.3204 - accuracy: 0.8732
# Epoch 00050: val_loss did not improve from 0.09393
# 187/187 [==============================] - 113s 603ms/step - loss: 0.3204 - accuracy: 0.8732 - val_loss: 10.4704 - val_accuracy: 0.8156
# 37/37 [==============================] - 4s 102ms/step - loss: 7.8213 - accuracy: 0.8305
# Test accuracy : 83.05084705352783 %
# 0.8305084745762712
#               precision    recall  f1-score   support
#
#            0       0.84      0.92      0.88       399
#            1       0.79      0.64      0.71       191
#
#     accuracy                           0.83       590
#    macro avg       0.82      0.78      0.80       590
# weighted avg       0.83      0.83      0.83       590
#
# false negative 0
# false negative 11
# false negative 15
# false negative 17
# false negative 27
# false positive 36
# false positive 40
# false negative 43
# false positive 45
# false negative 46
# false negative 49
# false negative 64
# false negative 65
# false negative 78
# false negative 81
# false negative 99
# false positive 101
# false positive 102
# false negative 105
# false negative 106
# false negative 113
# false negative 118
# false negative 121
# false negative 131
# false negative 152
# false negative 162
# false negative 174
# false negative 192
# false positive 193
# false negative 211
# false negative 212
# false negative 219
# false negative 223
# false positive 234
# false positive 235
# false positive 236
# false negative 237
# false positive 238
# false positive 244
# false negative 245
# false negative 248
# false negative 252
# false negative 255
# false negative 256
# false positive 264
# false positive 270
# false negative 272
# false positive 282
# false negative 283
# false negative 285
# false negative 290
# false positive 307
# false negative 309
# false negative 317
# false positive 318
# false negative 321
# false negative 323
# false positive 327
# false positive 329
# false negative 335
# false positive 337
# false negative 338
# false negative 339
# false negative 356
# false negative 358
# false negative 374
# false positive 376
# false positive 395
# false negative 409
# false positive 417
# false positive 422
# false positive 432
# false negative 444
# false negative 451
# false negative 457
# false negative 465
# false positive 468
# false negative 472
# false negative 477
# false negative 484
# false negative 486
# false negative 489
# false positive 490
# false positive 496
# false positive 498
# false negative 499
# false negative 500
# false negative 503
# false negative 511
# false negative 517
# false negative 518
# false positive 526
# false negative 528
# false positive 546
# false negative 552
# false negative 557
# false negative 569
# false negative 575
# false positive 576
# false positive 589

# %%
# Train MobileNet
# run a different model using the same dataset and data split
import numpy as np
import keras
from keras import backend as K
from keras.layers.core import Dense, Activation
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator 
from keras.preprocessing import image
from keras.models import Model
from keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt 

import tensorflow.keras.applications as applications
from keras import applications
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications import ResNet101
from tensorflow.keras.applications
50
# 187/187 [==============================] - ETA: 0s - loss: 0.0467 - accuracy: 0.9870
# Epoch 00045: val_loss did not improve from 0.03350
# 187/187 [==============================] - 56s 297ms/step - loss: 0.0467 - accuracy: 0.9870 - val_loss: 0.0911 - val_accuracy: 0.9750
# Epoch 46/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0472 - accuracy: 0.9870
# Epoch 00046: val_loss did not improve from 0.03350
# 187/187 [==============================] - 55s 293ms/step - loss: 0.0472 - accuracy: 0.9870 - val_loss: 0.1075 - val_accuracy: 0.9781
# Epoch 47/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0368 - accuracy: 0.9863
# Epoch 00047: val_loss did not improve from 0.03350
# 187/187 [==============================] - 62s 330ms/step - loss: 0.0368 - accuracy: 0.9863 - val_loss: 0.1500 - val_accuracy: 0.9563
# Epoch 48/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0899 - accuracy: 0.9689
# Epoch 00048: val_loss did not improve from 0.03350
# 187/187 [==============================] - 55s 293ms/step - loss: 0.0899 - accuracy: 0.9689 - val_loss: 0.4832 - val_accuracy: 0.9406
# Epoch 49/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0782 - accuracy: 0.9776
# Epoch 00049: val_loss did not improve from 0.03350
# 187/187 [==============================] - 62s 332ms/step - loss: 0.0782 - accuracy: 0.9776 - val_loss: 0.0613 - val_accuracy: 0.9844
# Epoch 50/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0524 - accuracy: 0.9863
# Epoch 00050: val_loss did not improve from 0.03350
# 187/187 [==============================] - 55s 296ms/step - loss: 0.0524 - accuracy: 0.9863 - val_loss: 0.0575 - val_accuracy: 0.9812
# 37/37 [==============================] - 1s 38ms/step - loss: 0.0826 - accuracy: 0.9780
# Test accuracy : 97.79661297798157 %
# 0.9779661016949153
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       399
#            1       0.97      0.96      0.97       191
#
#     accuracy                           0.98       590
#    macro avg       0.98      0.97      0.97       590
# weighted avg       0.98      0.98      0.98       590
#
# false positive 13
# false positive 67
# false positive 128
# false positive 199
# false negative 202
# false positive 210
# false negative 248
# false negative 256
# false negative 321
# false negative 335
# false negative 344
# false negative 477
# false negative 486

# %%
# Train MobileNet-2
# run a different model using the same dataset and data split
import numpy as np
import keras
from keras import backend as K
from keras.layers.core import Dense, Activation
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator 
from keras.preprocessing import image
from keras.models import Model
from keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt 

import tensorflow.keras.applications as applications
from keras import applications
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications import ResNet101
from tensorflow.keras.applications import VGG16

clf_model = keras.applications.mobilenet.MobileNet(weights='imagenet', include_top=False, input_tensor=Input(shape=(256,256,3)))
# clf_model.summary()

for layer in clf_model.layers:
    layers.trainable = False

head = clf_model.output
head = AveragePooling2D(pool_size=(4,4))(head)
head = Flatten(name='Flatten')(head)
head = Dense(256, activation='relu')(head)
head = Dropout(0.3)(head)
head = Dense(128, activation='relu')(head)
head = Dropout(0.2)(head)
head = Dense(2, activation='softmax')(head)

model = Model(clf_model.input, head)
model.compile(loss = 'categorical_crossentropy', 
              optimizer='adam', 
              metrics= ["accuracy"]
             )
# model.summary()

earlystopping = EarlyStopping(monitor='val_loss', 
                              mode='min', 
                              verbose=1, 
                              patience=15
                             )
checkpointer = ModelCheckpoint(filepath="clf-MobileNet-2-weights.hdf5", 
                               verbose=1, 
                               save_best_only=True
                              )
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=10,
                              min_delta=0.0001,
                              factor=0.2
                             )
callbacks = [checkpointer, earlystopping, reduce_lr]

h = model.fit(train_generator, 
              steps_per_epoch= train_generator.n // train_generator.batch_size, 
              epochs = 50, 
              validation_data= valid_generator, 
              validation_steps= valid_generator.n // valid_generator.batch_size, 
              callbacks=[checkpointer, earlystopping])

# saving model achitecture in json file
# model_json = model.to_json()
# with open("clf-resnet50-model.json", "w") as json_file:
#    json_file.write(model_json)

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(h.history['loss']);
plt.plot(h.history['val_loss']);
plt.title("Classification Model LOSS");
plt.ylabel("loss");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

plt.subplot(1,2,2)
plt.plot(h.history['accuracy']);
plt.plot(h.history['val_accuracy']);
plt.title("Classification Model Acc");
plt.ylabel("Accuracy");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

_, acc = model.evaluate(test_generator)
print("Test accuracy : {} %".format(acc*100))

prediction = model.predict(test_generator)

pred = np.argmax(prediction, axis=1)
#pred = np.asarray(pred).astype('str')
original = np.asarray(test['mask']).astype('int')

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
accuracy = accuracy_score(original, pred)
print(accuracy)

cm = confusion_matrix(original, pred)

report = classification_report(original, pred, labels = [0,1])
print(report)
plt.figure(figsize = (5,5))
sns.heatmap(cm, annot=True);
model.save("MobileNet-2")

for i in range(len(original)):
    if original[i] == 1 and pred[i] == 0:
        print("false negative", i)
    if original[i] == 0 and pred[i] == 1:
        print("false positive", i)
# Out:
# Epoch 1/50
# 187/187 [==============================] - ETA: 0s - loss: 0.5520 - accuracy: 0.8074
# Epoch 00001: val_loss improved from inf to 0.41116, saving model to clf-MobileNet-2-weights.hdf5
# 187/187 [==============================] - 56s 301ms/step - loss: 0.5520 - accuracy: 0.8074 - val_loss: 0.4112 - val_accuracy: 0.8656
# Epoch 2/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2629 - accuracy: 0.9104
# Epoch 00002: val_loss improved from 0.41116 to 0.15019, saving model to clf-MobileNet-2-weights.hdf5
# 187/187 [==============================] - 55s 296ms/step - loss: 0.2629 - accuracy: 0.9104 - val_loss: 0.1502 - val_accuracy: 0.9406
# Epoch 3/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2356 - accuracy: 0.9244
# Epoch 00003: val_loss did not improve from 0.15019
# 187/187 [==============================] - 61s 328ms/step - loss: 0.2356 - accuracy: 0.9244 - val_loss: 0.3082 - val_accuracy: 0.8781
# Epoch 4/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2054 - accuracy: 0.9431
# Epoch 00004: val_loss did not improve from 0.15019
# 187/187 [==============================] - 56s 297ms/step - loss: 0.2054 - accuracy: 0.9431 - val_loss: 0.2558 - val_accuracy: 0.9062
# Epoch 5/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1906 - accuracy: 0.9334
# Epoch 00005: val_loss improved from 0.15019 to 0.13090, saving model to clf-MobileNet-2-weights.hdf5
# 187/187 [==============================] -
50
# 187/187 [==============================] - ETA: 0s - loss: 0.0754 - accuracy: 0.9769
# Epoch 00036: val_loss did not improve from 0.04943
# 187/187 [==============================] - 56s 300ms/step - loss: 0.0754 - accuracy: 0.9769 - val_loss: 0.0800 - val_accuracy: 0.9844
# Epoch 00036: early stopping
# 37/37 [==============================] - 1s 39ms/step - loss: 0.1036 - accuracy: 0.9712
# Test accuracy : 97.11864590644836 %
# 0.9711864406779661
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       399
#            1       0.96      0.95      0.96       191
#
#     accuracy                           0.97       590
#    macro avg       0.97      0.97      0.97       590
# weighted avg       0.97      0.97      0.97       590
#
# false negative 27
# false positive 59
# false negative 99
# false negative 106
# false negative 202
# false positive 210
# false positive 239
# false negative 251
# false negative 256
# false negative 335
# false negative 344
# false negative 374
# false positive 376
# false positive 460
# false positive 475
# false positive 531
# false positive 583

# %%
# Train MobileNet-3
# run a different model using the same dataset and data split
import numpy as np
import keras
from keras import backend as K
from keras.layers.core import Dense, Activation
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator 
from keras.preprocessing import image
from keras.models import Model
from keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt 

import tensorflow.keras.applications as applications
from keras import applications
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications import ResNet101
from tensorflow.keras.applications import VGG16

clf_model = keras.applications.mobilenet.MobileNet(weights='imagenet', include_top=False, input_tensor=Input(shape=(256,256,3)))
# clf_model.summary()

for layer in clf_model.layers:
    layers.trainable = False
    
head = clf_model.output
head = AveragePooling2D(pool_size=(2,2))(head)
head = Flatten(name='Flatten')(head)
head = Dense(256, activation='relu')(head)
head = Dropout(0.1)(head)
head = Dense(128, activation='relu')(head)
head = Dropout(0.2)(head)
head = Dense(2, activation='softmax')(head)

model = Model(clf_model.input, head)
model.compile(loss = 'categorical_crossentropy', 
              optimizer='adam', 
              metrics= ["accuracy"]
             )
# model.summary()

earlystopping = EarlyStopping(monitor='val_loss', 
                              mode='min', 
                              verbose=1, 
                              patience=15
                             )
checkpointer = ModelCheckpoint(filepath="clf-MobileNet-3-weights.hdf5", 
                               verbose=1, 
                               save_best_only=True
                              )
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=10,
                              min_delta=0.0001,
                              factor=0.2
                             )
callbacks = [checkpointer, earlystopping, reduce_lr]

h = model.fit(train_generator, 
              steps_per_epoch= train_generator.n // train_generator.batch_size, 
              epochs = 50, 
              validation_data= valid_generator, 
              validation_steps= valid_generator.n // valid_generator.batch_size, 
              callbacks=[checkpointer, earlystopping])

# saving model achitecture in json file
# model_json = model.to_json()
# with open("clf-resnet50-model.json", "w") as json_file:
#    json_file.write(model_json)

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(h.history['loss']);
plt.plot(h.history['val_loss']);
plt.title("Classification Model LOSS");
plt.ylabel("loss");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

plt.subplot(1,2,2)
plt.plot(h.history['accuracy']);
plt.plot(h.history['val_accuracy']);
plt.title("Classification Model Acc");
plt.ylabel("Accuracy");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

_, acc = model.evaluate(test_generator)
print("Test accuracy : {} %".format(acc*100))

prediction = model.predict(test_generator)

pred = np.argmax(prediction, axis=1)
#pred = np.asarray(pred).astype('str')
original = np.asarray(test['mask']).astype('int')

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
accuracy = accuracy_score(original, pred)
print(accuracy)

cm = confusion_matrix(original, pred)

report = classification_report(original, pred, labels = [0,1])
print(report)
plt.figure(figsize = (5,5))
sns.heatmap(cm, annot=True);
model.save("MobileNet-3")

for i in range(len(original)):
    if original[i] == 1 and pred[i] == 0:
        print("false negative", i)
    if original[i] == 0 and pred[i] == 1:
        print("false positive", i)
# Out:
# Epoch 1/50
# 187/187 [==============================] - ETA: 0s - loss: 0.8684 - accuracy: 0.7860
# Epoch 00001: val_loss improved from inf to 0.43966, saving model to clf-MobileNet-3-weights.hdf5
# 187/187 [==============================] - 57s 302ms/step - loss: 0.8684 - accuracy: 0.7860 - val_loss: 0.4397 - val_accuracy: 0.8719
# Epoch 2/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2809 - accuracy: 0.9007
# Epoch 00002: val_loss did not improve from 0.43966
# 187/187 [==============================] - 55s 295ms/step - loss: 0.2809 - accuracy: 0.9007 - val_loss: 0.4528 - val_accuracy: 0.8844
# Epoch 3/50
# 187/187 [==============================] - ETA: 0s - loss: 0.3297 - accuracy: 0.9031
# Epoch 00003: val_loss did not improve from 0.43966
# 187/187 [==============================] - 62s 334ms/step - loss: 0.3297 - accuracy: 0.9031 - val_loss: 1.4678 - val_accuracy: 0.7156
# Epoch 4/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2287 - accuracy: 0.9308
# Epoch 00004: val_loss improved from 0.43966 to 0.12600, saving model to clf-MobileNet-3-weights.hdf5
# 187/187 [==============================] - 56s 299ms/step - loss: 0.2287 - accuracy: 0.9308 - val_loss: 0.1260 - val_accuracy: 0.9563
# Epoch 5/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1902 - accuracy: 0.9391
# Epoch 00005: val_loss improved from 0.12600 to 0.11096, saving model to clf-MobileNet-3-weights.hdf5
# 187/187 [==============================] - 64s 340ms/step - loss: 0.1902 - accuracy: 0.9391 - val_loss: 0.1110 - val_accuracy: 0.9563
# Epoch 6/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1818 - accuracy: 0.9462
# Epoch 00006: val_loss improved from 0.11096 to 0.08512, saving model to clf-MobileNet-3-weights.hdf5
# 187/187 [==============================] - 55s 295ms/step - loss: 0.1818 - accuracy: 0.9462 - val_loss: 0.0851 - val_accuracy: 0.9781
# Epoch 7/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1714 - accuracy: 0.9478
# Epoch 00007: val_loss did not improve from 0.08512
# 187/187 [==============================] - 62s 334ms/step - loss: 0.1714 - accuracy: 0.9478 - val_loss: 0.1397 - val_accuracy: 0.9406
# Epoch 8/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1388 - accuracy: 0.9599
# Epoch 00008: val_loss did not improve from 0.08512
# 187/187 [==============================] - 55s 296ms/step - loss: 0.1388 - accuracy: 0.9599 - val_loss: 0.3719 - val_accuracy: 0.8406
# Epoch 9/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1357 - accuracy: 0.9538
# Epoch 00009: val_loss improved from 0.08512 to 0.07729, saving model to clf-MobileNet-3-weights.hdf5
# 187/187 [==============================] - 56s 298ms/step - loss: 0.1357 - accuracy: 0.9538 - val_loss: 0.0773 - val_accuracy: 0.9844
# Epoch 10/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1271 - accuracy: 0.9585
# Epoch 00010: val_loss did not improve from 0.07729
# 187/187 [==============================] - 63s 339ms/step - loss: 0.1271 - accuracy: 0.9585 - val_loss: 0.0775 - val_accuracy: 0.9812
# Epoch 11/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1362 - accuracy: 0.9555
# Epoch 00011: val_loss improved from 0.07729 to 0.06223, saving model to clf-MobileNet-3-weights.hdf5
# 187/187 [==============================] - 55s 296ms/step - loss: 0.1362 - accuracy: 0.9555 - val_loss: 0.0622 - val_accuracy: 0.9781
# Epoch 12/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1256 - accuracy: 0.9595
# Epoch 00012: val_loss improved from 0.06223 to 0.05656, saving model to clf-MobileNet-3-weights.hdf5
# 187/187 [==============================] -
# Epoch 28/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0694 - accuracy: 0.9776
# Epoch 00028: val_loss did not improve from 0.02942
# 187/187 [==============================] - 53s 285ms/step - loss: 0.0694 - accuracy: 0.9776 - val_loss: 0.0737 - val_accuracy: 0.9625
# Epoch 29/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0734 - accuracy: 0.9769
# Epoch 00029: val_loss did not improve from 0.02942
# 187/187 [==============================] - 64s 340ms/step - loss: 0.0734 - accuracy: 0.9769 - val_loss: 0.0533 - val_accuracy: 0.9844
# Epoch 30/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0723 - accuracy: 0.9753
# Epoch 00030: val_loss did not improve from 0.02942
# 187/187 [==============================] - 54s 291ms/step - loss: 0.0723 - accuracy: 0.9753 - val_loss: 0.0594 - val_accuracy: 0.9812
# Epoch 31/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0914 - accuracy: 0.9746
# Epoch 00031: val_loss did not improve from 0.02942
# 187/187 [==============================] - 55s 293ms/step - loss: 0.0914 - accuracy: 0.9746 - val_loss: 0.1076 - val_accuracy: 0.9656
# Epoch 00031: early stopping
# 37/37 [==============================] - 2s 50ms/step - loss: 0.1199 - accuracy: 0.9712
# Test accuracy : 97.11864590644836 %
# 0.9711864406779661
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98       399
#            1       0.97      0.94      0.95       191
#
#     accuracy                           0.97       590
#    macro avg       0.97      0.96      0.97       590
# weighted avg       0.97      0.97      0.97       590
#
# false negative 27
# false negative 65
# false negative 99
# false negative 106
# false positive 210
# false positive 239
# false negative 248
# false negative 251
# false negative 256
# false positive 318
# false negative 335
# false negative 344
# false positive 368
# false negative 374
# false positive 414
# false negative 477
# false positive 583

# %%
# Train MobileNetV2
# run a different model using the same dataset and data split
import numpy as np
import keras
from keras import backend as K
from keras.layers.core import Dense, Activation
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator 
from keras.preprocessing import image
from keras.models import Model
from keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt 

import tensorflow.keras.applications as applications
from keras import applications
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications import ResNet101
from tensorflow.keras.applications import VGG16

clf_model = keras.applications.mobilenet_v2.MobileNetV2(weights='imagenet', include_top=False, input_tensor=Input(shape=(256,256,3)))
# clf_model.summary()


for layer in clf_model.layers:
    layers.trainable = False
    
head = clf_model.output
head = AveragePooling2D(pool_size=(2,2))(head)
head = Flatten(name='Flatten')(head)
head = Dense(256, activation='relu')(head)
head = Dropout(0.1)(head)
head = Dense(128, activation='relu')(head)
head = Dropout(0.2)(head)
head = Dense(2, activation='softmax')(head)

model = Model(clf_model.input, head)
model.compile(loss = 'categorical_crossentropy', 
              optimizer='adam', 
              metrics= ["accuracy"]
             )
# model.summary()

earlystopping = EarlyStopping(monitor='val_loss', 
                              mode='min', 
                              verbose=1, 
                              patience=15
                             )
checkpointer = ModelCheckpoint(filepath="clf-MobileNetV2-weights.hdf5", 
                               verbose=1, 
                               save_best_only=True
                              )
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=10,
                              min_delta=0.0001,
                              factor=0.2
                             )
callbacks = [checkpointer, earlystopping, reduce_lr]

h = model.fit(train_generator, 
              steps_per_epoch= train_generator.n // train_generator.batch_size, 
              epochs = 50, 
              validation_data= valid_generator, 
              validation_steps= valid_generator.n // valid_generator.batch_size, 
              callbacks=[checkpointer, earlystopping])

# saving model achitecture in json file
# model_json = model.to_json()
# with open("clf-resnet50-model.json", "w") as json_file:
#    json_file.write(model_json)

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(h.history['loss']);
plt.plot(h.history['val_loss']);
plt.title("Classification Model LOSS");
plt.ylabel("loss");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

plt.subplot(1,2,2)
plt.plot(h.history['accuracy']);
plt.plot(h.history['val_accuracy']);
plt.title("Classification Model Acc");
plt.ylabel("Accuracy");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

_, acc = model.evaluate(test_generator)
print("Test accuracy : {} %".format(acc*100))

prediction = model.predict(test_generator)

pred = np.argmax(prediction, axis=1)
#pred = np.asarray(pred).astype('str')
original = np.asarray(test['mask']).astype('int')

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
accuracy = accuracy_score(original, pred)
print(accuracy)

cm = confusion_matrix(original, pred)

report = classification_report(original, pred, labels = [0,1])
print(report)
plt.figure(figsize = (5,5))
sns.heatmap(cm, annot=True);
model.save("MobileNetV2")

for i in range(len(original)):
    if original[i] == 1 and pred[i] == 0:
        print("false negative", i)
    if original[i] == 0 and pred[i] == 1:
        print("false positive", i)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# Epoch 1/50
# 187/187 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.8013
# Epoch 00001: val_loss improved from inf to 15.91052, saving model to clf-MobileNetV2-weights.hdf5
# 187/187 [==============================] - 56s 302ms/step - loss: 0.6936 - accuracy: 0.8013 - val_loss: 15.9105 - val_accuracy: 0.6406
# Epoch 2/50
# 187/187 [==============================] - ETA: 0s - loss: 0.3993 - accuracy: 0.8849
# Epoch 00002: val_loss improved from 15.91052 to 0.79347, saving model to clf-MobileNetV2-weights.hdf5
# 187/187 [==============================] - 55s 295ms/step - loss: 0.3993 - accuracy: 0.8849 - val_loss: 0.7935 - val_accuracy: 0.6062
# Epoch 3/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2907 - accuracy: 0.9090
# Epoch 00003: val_loss did not improve from 0.79347
# 187/187 [==============================] - 64s 342ms/step - loss: 0.2907 - accuracy: 0.9090 - val_loss: 1.3073 - val_accuracy: 0.5219
# Epoch 4/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2070 - accuracy: 0.9321
# Epoch 00004: val_loss did not improve from 0.79347
# 187/187 [==============================] - 55s 294ms/step - loss: 0.2070 - accuracy: 0.9321 - val_loss: 3.9994 - val_accuracy: 0.4594
# Epoch 5/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2001 - accuracy: 0.9391
# Epoch 00005: val_loss did not improve from 0.79347
# 187/187 [==============================] - 64s 343ms/step - loss: 0.2001 - accuracy: 0.9391 - val_loss: 3.6575 - val_accuracy: 0.4437
# Epoch 6/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2458 - accuracy: 0.9184
# Epoch 00006: val_loss did not improve from 0.79347
# 187/187 [==============================] - 55s 293ms/step - loss: 0.2458 - accuracy: 0.9184 - val_loss: 10.3815 - val_accuracy: 0.4250
# Epoch 7/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1922 - accuracy: 0.9411
# Epoch 00007: val_loss did not improve from 0.79347
# 187/187 [==============================] - 61s 325ms/step - loss: 0.1922 - accuracy: 0.9411 - val_loss: 8.6909 - val_accuracy: 0.4219
# Epoch 8/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1635 - accuracy: 0.
# Epoch 23/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1297 - accuracy: 0.9565
# Epoch 00023: val_loss did not improve from 0.56608
# 187/187 [==============================] - 55s 293ms/step - loss: 0.1297 - accuracy: 0.9565 - val_loss: 1.6435 - val_accuracy: 0.7312
# Epoch 24/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1623 - accuracy: 0.9492
# Epoch 00024: val_loss did not improve from 0.56608
# 187/187 [==============================] - 64s 344ms/step - loss: 0.1623 - accuracy: 0.9492 - val_loss: 3.4393 - val_accuracy: 0.4594
# Epoch 25/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1606 - accuracy: 0.9478
# Epoch 00025: val_loss did not improve from 0.56608
# 187/187 [==============================] - 55s 295ms/step - loss: 0.1606 - accuracy: 0.9478 - val_loss: 4.2573 - val_accuracy: 0.4406
# Epoch 00025: early stopping
# 37/37 [==============================] - 2s 53ms/step - loss: 4.4794 - accuracy: 0.4000
# Test accuracy : 40.00000059604645 %
# 0.4
#               precision    recall  f1-score   support
#
#            0       1.00      0.11      0.20       399
#            1       0.35      1.00      0.52       191
#
#     accuracy                           0.40       590
#    macro avg       0.68      0.56      0.36       590
# weighted avg       0.79      0.40      0.31       590
#
# false positive 1
# false positive 2
# false positive 4
# false positive 5
# false positive 6
# false positive 7
# false positive 8
# false positive 9
# false positive 10
# false positive 12
# false positive 13
# false positive 14
# false positive 16
# false positive 20
# false positive 21
# false positive 22
# false positive 28
# false positive 30
# false positive 32
# false positive 33
# false positive 34
# false positive 35
# false positive 36
# false positive 37
# false positive 38
# false positive 39
# false positive 40
# false positive 41
# false positive 45
# false positive 47
# false positive 50
# false positive 52
# false positive 54
# false positive 55
# false positive 56
# false positive 57
# false positive 59
# false positive 60
# false positive 61
# false positive 66
# false positive 67
# false positive 68
# false positive 69
# false positive 71
# false positive 72
# false positive 73
# false positive 74
# false positive 75
# false positive 76
# false positive 80
# false positive 82
# false positive 84
# false positive 85
# false positive 86
# false positive 87
# false positive 88
# false positive 89
# false positive 91
# false positive 92
# false positive 93
# false positive 94
# false positive 95
# false positive 97
# false positive 100
# false positive 101
# false positive 102
# false positive 104
# false positive 107
# false positive 108
# false positive 109
# false positive 110
# false positive 111
# false positive 114
# false positive 115
# false positive 116
# false positive 117
# false positive 119
# false positive 120
# false positive 122
# false positive 123
# false positive 124
# false positive 126
# false positive 127
# false positive 128
# false positive 129
# false positive 130
# false positive 133
# false positive 134
# false positive 135
# false positive 139
# false positive 140
# false positive 141
# false positive 144
# false positive 145
# false positive 146
# false positive 147
# false positive 149
# false positive 153
# false positive 155
# false positive 156
# false positive 157
# false positive 158
# false positive 159
# false positive 161
# false positive 165
# false positive 166
# false positive 167
# false positive 168
# false positive 169
# false positive 170
# false positive 172
# false positive 175
# false positive 176
# false positive 179
# false positive 180
# false positive 181
# false positive 183
# false positive 185
# false positive 186
# false positive 187
# false positive 188
# false positive 189
# false positive 190
# false positive 191
# false positive 193
# false positive 196
# false positive 197
# false positive 198
# false positive 199
# false positive 204
# false positive 206
# false positive 207
# false positive 208
# false positive 210
# false positive 213
# false positive 215
# false positive 217
# false positive 220
# false positive 221
# false positive 224
# false positive 225
# false positive 226
# false positive 230
# false positive 231
# false positive 232
# false positive 233
# false positive 234
# false positive 235
# false positive 236
# false positive 238
# false positive 239
# false positive 240
# false positive 241
# false positive 242
# false positive 244
# false positive 246
# false positive 249
# false positive 253
# false positive 258
# false positive 259
# false positive 260
# false positive 261
# false positive 263
# false positive 264
# false positive 267
# false positive 268
# false positive 269
# false positive 270
# false positive 271
# false positive 273
# false positive 274
# false positive 275
# false positive 277
# false positive 278
# false positive 279
# false positive 280
# false positive 282
# false positive 287
# false positive 292
# false positive 294
# false positive 295
# false positive 296
# false positive 297
# false positive 305
# false positive 306
# false positive 307
# false positive 308
# false positive 310
# false positive 311
# false positive 314
# false positive 315
# false positive 316
# false positive 318
# false positive 319
# false positive 320
# false positive 322
# false positive 325
# false positive 327
# false positive 329
# false positive 331
# false positive 332
# false positive 334
# false positive 336
# false positive 337
# false positive 341
# false positive 342
# false positive 346
# false positive 347
# false positive 348
# false positive 349
# false positive 350
# false positive 353
# false positive 354
# false positive 355
# false positive 359
# false positive 360
# false positive 361
# false positive 363
# false positive 366
# false positive 367
# false positive 368
# false positive 369
# false positive 370
# false positive 371
# false positive 373
# false positive 376
# false positive 379
# false positive 380
# false positive 381
# false positive 382
# false positive 383
# false positive 389
# false positive 390
# false positive 391
# false positive 393
# false positive 395
# false positive 396
# false positive 397
# false positive 399
# false positive 400
# false positive 401
# false positive 404
# false positive 405
# false positive 406
# false positive 410
# false positive 413
# false positive 414
# false positive 416
# false positive 417
# false positive 418
# false positive 419
# false positive 420
# false positive 422
# false positive 423
# false positive 424
# false positive 425
# false positive 426
# false positive 427
# false positive 428
# false positive 431
# false positive 432
# false positive 433
# false positive 435
# false positive 436
# false positive 437
# false positive 438
# false positive 440
# false positive 441
# false positive 443
# false positive 445
# false positive 448
# false positive 449
# false positive 450
# false positive 453
# false positive 454
# false positive 456
# false positive 458
# false positive 459
# false positive 460
# false positive 461
# false positive 462
# false positive 463
# false positive 464
# false positive 467
# false positive 468
# false positive 469
# false positive 473
# false positive 475
# false positive 476
# false positive 478
# false positive 481
# false positive 482
# false positive 485
# false positive 487
# false positive 488
# false positive 490
# false positive 494
# false positive 495
# false positive 496
# false positive 498
# false positive 501
# false positive 502
# false positive 505
# false positive 507
# false positive 508
# false positive 510
# false positive 512
# false positive 513
# false positive 515
# false positive 516
# false positive 519
# false positive 520
# false positive 521
# false positive 522
# false positive 524
# false positive 526
# false positive 527
# false positive 530
# false positive 531
# false positive 532
# false positive 533
# false positive 535
# false positive 536
# false positive 538
# false positive 539
# false positive 544
# false positive 545
# false positive 546
# false positive 547
# false positive 548
# false positive 550
# false positive 553
# false positive 554
# false positive 556
# false positive 558
# false positive 560
# false positive 564
# false positive 565
# false positive 566
# false positive 567
# false positive 568
# false positive 573
# false positive 574
# false positive 576
# false positive 578
# false positive 581
# false positive 582
# false positive 583
# false positive 584
# false positive 585
# false positive 586
# false positive 587
# false positive 588
# false positive 589

# %% [markdown]
# the predictions made by AI are almost correct :)
