# %% [markdown]
# # 1: IMPORTING LIBRARIES AND DATASET

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import zipfile
import cv2
from skimage import io

import tensorflow as tf
from tensorflow.python.keras import Sequential
from tensorflow.keras import layers, optimizers
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
import tensorflow.keras.backend as K

import random
import glob
from sklearn.preprocessing import StandardScaler, normalize
from IPython.display import display

# %%
data = pd.read_csv('../input/lgg-mri-segmentation/kaggle_3m/data.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Patient                    110 non-null    object
#  1   RNASeqCluster              92 non-null     float64
#  2   MethylationCluster         109 non-null    float64
#  3   miRNACluster               110 non-null    int64
#  4   CNCluster                  108 non-null    float64
#  5   RPPACluster                98 non-null     float64
#  6   OncosignCluster            105 non-null    float64
#  7   COCCluster                 110 non-null    int64
#  8   histological_type          109 non-null    float64
#  9   neoplasm_histologic_grade  109 non-null    float64
#  10  tumor_tissue_site          109 non-null    float64
#  11  laterality                 109 non-null    float64
#  12  tumor_location             109 non-null    float64
#  13  gender                     109 non-null    float64
#  14  age_at_initial_pathologic  109 non-null    float64
#  15  race                       108 non-null    float64
#  16  ethnicity                  102 non-null    float64
#  17  death01                    109 non-null    float64
# dtypes: float64(15), int64(2), object(1)
# memory usage: 15.6+ KB

# %%
data.head(10)
# Out:
#         Patient  RNASeqCluster  MethylationCluster  miRNACluster  CNCluster  \
# 0  TCGA_CS_4941            2.0                 4.0             2        2.0
# 1  TCGA_CS_4942            1.0                 5.0             2        1.0
# 2  TCGA_CS_4943            1.0                 5.0             2        1.0
# 3  TCGA_CS_4944            NaN                 5.0             2        1.0
# 4  TCGA_CS_5393            4.0                 5.0             2        1.0
# 5  TCGA_CS_5395            2.0                 4.0             2        2.0
# 6  TCGA_CS_5396            3.0                 3.0             2        3.0
# 7  TCGA_CS_5397            NaN                 4.0             1        2.0
# 8  TCGA_CS_6186            2.0                 4.0             1        2.0
# 9  TCGA_CS_6188            2.0                 4.0             3        2.0
#
#    RPPACluster  OncosignCluster  COCCluster  histological_type  \
# 0          NaN              3.0           2                1.0
# 1          1.0              2.0           1                1.0
# 2          2.0              2.0           1                1.0
# 3          2.0              1.0           1                1.0
# 4          2.0              3.0           1                1.0
# 5          NaN              3.0           2                3.0
# 6          2.0              2.0           3                3.0
# 7          3.0              3.0           2                1.0
# 8          1.0              3.0           2                2.0
# 9          3.0              3.0           2                1.0
#
#    neoplasm_histologic_grade  tumor_tissue_site  laterality  tumor_location  \
# 0                        2.0                1.0         3.0             2.0
# 1                        2.0                1.0         3.0             2.0
# 2                        2.0                1.0         1.0             2.0
# 3                        1.0                1.0         3.0             6.0
# 4                        2.0                1.0         1.0             6.0
# 5                        1.0                1.0         3.0             5.0
# 6                        2.0                1.0         3.0             2.0
# 7                        2.0                1.0         1.0             6.0
# 8                        2.0                1.0         3.0             2.0
# 9                        2.0                1.0         3.0             6.0
#
#    gender  age_at_initial_pathologic  race  ethnicity  death01
# 0     2.0                       67.0   3.0        2.0      1.0
# 1     1.0                       44.0   2.0        NaN      1.0
# 2     2.0                       37.0   3.0        NaN      0.0
# 3     2.0                       50.0   3.0        NaN      0.0
# 4     2.0                       39.0   3.0        NaN      0.0
# 5     2.0                       43.0   2.0        NaN      1.0
# 6     1.0                       53.0   3.0        2.0      0.0
# 7     1.0                       54.0   3.0        2.0      1.0
# 8     2.0                       58.0   3.0        2.0      1.0
# 9     2.0                       48.0   3.0        2.0      0.0

# %%
data_map = []
for sub_dir_path in glob.glob("/kaggle/input/lgg-mri-segmentation/kaggle_3m/"+"*"):
    #if os.path.isdir(sub_path_dir):
    try:
        dir_name = sub_dir_path.split('/')[-1]
        for filename in os.listdir(sub_dir_path):
            image_path = sub_dir_path + '/' + filename
            data_map.extend([dir_name, image_path])
    except Exception as e:
        print(e)
# Out:
# [Errno 20] Not a directory: '/kaggle/input/lgg-mri-segmentation/kaggle_3m/README.md'
# [Errno 20] Not a directory: '/kaggle/input/lgg-mri-segmentation/kaggle_3m/data.csv'

# %%
df = pd.DataFrame({"patient_id" : data_map[::2],
                   "path" : data_map[1::2]})
df.head()
# Out:
#               patient_id                                               path
# 0  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...

# %%
df_imgs = df[~df['path'].str.contains("mask")]
df_masks = df[df['path'].str.contains("mask")]

# File path line length images for later sorting
BASE_LEN = 89 # len(/kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_6404_19850629/TCGA_DU_6404_19850629_ <-!!!43.tif)
END_IMG_LEN = 4 # len(/kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_6404_19850629/TCGA_DU_6404_19850629_43 !!!->.tif)
END_MASK_LEN = 9 # (/kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_6404_19850629/TCGA_DU_6404_19850629_43 !!!->_mask.tif)

# Data sorting
imgs = sorted(df_imgs["path"].values, key=lambda x : int(x[BASE_LEN:-END_IMG_LEN]))
masks = sorted(df_masks["path"].values, key=lambda x : int(x[BASE_LEN:-END_MASK_LEN]))

# Sorting check
idx = random.randint(0, len(imgs)-1)
print("Path to the Image:", imgs[idx], "\nPath to the Mask:", masks[idx])
# Out:
# Path to the Image: /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_FG_6689_20020326/TCGA_FG_6689_20020326_43.tif
# Path to the Mask: /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_FG_6689_20020326/TCGA_FG_6689_20020326_43_mask.tif

# %% [markdown]
# ### creating final datset

# %%
# Final dataframe
brain_df = pd.DataFrame({"patient_id": df_imgs.patient_id.values,
                         "image_path": imgs,
                         "mask_path": masks
                        })
def pos_neg_diagnosis(mask_path):
    value = np.max(cv2.imread(mask_path))
    if value > 0 : 
        return 1
    else:
        return 0
    
brain_df['mask'] = brain_df['mask_path'].apply(lambda x: pos_neg_diagnosis(x))
brain_df
# Out:
#                  patient_id  \
# 0     TCGA_DU_7010_19860307
# 1     TCGA_DU_7010_19860307
# 2     TCGA_DU_7010_19860307
# 3     TCGA_DU_7010_19860307
# 4     TCGA_DU_7010_19860307
# ...                     ...
# 3924  TCGA_DU_7306_19930512
# 3925  TCGA_DU_7306_19930512
# 3926  TCGA_DU_7306_19930512
# 3927  TCGA_DU_7306_19930512
# 3928  TCGA_DU_7306_19930512
#
#                                              image_path  \
# 0     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# ...                                                 ...
# 3924  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3925  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3926  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3927  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3928  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                               mask_path  mask
# 0     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 1     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 2     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 4     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# ...                                                 ...   ...
# 3924  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3925  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3926  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3927  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3928  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
#
# [3929 rows x 4 columns]

# %% [markdown]
# # 2: DATA VISUALIZATION

# %%
brain_df['mask'].value_counts()
# Out:
# 0    2556
# 1    1373
# Name: mask, dtype: int64

# %%
import plotly.graph_objects as go  # using plotly to create interactive plots

fig = go.Figure([go.Bar(x=brain_df['mask'].value_counts().index, 
                        y=brain_df['mask'].value_counts(), 
                        width=[.4, .4]
                       )
                ])
fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)',
                  marker_line_width=4, opacity=0.4
                 )
fig.update_layout(title_text="Mask Count Plot",
                  width=700,
                  height=550,
                  yaxis=dict(
                             title_text="Count",
                             tickmode="array",
                             titlefont=dict(size=20)
                           )
                 )
fig.update_yaxes(automargin=True)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="b17f363c-c5b1-406e-bc5b-d408d467b4e3" class="plotly-graph-div" style="height:550px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b17f363c-c5b1-406e-bc5b-d408d467b4e3")) {                    Plotly.newPlot(                        "b17f363c-c5b1-406e-bc5b-d408d467b4e3",                        [{"marker": {"color": "rgb(158,202,225)", "line": {"color": "rgb(8,48,107)", "width": 4}}, "opacity": 0.4, "type": "bar", "width": [0.4, 0.4], "x": [0, 1], "y": [2556, 1373]}],                        {"height": 550, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"co ...

# %%
for i in range(len(brain_df)):
    if cv2.imread(brain_df.mask_path[i]).max() > 0:
        break

plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.imshow(cv2.imread(brain_df.mask_path[i]));
plt.title('Tumor Location')

plt.subplot(1,2,2)
plt.imshow(cv2.imread(brain_df.image_path[i]));

# %%
cv2.imread(brain_df.mask_path[i]).max(), cv2.imread(brain_df.mask_path[i]).min()
# Out:
# (255, 0)

# %%
# Basic visualizations: Visualize the images (MRI and Mask) in the dataset separately 

fig, axs = plt.subplots(6,2, figsize=(16,26))
count = 0
for x in range(6):
  i = random.randint(0, len(brain_df)) # select a random index
  axs[count][0].title.set_text("Brain MRI") # set title
  axs[count][0].imshow(cv2.imread(brain_df.image_path[i])) # show MRI 
  axs[count][1].title.set_text("Mask - " + str(brain_df['mask'][i])) # plot title on the mask (0 or 1)
  axs[count][1].imshow(cv2.imread(brain_df.mask_path[i])) # Show corresponding mask
  count += 1

fig.tight_layout()

# %%
count = 0
i = 0
fig,axs = plt.subplots(12,3, figsize=(20,50))
for mask in brain_df['mask']:
    if (mask==1):
        img = io.imread(brain_df.image_path[i])
        axs[count][0].title.set_text("Brain MRI")
        axs[count][0].imshow(img)
        
        mask = io.imread(brain_df.mask_path[i])
        axs[count][1].title.set_text("Mask")
        axs[count][1].imshow(mask, cmap='gray')
        
        img[mask==255] = (0,255,150)  # change pixel color at the position of mask
        axs[count][2].title.set_text("MRI with Mask")
        axs[count][2].imshow(img)
        count +=1
    i += 1
    if (count==12):
        break
        
fig.tight_layout()

# %% [markdown]
# # 5: CRETING TEST, TRAIN & VAL SET

# %%
brain_df_train = brain_df.drop(columns=['patient_id'])
# Convert the data in mask column to string format, to use categorical mode in flow_from_dataframe
brain_df_train['mask'] = brain_df_train['mask'].apply(lambda x: str(x))
brain_df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3929 entries, 0 to 3928
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   image_path  3929 non-null   object
#  1   mask_path   3929 non-null   object
#  2   mask        3929 non-null   object
# dtypes: object(3)
# memory usage: 92.2+ KB

# %%
from sklearn.model_selection import train_test_split
SEED = 123456
import os
import random as rn
import numpy as np

os.environ['PYTHONHASHSEED']=str(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
rn.seed(SEED)

train, test = train_test_split(brain_df_train, test_size=0.15, random_state = 123456)

# %%
from keras_preprocessing.image import ImageDataGenerator

#datagen = ImageDataGenerator(rescale=1./255., validation_split=0.1)
datagen = ImageDataGenerator(rescale=1./255., validation_split=0.1, rotation_range = 15, horizontal_flip = True, vertical_flip = True)

train_generator = datagen.flow_from_dataframe(train,
                                              directory='./',
                                              x_col='image_path',
                                              y_col='mask',
                                              subset='training',
                                              class_mode='categorical',
                                              batch_size=16,
                                              shuffle=True,
                                              target_size=(256,256)
                                             )
valid_generator = datagen.flow_from_dataframe(train,
                                              directory='./',
                                              x_col='image_path',
                                              y_col='mask',
                                              subset='validation',
                                              class_mode='categorical',
                                              batch_size=16,
                                              shuffle=True,
                                              target_size=(256,256)
                                             )
test_datagen = ImageDataGenerator(rescale=1./255.)
test_generator = test_datagen.flow_from_dataframe(test,
                                                  directory='./',
                                                  x_col='image_path',
                                                  y_col='mask',
                                                  class_mode='categorical',
                                                  batch_size=16,
                                                  shuffle=False,
                                                  target_size=(256,256)
                                                 )
# Out:
# Found 3006 validated image filenames belonging to 2 classes.
# Found 333 validated image filenames belonging to 2 classes.
# Found 590 validated image filenames belonging to 2 classes.

# %% [markdown]
# # 6: TRAIN A CLASSIFIER MODEL TO DETECT IF TUMOR EXISTS OR NOT

# %% [markdown]
# # 7: CLASSIFIACTION MODEL EVALUATION

# %%
# Train ResNet152
# run a different model using the same dataset and data split
import numpy as np
import keras
from keras import backend as K
from keras.layers.core import Dense, Activation
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator 
from keras.preprocessing import image
from keras.models import Model
from keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt 

import tensorflow.keras.applications as applications
from keras import applications
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications import ResNet152


clf_model = ResNet152(weights='imagenet', include_top=False, input_tensor=Input(shape=(256,256,3)))
# clf_model.summary()

for layer in clf_model.layers:
    layers.trainable = True
    
head = clf_model.output
head = AveragePooling2D(pool_size=(4,4))(head)
head = Flatten(name='Flatten')(head)
head = Dense(256, activation='relu')(head)
head = Dropout(0.1)(head)
head = Dense(256, activation='relu')(head)
head = Dropout(0.1)(head)
head = Dense(256, activation='relu')(head)
head = Dropout(0.1)(head)
head = Dense(2, activation='softmax')(head)

model = Model(clf_model.input, head)
model.compile(loss = 'categorical_crossentropy', 
              optimizer='adam', 
              metrics= ["accuracy"]
             )
# model.summary()

earlystopping = EarlyStopping(monitor='val_loss', 
                              mode='min', 
                              verbose=1, 
                              patience=15
                             )
checkpointer = ModelCheckpoint(filepath="clf-ResNet152-weights.hdf5", 
                               verbose=1, 
                               save_best_only=True
                              )
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=10,
                              min_delta=0.0001,
                              factor=0.2
                             )
callbacks = [checkpointer, earlystopping, reduce_lr]

h = model.fit(train_generator, 
              steps_per_epoch= train_generator.n // train_generator.batch_size, 
              epochs = 50, 
              validation_data= valid_generator, 
              validation_steps= valid_generator.n // valid_generator.batch_size, 
              callbacks=[checkpointer, earlystopping])

# saving model achitecture in json file
# model_json = model.to_json()
# with open("clf-resnet50-model.json", "w") as json_file:
#    json_file.write(model_json)

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(h.history['loss']);
plt.plot(h.history['val_loss']);
plt.title("Classification Model LOSS");
plt.ylabel("loss");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

plt.subplot(1,2,2)
plt.plot(h.history['accuracy']);
plt.plot(h.history['val_accuracy']);
plt.title("Classification Model Acc");
plt.ylabel("Accuracy");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

_, acc = model.evaluate(test_generator)
print("Test accuracy : {} %".format(acc*100))

prediction = model.predict(test_generator)

pred = np.argmax(prediction, axis=1)
#pred = np.asarray(pred).astype('str')
original = np.asarray(test['mask']).astype('int')

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
accuracy = accuracy_score(original, pred)
print(accuracy)

cm = confusion_matrix(original, pred)

report = classification_report(original, pred, labels = [0,1])
print(report)
plt.figure(figsize = (5,5))
sns.heatmap(cm, annot=True);
model.save("ResNet152")

for i in range(len(original)):
    if original[i] == 1 and pred[i] == 0:
        print("false negative", i)
    if original[i] == 0 and pred[i] == 1:
        print("false positive", i)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234700800/234698864 [==============================] - 6s 0us/step
# Epoch 1/50
# 187/187 [==============================] - ETA: 0s - loss: 0.7417 - accuracy: 0.6609
# Epoch 00001: val_loss improved from inf to 0.68301, saving model to clf-ResNet152-weights.hdf5
# 187/187 [==============================] - 101s 543ms/step - loss: 0.7417 - accuracy: 0.6609 - val_loss: 0.6830 - val_accuracy: 0.6375
# Epoch 2/50
# 187/187 [==============================] - ETA: 0s - loss: 0.5263 - accuracy: 0.7314
# Epoch 00002: val_loss did not improve from 0.68301
# 187/187 [==============================] - 76s 404ms/step - loss: 0.5263 - accuracy: 0.7314 - val_loss: 1.6532 - val_accuracy: 0.3656
# Epoch 3/50
# 187/187 [==============================] - ETA: 0s - loss: 0.5105 - accuracy: 0.7274
# Epoch 00003: val_loss did not improve from 0.68301
# 187/187 [==============================] - 73s 391ms/step - loss: 0.5105 - accuracy: 0.7274 - val_loss: 96.0335 - val_accuracy: 0.3688
# Epoch 4/50
# 187/187 [==============================] - ETA: 0s - loss: 0.4564 - accuracy: 0.7625
# Epoch 00004: val_loss did not improve from 0.68301
# 187/187 [==============================] - 74s 396ms/step - loss: 0.4564 - accuracy: 0.7625 - val_loss: 0.7276 - val_accuracy: 0.6281
# Epoch 5/50
# 187/187 [==============================] - ETA: 0s - loss: 0.4300 - accuracy: 0.7943
# Epoch 00005: val_loss improved from 0.68301 to 0.56133, saving model to clf-ResNet152-weights.hdf5
# 187/187 [==============================] - 78s 415ms/step - loss: 0.4300 - accuracy: 0.7943 - val_loss: 0.5613 - val_accuracy: 0.8000
# Epoch 6/50
# 187/187 [==============================] - ETA: 0s - loss: 0.4055 - accuracy: 0.8110
# Epoch 00006: val_loss improved from 0.56133 to 0.40338, saving model to clf-ResNet152-weights.hdf5
# 187/187 [==============================] - 78s 418ms/step - loss: 0.4055 - accuracy: 0.8110 - val_loss: 0.4034 - val_accuracy: 0.7594
# Epoch 7/50
# 187/187 [==============================] - ETA: 0s - loss: 0.3674 - accuracy: 0.8314
# Epoch 00007: val_loss improved from 0.40338 to 0.39624, saving model to clf-ResNet152-weights.hdf5
# 187/187 [==============================] - 78s 416ms/step - loss: 0.3674 - accuracy: 0.8314 - val_loss: 0.3962 - val_accuracy: 0.8031
# Epoch 8/50
# 187/187 [==============================] - ETA: 0s - loss: 0.3528 - accuracy: 0.8401
# Epoch 00008: val_loss did not improve from 0.39624
# 187/187 [==============================] - 73s 393ms/step - loss: 0.3528 - accuracy: 0.8401 - val_loss: 0.4087 - val_accuracy: 0.8250
# Epoch 9/50
# 187/187 [==============================] - ETA: 0s - loss: 0.3476 - accuracy: 0.8411
# Epoch 00009: val_loss improved from 0.39624 to 0.28549, saving model to clf-ResNet152-weights.hdf5
# 187/187 [==============================] - 77s
50
# 187/187 [==============================] - ETA: 0s - loss: 0.1444 - accuracy: 0.9508
# Epoch 00039: val_loss improved from 0.11108 to 0.09551, saving model to clf-ResNet152-weights.hdf5
# 187/187 [==============================] - 78s 420ms/step - loss: 0.1444 - accuracy: 0.9508 - val_loss: 0.0955 - val_accuracy: 0.9688
# Epoch 40/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1693 - accuracy: 0.9435
# Epoch 00040: val_loss did not improve from 0.09551
# 187/187 [==============================] - 76s 404ms/step - loss: 0.1693 - accuracy: 0.9435 - val_loss: 0.1876 - val_accuracy: 0.9375
# Epoch 41/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1532 - accuracy: 0.9468
# Epoch 00041: val_loss did not improve from 0.09551
# 187/187 [==============================] - 75s 403ms/step - loss: 0.1532 - accuracy: 0.9468 - val_loss: 1.4539 - val_accuracy: 0.6750
# Epoch 42/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1601 - accuracy: 0.9398
# Epoch 00042: val_loss did not improve from 0.09551
# 187/187 [==============================] - 75s 401ms/step - loss: 0.1601 - accuracy: 0.9398 - val_loss: 0.1013 - val_accuracy: 0.9781
# Epoch 43/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1685 - accuracy: 0.9415
# Epoch 00043: val_loss did not improve from 0.09551
# 187/187 [==============================] - 77s 413ms/step - loss: 0.1685 - accuracy: 0.9415 - val_loss: 0.1199 - val_accuracy: 0.9594
# Epoch 44/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1517 - accuracy: 0.9478
# Epoch 00044: val_loss did not improve from 0.09551
# 187/187 [==============================] - 75s 402ms/step - loss: 0.1517 - accuracy: 0.9478 - val_loss: 0.1719 - val_accuracy: 0.9312
# Epoch 45/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1504 - accuracy: 0.9492
# Epoch 00045: val_loss did not improve from 0.09551
# 187/187 [==============================] - 76s 405ms/step - loss: 0.1504 - accuracy: 0.9492 - val_loss: 0.2122 - val_accuracy: 0.9156
# Epoch 46/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1395 - accuracy: 0.9485
# Epoch 00046: val_loss did not improve from 0.09551
# 187/187 [==============================] - 75s 400ms/step - loss: 0.1395 - accuracy: 0.9485 - val_loss: 0.1031 - val_accuracy: 0.9750
# Epoch 47/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1656 - accuracy: 0.9452
# Epoch 00047: val_loss did not improve from 0.09551
# 187/187 [==============================] - 75s 404ms/step - loss: 0.1656 - accuracy: 0.9452 - val_loss: 1.2014 - val_accuracy: 0.8438
# Epoch 48/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1723 - accuracy: 0.9448
# Epoch 00048: val_loss did not improve from 0.09551
# 187/187 [==============================] - 75s 402ms/step - loss: 0.1723 - accuracy: 0.9448 - val_loss: 0.1203 - val_accuracy: 0.9563
# Epoch 49/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1715 - accuracy: 0.9351
# Epoch 00049: val_loss did not improve from 0.09551
# 187/187 [==============================] - 74s 398ms/step - loss: 0.1715 - accuracy: 0.9351 - val_loss: 0.1368 - val_accuracy: 0.9469
# Epoch 50/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1583 - accuracy: 0.9492
# Epoch 00050: val_loss did not improve from 0.09551
# 187/187 [==============================] - 75s 399ms/step - loss: 0.1583 - accuracy: 0.9492 - val_loss: 0.0978 - val_accuracy: 0.9719
# 37/37 [==============================] - 7s 178ms/step - loss: 0.1434 - accuracy: 0.9508
# Test accuracy : 95.08474469184875 %
# 0.9508474576271186
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       399
#            1       0.92      0.93      0.92       191
#
#     accuracy                           0.95       590
#    macro avg       0.94      0.94      0.94       590
# weighted avg       0.95      0.95      0.95       590
#
# false negative 27
# false positive 67
# false positive 74
# false negative 103
# false negative 152
# false positive 193
# false negative 202
# false positive 204
# false positive 210
# false positive 220
# false positive 221
# false positive 239
# false negative 255
# false negative 256
# false positive 259
# false positive 287
# false negative 298
# false negative 335
# false negative 344
# false positive 346
# false negative 374
# false positive 414
# false positive 440
# false negative 451
# false negative 477
# false negative 486
# false negative 529
# false positive 535
# false positive 545

# %%
# Train ResNet152_2
# run a different model using the same dataset and data split
import numpy as np
import keras
from keras import backend as K
from keras.layers.core import Dense, Activation
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator 
from keras.preprocessing import image
from keras.models import Model
from keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt 

import tensorflow.keras.applications as applications
from keras import applications
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications import ResN
50
# 187/187 [==============================] - ETA: 0s - loss: 0.1864 - accuracy: 0.9465
# Epoch 00044: val_loss did not improve from 0.11052
# 187/187 [==============================] - 76s 408ms/step - loss: 0.1864 - accuracy: 0.9465 - val_loss: 0.2052 - val_accuracy: 0.9312
# Epoch 45/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1794 - accuracy: 0.9492
# Epoch 00045: val_loss did not improve from 0.11052
# 187/187 [==============================] - 79s 422ms/step - loss: 0.1794 - accuracy: 0.9492 - val_loss: 0.1321 - val_accuracy: 0.9469
# Epoch 46/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1531 - accuracy: 0.9535
# Epoch 00046: val_loss did not improve from 0.11052
# 187/187 [==============================] - 77s 413ms/step - loss: 0.1531 - accuracy: 0.9535 - val_loss: 6.6199 - val_accuracy: 0.7875
# Epoch 47/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1760 - accuracy: 0.9455
# Epoch 00047: val_loss did not improve from 0.11052
# 187/187 [==============================] - 76s 405ms/step - loss: 0.1760 - accuracy: 0.9455 - val_loss: 0.1137 - val_accuracy: 0.9688
# Epoch 48/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1620 - accuracy: 0.9525
# Epoch 00048: val_loss did not improve from 0.11052
# 187/187 [==============================] - 77s 410ms/step - loss: 0.1620 - accuracy: 0.9525 - val_loss: 0.2024 - val_accuracy: 0.9375
# Epoch 49/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1725 - accuracy: 0.9508
# Epoch 00049: val_loss did not improve from 0.11052
# 187/187 [==============================] - 79s 421ms/step - loss: 0.1725 - accuracy: 0.9508 - val_loss: 0.1434 - val_accuracy: 0.9438
# Epoch 50/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1600 - accuracy: 0.9475
# Epoch 00050: val_loss did not improve from 0.11052
# 187/187 [==============================] - 75s 401ms/step - loss: 0.1600 - accuracy: 0.9475 - val_loss: 0.1812 - val_accuracy: 0.9250
# 37/37 [==============================] - 4s 104ms/step - loss: 0.3040 - accuracy: 0.9508
# Test accuracy : 95.08474469184875 %
# 0.9508474576271186
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.96       399
#            1       0.90      0.95      0.93       191
#
#     accuracy                           0.95       590
#    macro avg       0.94      0.95      0.94       590
# weighted avg       0.95      0.95      0.95       590
#
# false positive 21
# false positive 67
# false positive 71
# false positive 108
# false positive 126
# false positive 128
# false positive 157
# false positive 193
# false positive 210
# false positive 239
# false positive 241
# false negative 256
# false positive 259
# false negative 262
# false positive 316
# false negative 335
# false negative 344
# false positive 368
# false negative 374
# false positive 414
# false negative 430
# false negative 466
# false positive 498
# false positive 531
# false positive 535
# false negative 540
# false negative 542
# false positive 583
# false positive 584

# %%
# Train MobileNet
# run a different model using the same dataset and data split
import numpy as np
import keras
from keras import backend as K
from keras.layers.core import Dense, Activation
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator 
from keras.preprocessing import image
from keras.models import Model
from keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt 

import tensorflow.keras.applications as applications
from keras import applications
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications import ResNet101
from tensorflow.keras.applications import VGG16

clf_model = keras.applications.mobilenet.MobileNet(weights='imagenet', include_top=False, input_tensor=Input(shape=(256,256,3)))
# clf_model.summary()

for layer in clf_model.layers:
    layers.trainable = True
    
head = clf_model.output
head = AveragePooling2D(pool_size=(4,4))(head)
head = Flatten(name='Flatten')(head)
head = Dense(256, activation='relu')(head)
head = Dropout(0.35)(head)
head = Dense(256, activation='relu')(head)
head = Dropout(0.1)(head)
head = Dense(2, activation='softmax')(head)

model = Model(clf_model.input, head)
model.compile(loss = 'categorical_crossentropy', 
              optimizer='adam', 
              metrics= ["accuracy"]
             )
# model.summary()

earlystopping = EarlyStopping(monitor='val_loss', 
                              mode='min', 
                              verbose=1, 
                              patience=15
                             )
checkpointer = ModelCheckpoint(filepath="clf-MobileNet-weights.hdf5", 
                               verbose=1, 
                               save_best_only=True
                              )
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=10,
                              min_delta=0.0001,
                              factor=0.2
                             )
callbacks = [checkpointer, earlystopping, reduce_lr]

h = model.fit(train_generator, 
              steps_per_epoch= train_generator.n // train_generator.batch_size, 
              epochs = 50, 
              validation_data= valid_generator, 
              validation_steps= valid_generator.n // valid_generator.batch_size, 
              callbacks=[checkpointer, earlystopping])

# saving model achitecture in json file
# model_json = model.to_json()
# with open("clf-resnet50-model.json", "w") as json_file:
#    json_file.write(model_json)

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(h.history['loss']);
plt.plot(h.history['val_loss']);
plt.title("Classification Model LOSS");
plt.ylabel("loss");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

plt.subplot(1,2,2)
plt.plot(h.history['accuracy']);
plt.plot(h.history['val_accuracy']);
plt.title("Classification Model Acc");
plt.ylabel("Accuracy");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

_, acc = model.evaluate(test_generator)
print("Test accuracy : {} %".format(acc*100))

prediction = model.predict(test_generator)

pred = np.argmax(prediction, axis=1)
#pred = np.asarray(pred).astype('str')
original = np.asarray(test['mask']).astype('int')

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
accuracy = accuracy_score(original, pred)
print(accuracy)

cm = confusion_matrix(original, pred)

report = classification_report(original, pred, labels = [0,1])
print(report)
plt.figure(figsize = (5,5))
sns.heatmap(cm, annot=True);
model.save("MobileNet")

for i in range(len(original)):
    if original[i] == 1 and pred[i] == 0:
        print("false negative", i)
    if original[i] == 0 and pred[i] == 1:
        print("false positive", i)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17227776/17225924 [==============================] - 1s 0us/step
# Epoch 1/50
# 187/187 [==============================] - ETA: 0s - loss: 0.5642 - accuracy: 0.7629
# Epoch 00001: val_loss improved from inf to 0.34230, saving model to clf-MobileNet-weights.hdf5
# 187/187 [==============================] - 56s 298ms/step - loss: 0.5642 - accuracy: 0.7629 - val_loss: 0.3423 - val_accuracy: 0.8750
# Epoch 2/50
# 187/187 [==============================] - ETA: 0s - loss: 0.3033 - accuracy: 0.8933
# Epoch 00002: val_loss improved from 0.34230 to 0.26901, saving model to clf-MobileNet-weights.hdf5
# 187/187 [==============================] - 59s 315ms/step - loss: 0.3033 - accuracy: 0.8933 - val_loss: 0.2690 - val_accuracy: 0.9219
# Epoch 3/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2854 - accuracy: 0.8856
# Epoch 00003: val_loss improved from 0.26901 to 0.20391, saving model to clf-MobileNet-weights.hdf5
# 187/187 [==============================] - 58s 311ms/step - loss: 0.2854 - accuracy: 0.8856 - val_loss: 0.2039 - val_accuracy: 0.9406
# Epoch 4/50
# 187/187 [==============================] - ETA: 0s - loss: 0.
50
# 187/187 [==============================] - ETA: 0s - loss: 0.0567 - accuracy: 0.9816
# Epoch 00035: val_loss did not improve from 0.03315
# 187/187 [==============================] - 60s 321ms/step - loss: 0.0567 - accuracy: 0.9816 - val_loss: 0.0409 - val_accuracy: 0.9906
# Epoch 36/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0797 - accuracy: 0.9736
# Epoch 00036: val_loss did not improve from 0.03315
# 187/187 [==============================] - 56s 300ms/step - loss: 0.0797 - accuracy: 0.9736 - val_loss: 0.1042 - val_accuracy: 0.9656
# Epoch 37/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0598 - accuracy: 0.9799
# Epoch 00037: val_loss did not improve from 0.03315
# 187/187 [==============================] - 60s 321ms/step - loss: 0.0598 - accuracy: 0.9799 - val_loss: 0.1056 - val_accuracy: 0.9719
# Epoch 38/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0636 - accuracy: 0.9773
# Epoch 00038: val_loss did not improve from 0.03315
# 187/187 [==============================] - 61s 324ms/step - loss: 0.0636 - accuracy: 0.9773 - val_loss: 0.0748 - val_accuracy: 0.9750
# Epoch 39/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0631 - accuracy: 0.9799
# Epoch 00039: val_loss did not improve from 0.03315
# 187/187 [==============================] - 61s 326ms/step - loss: 0.0631 - accuracy: 0.9799 - val_loss: 0.1183 - val_accuracy: 0.9563
# Epoch 40/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0501 - accuracy: 0.9826
# Epoch 00040: val_loss did not improve from 0.03315
# 187/187 [==============================] - 55s 296ms/step - loss: 0.0501 - accuracy: 0.9826 - val_loss: 0.0577 - val_accuracy: 0.9844
# Epoch 41/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0591 - accuracy: 0.9806
# Epoch 00041: val_loss did not improve from 0.03315
# 187/187 [==============================] - 60s 319ms/step - loss: 0.0591 - accuracy: 0.9806 - val_loss: 0.0697 - val_accuracy: 0.9812
# Epoch 42/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0468 - accuracy: 0.9863
# Epoch 00042: val_loss did not improve from 0.03315
# 187/187 [==============================] - 56s 300ms/step - loss: 0.0468 - accuracy: 0.9863 - val_loss: 0.1085 - val_accuracy: 0.9719
# Epoch 00042: early stopping
# 37/37 [==============================] - 1s 38ms/step - loss: 0.1235 - accuracy: 0.9729
# Test accuracy : 97.28813767433167 %
# 0.9728813559322034
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       399
#            1       0.97      0.95      0.96       191
#
#     accuracy                           0.97       590
#    macro avg       0.97      0.97      0.97       590
# weighted avg       0.97      0.97      0.97       590
#
# false positive 67
# false negative 106
# false positive 147
# false negative 202
# false positive 208
# false positive 210
# false positive 239
# false negative 321
# false negative 326
# false negative 335
# false negative 344
# false positive 460
# false negative 472
# false negative 477
# false negative 555
# false negative 569

# %%
# Train MobileNet-2
# run a different model using the same dataset and data split
import numpy as np
import keras
from keras import backend as K
from keras.layers.core import Dense, Activation
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator 
from keras.preprocessing import image
from keras.models import Model
from keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt 

import tensorflow.keras.applications as applications
from keras import applications
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications import ResNet101
from tensorflow.keras.applications import VGG16

clf_model = keras.applications.mobilenet.MobileNet(weights='imagenet', include_top=False, input_tensor=Input(shape=(256,256,3)))
# clf_model.summary()

for layer in clf_model.layers:
    layers.trainable = True

head = clf_model.output
head = AveragePooling2D(pool_size=(4,4))(head)
head = Flatten(name='Flatten')(head)
head = Dense(256, activation='relu')(head)
head = Dropout(0.3)(head)
head = Dense(128, activation='relu')(head)
head = Dropout(0.2)(head)
head = Dense(2, activation='softmax')(head)

model = Model(clf_model.input, head)
model.compile(loss = 'categorical_crossentropy', 
              optimizer='adam', 
              metrics= ["accuracy"]
             )
# model.summary()

earlystopping = EarlyStopping(monitor='val_loss', 
                              mode='min', 
                              verbose=1, 
                              patience=15
                             )
checkpointer = ModelCheckpoint(filepath="clf-MobileNet-2-weights.hdf5", 
                               verbose=1, 
                               save_best_only=True
                              )
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=10,
                              min_delta=0.0001,
                              factor=0.2
                             )
callbacks = [checkpointer, earlystopping, reduce_lr]

h = model.fit(train_generator, 
              steps_per_epoch= train_generator.n // train_generator.batch_size, 
              epochs = 50, 
              validation_data= valid_generator, 
              validation_steps= valid_generator.n // valid_generator.batch_size, 
              callbacks=[checkpointer, earlystopping])

# saving model achitecture in json file
# model_json = model.to_json()
# with open("clf-resnet50-model.json", "w") as json_file:
#    json_file.write(model_json)

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(h.history['loss']);
plt.plot(h.history['val_loss']);
plt.title("Classification Model LOSS");
plt.ylabel("loss");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

plt.subplot(1,2,2)
plt.plot(h.history['accuracy']);
plt.plot(h.history['val_accuracy']);
plt.title("Classification Model Acc");
plt.ylabel("Accuracy");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

_, acc = model.evaluate(test_generator)
print("Test accuracy : {} %".format(acc*100))

prediction = model.predict(test_generator)

pred = np.argmax(prediction, axis=1)
#pred = np.asarray(pred).astype('str')
original = np.asarray(test['mask']).astype('int')

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
accuracy = accuracy_score(original, pred)
print(accuracy)

cm = confusion_matrix(original, pred)

report = classification_report(original, pred, labels = [0,1])
print(report)
plt.figure(figsize = (5,5))
sns.heatmap(cm, annot=True);
model.save("MobileNet-2")

for i in range(len(original)):
    if original[i] == 1 and pred[i] == 0:
        print("false negative", i)
    if original[i] == 0 and pred[i] == 1:
        print("false positive", i)
# Out:
# Epoch 1/50
# 187/187 [==============================] - ETA: 0s - loss: 0.4982 - accuracy: 0.8097
# Epoch 00001: val_loss improved from inf to 0.66990, saving model to clf-MobileNet-2-weights.hdf5
# 187/187 [==============================] - 56s 298ms/step - loss: 0.4982 - accuracy: 0.8097 - val_loss: 0.6699 - val_accuracy: 0.7969
# Epoch 2/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2762 - accuracy: 0.9017
# Epoch 00002: val_loss improved from 0.66990 to 0.48747, saving model to clf-MobileNet-2-weights.hdf5
# 187/187 [==============================] - 56s 298ms/step - loss: 0.2762 - accuracy: 0.9017 - val_loss: 0.4875 - val_accuracy: 0.8375
# Epoch 3/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2468 - accuracy: 0.9301
# Epoch 00003: val_loss improved from 0.48747 to 0.46299, saving model to clf-MobileNet-2-weights.hdf5
# 187/187 [==============================] - 62s 329ms/step - loss: 0.2468 - accuracy: 0.9301 - val_loss: 0.4630 - val_accuracy: 0.8469
# Epoch 4/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2041 - accuracy: 0.
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97       399
#            1       0.93      0.95      0.94       191
#
#     accuracy                           0.96       590
#    macro avg       0.96      0.96      0.96       590
# weighted avg       0.96      0.96      0.96       590
#
# false negative 15
# false positive 67
# false negative 99
# false positive 123
# false positive 128
# false positive 147
# false positive 210
# false positive 233
# false positive 239
# false negative 256
# false negative 321
# false negative 335
# false negative 344
# false negative 374
# false positive 383
# false positive 437
# false positive 460
# false negative 477
# false positive 527
# false positive 531
# false negative 569
# false positive 587

# %%
# Train MobileNet-3
# run a different model using the same dataset and data split
import numpy as np
import keras
from keras import backend as K
from keras.layers.core import Dense, Activation
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator 
from keras.preprocessing import image
from keras.models import Model
from keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt 

import tensorflow.keras.applications as applications
from keras import applications
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications import ResNet101
from tensorflow.keras.applications import VGG16

clf_model = keras.applications.mobilenet.MobileNet(weights='imagenet', include_top=False, input_tensor=Input(shape=(256,256,3)))
# clf_model.summary()

for layer in clf_model.layers:
    layers.trainable = True
    
head = clf_model.output
head = AveragePooling2D(pool_size=(2,2))(head)
head = Flatten(name='Flatten')(head)
head = Dense(256, activation='relu')(head)
head = Dropout(0.1)(head)
head = Dense(128, activation='relu')(head)
head = Dropout(0.2)(head)
head = Dense(2, activation='softmax')(head)

model = Model(clf_model.input, head)
model.compile(loss = 'categorical_crossentropy', 
              optimizer='adam', 
              metrics= ["accuracy"]
             )
# model.summary()

earlystopping = EarlyStopping(monitor='val_loss', 
                              mode='min', 
                              verbose=1, 
                              patience=15
                             )
checkpointer = ModelCheckpoint(filepath="clf-MobileNet-3-weights.hdf5", 
                               verbose=1, 
                               save_best_only=True
                              )
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=10,
                              min_delta=0.0001,
                              factor=0.2
                             )
callbacks = [checkpointer, earlystopping, reduce_lr]

h = model.fit(train_generator, 
              steps_per_epoch= train_generator.n // train_generator.batch_size, 
              epochs = 50, 
              validation_data= valid_generator, 
              validation_steps= valid_generator.n // valid_generator.batch_size, 
              callbacks=[checkpointer, earlystopping])

# saving model achitecture in json file
# model_json = model.to_json()
# with open("clf-resnet50-model.json", "w") as json_file:
#    json_file.write(model_json)

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(h.history['loss']);
plt.plot(h.history['val_loss']);
plt.title("Classification Model LOSS");
plt.ylabel("loss");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

plt.subplot(1,2,2)
plt.plot(h.history['accuracy']);
plt.plot(h.history['val_accuracy']);
plt.title("Classification Model Acc");
plt.ylabel("Accuracy");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

_, acc = model.evaluate(test_generator)
print("Test accuracy : {} %".format(acc*100))

prediction = model.predict(test_generator)

pred = np.argmax(prediction, axis=1)
#pred = np.asarray(pred).astype('str')
original = np.asarray(test['mask']).astype('int')

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
accuracy = accuracy_score(original, pred)
print(accuracy)

cm = confusion_matrix(original, pred)

report = classification_report(original, pred, labels = [0,1])
print(report)
plt.figure(figsize = (5,5))
sns.heatmap(cm, annot=True);
model.save("MobileNet-3")

for i in range(len(original)):
    if original[i] == 1 and pred[i] == 0:
        print("false negative", i)
    if original[i] == 0 and pred[i] == 1:
        print("false positive", i)
# Out:
# Epoch 1/50
# 187/187 [==============================] - ETA: 0s - loss: 0.8610 - accuracy: 0.7722
# Epoch 00001: val_loss improved from inf to 1.32097, saving model to clf-MobileNet-3-weights.hdf5
# 187/187 [==============================] - 56s 302ms/step - loss: 0.8610 - accuracy: 0.7722 - val_loss: 1.3210 - val_accuracy: 0.6375
# Epoch 2/50
# 187/187 [==============================] - ETA: 0s - loss: 0.3389 - accuracy: 0.8836
# Epoch 00002: val_loss improved from 1.32097 to 0.30380, saving model to clf-MobileNet-3-weights.hdf5
# 187/187 [==============================] - 56s 301ms/step - loss: 0.3389 - accuracy: 0.8836 - val_loss: 0.3038 - val_accuracy: 0.9281
# Epoch 3/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2554 - accuracy: 0.9214
# Epoch 00003: val_loss improved from 0.30380 to 0.19395, saving model to clf-MobileNet-3-weights.hdf5
# 187/187 [==============================] - 64s 340ms/step - loss: 0.2554 - accuracy: 0.9214 - val_loss: 0.1940 - val_accuracy: 0.9500
# Epoch 4/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2156 - accuracy: 0.9294
# Epoch 00004: val_loss did not improve from 0.19395
# 187/187 [==============================] - 55s 294ms/step - loss: 0.2156 - accuracy: 0.9294 - val_loss: 0.2237 - val_accuracy: 0.9219
# Epoch 5/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1890 - accuracy: 0.9441
# Epoch 00005: val_loss improved from 0.19395 to 0.11315, saving model to clf-MobileNet-3-weights.hdf5
# 187/187 [==============================] - 63s 339ms/step - loss: 0.1890 - accuracy: 0.9441 - val_loss: 0.1131 - val_accuracy: 0.9563
# Epoch 6/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1757 - accuracy: 0.9388
# Epoch 00006: val_loss improved from 0.11315 to 0.07107, saving model to clf-MobileNet-3-weights.hdf5
# 187/187 [==============================] - 56s 301ms/step - loss: 0.1757 - accuracy: 0.9388 - val_loss: 0.0711 - val_accuracy: 0.9750
# Epoch 7/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1556 - accuracy: 0.9508
# Epoch 00007: val_loss did not improve from 0.07107
# 187/187 [==============================] - 63s 338ms/step - loss: 0.1556 - accuracy: 0.9508 - val_loss: 0.1069 - val_accuracy: 0.9625
# Epoch 8/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1516 - accuracy: 0.9532
# Epoch 00008: val_loss did not improve from 0.07107
# 187/187 [==============================] - 56s 298ms/step - loss: 0.1516 - accuracy: 0.9532 - val_loss: 0.1594 - val_accuracy: 0.9406
# Epoch 9/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1462 - accuracy: 0.9602
# Epoch 00009: val_loss did not improve from 0.07107
# 187/187 [==============================] - 55s 293ms/step - loss: 0.1462 - accuracy: 0.9602 - val_loss: 0.3952 - val_accuracy: 0.8344
# Epoch 10/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1438 - accuracy: 0.9545
# Epoch 00010: val_loss did not improve from 0.07107
# 187/187 [==============================] - 63s 339ms/step - loss: 0.1438 - accuracy: 0.9545 - val_loss: 0.1156 - val_accuracy: 0.9531
# Epoch 11/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1264 - accuracy: 0.9619
# Epoch 00011: val_loss did not improve from 0.07107
# 187/187 [==============================] - 56s 299ms/step - loss: 0.1264 - accuracy: 0.9619 - val_loss: 0.1380 - val_accuracy: 0.9500
# Epoch 12/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1247 - accuracy: 0.9632
# Epoch 00012: val_loss did not improve from 0.07107
# 187/187 [==============================] - 63s 339ms/step - loss: 0.1247 - accuracy: 0.9632 - val_loss: 0.2887 - val_accuracy: 0.9219
# Epoch 13/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1365 - accuracy: 0.
# Epoch 28/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0787 - accuracy: 0.9746
# Epoch 00028: val_loss did not improve from 0.04418
# 187/187 [==============================] - 63s 339ms/step - loss: 0.0787 - accuracy: 0.9746 - val_loss: 0.1424 - val_accuracy: 0.9469
# Epoch 29/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0831 - accuracy: 0.9742
# Epoch 00029: val_loss did not improve from 0.04418
# 187/187 [==============================] - 56s 302ms/step - loss: 0.0831 - accuracy: 0.9742 - val_loss: 0.0828 - val_accuracy: 0.9688
# Epoch 30/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0735 - accuracy: 0.9749
# Epoch 00030: val_loss did not improve from 0.04418
# 187/187 [==============================] - 55s 294ms/step - loss: 0.0735 - accuracy: 0.9749 - val_loss: 0.2487 - val_accuracy: 0.9250
# Epoch 31/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0878 - accuracy: 0.9702
# Epoch 00031: val_loss did not improve from 0.04418
# 187/187 [==============================] - 64s 342ms/step - loss: 0.0878 - accuracy: 0.9702 - val_loss: 0.1300 - val_accuracy: 0.9563
# Epoch 32/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0795 - accuracy: 0.9746
# Epoch 00032: val_loss did not improve from 0.04418
# 187/187 [==============================] - 55s 295ms/step - loss: 0.0795 - accuracy: 0.9746 - val_loss: 0.1293 - val_accuracy: 0.9656
# Epoch 33/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0783 - accuracy: 0.9726
# Epoch 00033: val_loss did not improve from 0.04418
# 187/187 [==============================] - 65s 345ms/step - loss: 0.0783 - accuracy: 0.9726 - val_loss: 0.0695 - val_accuracy: 0.9781
# Epoch 34/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0674 - accuracy: 0.9789
# Epoch 00034: val_loss did not improve from 0.04418
# 187/187 [==============================] - 56s 298ms/step - loss: 0.0674 - accuracy: 0.9789 - val_loss: 0.0527 - val_accuracy: 0.9875
# Epoch 35/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0741 - accuracy: 0.9753
# Epoch 00035: val_loss did not improve from 0.04418
# 187/187 [==============================] - 55s 294ms/step - loss: 0.0741 - accuracy: 0.9753 - val_loss: 0.1526 - val_accuracy: 0.9563
# Epoch 36/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0739 - accuracy: 0.9783
# Epoch 00036: val_loss did not improve from 0.04418
# 187/187 [==============================] - 64s 343ms/step - loss: 0.0739 - accuracy: 0.9783 - val_loss: 0.1371 - val_accuracy: 0.9469
# Epoch 00036: early stopping
# 37/37 [==============================] - 1s 36ms/step - loss: 0.1657 - accuracy: 0.9559
# Test accuracy : 95.59321999549866 %
# 0.9559322033898305
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97       399
#            1       0.99      0.87      0.93       191
#
#     accuracy                           0.96       590
#    macro avg       0.97      0.93      0.95       590
# weighted avg       0.96      0.96      0.96       590
#
# false negative 11
# false negative 17
# false negative 27
# false negative 65
# false negative 99
# false negative 103
# false negative 106
# false negative 131
# false negative 152
# false positive 193
# false negative 202
# false positive 210
# false negative 212
# false negative 248
# false negative 251
# false negative 256
# false negative 321
# false negative 326
# false negative 335
# false negative 344
# false negative 356
# false negative 374
# false negative 451
# false negative 472
# false negative 477
# false negative 569

# %%
# Train MobileNetV2
# run a different model using the same dataset and data split
import numpy as np
import keras
from keras import backend as K
from keras.layers.core import Dense, Activation
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator 
from keras.preprocessing import image
from keras.models import Model
from keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt 

import tensorflow.keras.applications as applications
from keras import applications
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications import ResNet101
from tensorflow.keras.applications import VGG16

clf_model = keras.applications.mobilenet_v2.MobileNetV2(weights='imagenet', include_top=False, input_tensor=Input(shape=(256,256,3)))
# clf_model.summary()


for layer in clf_model.layers:
    layers.trainable = True
    
head = clf_model.output
head = AveragePooling2D(pool_size=(2,2))(head)
head = Flatten(name='Flatten')(head)
head = Dense(256, activation='relu')(head)
head = Dropout(0.1)(head)
head = Dense(128, activation='relu')(head)
head = Dropout(0.2)(head)
head = Dense(2, activation='softmax')(head)

model = Model(clf_model.input, head)
model.compile(loss = 'categorical_crossentropy', 
              optimizer='adam', 
              metrics= ["accuracy"]
             )
# model.summary()

earlystopping = EarlyStopping(monitor='val_loss', 
                              mode='min', 
                              verbose=1, 
                              patience=15
                             )
checkpointer = ModelCheckpoint(filepath="clf-MobileNetV2-weights.hdf5", 
                               verbose=1, 
                               save_best_only=True
                              )
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=10,
                              min_delta=0.0001,
                              factor=0.2
                             )
callbacks = [checkpointer, earlystopping, reduce_lr]

h = model.fit(train_generator, 
              steps_per_epoch= train_generator.n // train_generator.batch_size, 
              epochs = 50, 
              validation_data= valid_generator, 
              validation_steps= valid_generator.n // valid_generator.batch_size, 
              callbacks=[checkpointer, earlystopping])

# saving model achitecture in json file
# model_json = model.to_json()
# with open("clf-resnet50-model.json", "w") as json_file:
#    json_file.write(model_json)

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(h.history['loss']);
plt.plot(h.history['val_loss']);
plt.title("Classification Model LOSS");
plt.ylabel("loss");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

plt.subplot(1,2,2)
plt.plot(h.history['accuracy']);
plt.plot(h.history['val_accuracy']);
plt.title("Classification Model Acc");
plt.ylabel("Accuracy");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

_, acc = model.evaluate(test_generator)
print("Test accuracy : {} %".format(acc*100))

prediction = model.predict(test_generator)

pred = np.argmax(prediction, axis=1)
#pred = np.asarray(pred).astype('str')
original = np.asarray(test['mask']).astype('int')

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
accuracy = accuracy_score(original, pred)
print(accuracy)

cm = confusion_matrix(original, pred)

report = classification_report(original, pred, labels = [0,1])
print(report)
plt.figure(figsize = (5,5))
sns.heatmap(cm, annot=True);
model.save("MobileNetV2")

for i in range(len(original)):
    if original[i] == 1 and pred[i] == 0:
        print("false negative", i)
    if original[i] == 0 and pred[i] == 1:
        print("false positive", i)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# Epoch 1/50
# 187/187 [==============================] - ETA: 0s - loss: 0.6238 - accuracy: 0.8080
# Epoch 00001: val_loss improved from inf to 2.22253, saving model to clf-MobileNetV2-weights.hdf5
# 187/187 [==============================] - 58s 308ms/step - loss: 0.6238 - accuracy: 0.8080 - val_loss: 2.2225 - val_accuracy: 0.3656
# Epoch 2/50
# 187/187 [==============================] - ETA: 0s - loss: 0.3531 - accuracy: 0.8873
# Epoch 00002: val_loss did not improve from 2.22253
# 187/187 [==============================] - 57s 304ms/step - loss: 0.3531 - accuracy: 0.8873 - val_loss: 14.1826 - val_accuracy: 0.3688
# Epoch 3/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2765 - accuracy: 0.9084
# Epoch 00003: val_loss did not improve from 2.22253
# 187/187 [==============================] - 65s 345ms/step - loss: 0.2765 - accuracy: 0.9084 - val_loss: 3.4980 - val_accuracy: 0.4906
# Epoch 4/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2076 - accuracy: 0.9291
# Epoch 00004: val_loss did not improve from 2.22253
# 187/187 [==============================] - 56s 298ms/step - loss: 0.2076 - accuracy: 0.9291 - val_loss: 9.7758 - val_accuracy: 0.4875
# Epoch 5/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1853 - accuracy: 0.9344
# Epoch 00005: val_loss did not improve from 2.22253
# 187/187 [==============================] - 65s 349ms/step - loss: 0.1853 - accuracy: 0.9344 - val_loss: 4.5848 - val_accuracy: 0.5625
# Epoch 6/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1883 - accuracy: 0.9381
# Epoch 00006: val_loss did not improve from 2.22253
# 187/187 [==============================] - 56s 302ms/step - loss: 0.1883 - accuracy: 0.9381 - val_loss: 8.2685 - val_accuracy: 0.4219
# Epoch 7/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1856 - accuracy: 0.9395
# Epoch 00007: val_loss did not improve from 2.22253
# 187/187 [==============================] - 66s 352ms/step - loss: 0.1856 - accuracy: 0.9395 - val_loss: 11.2127 - val_accuracy: 0.4219
# Epoch 8/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1559 - accuracy: 0.9498
# Epoch 00008: val_loss did not improve from 2.22253
# 187/187 [==============================] - 57s 303ms/step - loss: 0.1559 - accuracy: 0.9498 - val_loss: 3.4639 - val_accuracy: 0.4563
# Epoch 9/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1530 - accuracy: 0.9462
# Epoch 00009: val_loss did not improve from 2.22253
# 187/187 [==============================] - 57s 306ms/step - loss: 0.1530 - accuracy: 0.9462 - val_loss: 2.5539 - val_accuracy: 0.5344
# Epoch 10/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1401 - accuracy: 0.9559
# Epoch 00010: val_loss did not improve from 2.22253
# 187/187 [==============================] - 66s 354ms/step - loss: 0.1401 - accuracy: 0.9559 - val_loss: 3.5548 - val_accuracy: 0.5063
# Epoch 11/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1244 - accuracy: 0.9629
# Epoch 00011: val_loss did not improve from 2.22253
# 187/187 [==============================] - 56s 300ms/step - loss: 0.1244 - accuracy: 0.9629 - val_loss: 2.4888 - val_accuracy: 0.5750
# Epoch 12/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1208 - accuracy: 0.9592
# Epoch 00012: val_loss did not improve from 2.22253
# 187/187 [==============================] - 65s 349ms/step - loss: 0.1208 - accuracy: 0.9592 - val_loss: 3.0751 - val_accuracy: 0.5594
# Epoch 13/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1443 - accuracy: 0.9538
# Epoch 00013: val_loss did not improve from 2.22253
# 187/187 [==============================] - 56s 298ms/step - loss: 0.1443 - accuracy: 0.9538 - val_loss: 3.5403 - val_accuracy: 0.5375
# Epoch 14/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1431 - accuracy: 0.9559
# Epoch 00014: val_loss did not improve from 2.22253
# 187/187 [==============================] - 65s 348ms/step - loss: 0.1431 - accuracy: 0.9559 - val_loss: 5.4689 - val_accuracy: 0.5375
# Epoch 15/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1945 - accuracy: 0.9438
# Epoch 00015: val_loss improved from 2.22253 to 0.99995, saving model to clf-MobileNetV2-weights.hdf5
# 187/187 [==============================] - 57s 306ms/step - loss: 0.1945 - accuracy: 0.9438 - val_loss: 0.9999 - val_accuracy: 0.6406
# Epoch 16/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1857 - accuracy: 0.9401
# Epoch 00016: val_loss did not improve from 0.99995
# 187/187 [==============================] - 56s 300ms/step - loss: 0.1857 - accuracy: 0.9401 - val_loss: 4.0313 - val_accuracy: 0.7000
# Epoch 17/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1415 - accuracy: 0.9545
# Epoch 00017: val_loss did not improve from 0.99995
# 187/187 [==============================] - 65s 350ms/step - loss: 0.1415 - accuracy: 0.9545 - val_loss: 1.0758 - val_accuracy: 0.7875
# Epoch 18/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1200 - accuracy: 0.9609
# Epoch 00018: val_loss improved from 0.99995 to 0.58257, saving model to clf-MobileNetV2-weights.hdf5
# 187/187 [==============================] - 56s 301ms/step - loss: 0.1200 - accuracy: 0.9609 - val_loss: 0.5826 - val_accuracy: 0.7812
# Epoch 19/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1364 - accuracy: 0.9562
# Epoch 00019: val_loss did not improve from 0.58257
# 187/187 [==============================] - 65s 349ms/step - loss: 0.1364 - accuracy: 0.9562 - val_loss: 1.8359 - val_accuracy: 0.6656
# Epoch 20/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1224 - accuracy: 0.9622
# Epoch 00020: val_loss did not improve from 0.58257
# 187/187 [==============================] - 55s 296ms/step - loss: 0.1224 - accuracy: 0.9622 - val_loss: 1.1886 - val_accuracy: 0.6812
# Epoch 21/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1358 - accuracy: 0.9572
# Epoch 00021: val_loss did not improve from 0.58257
# 187/187 [==============================] - 63s 338ms/step - loss: 0.1358 - accuracy: 0.9572 - val_loss: 1.1417 - val_accuracy: 0.6719
# Epoch 22/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2208 - accuracy: 0.9355
# Epoch 00022: val_loss did not improve from 0.58257
# 187/187 [==============================] - 58s 308ms/step - loss: 0.2208 - accuracy: 0.9355 - val_loss: 4.8980 - val_accuracy: 0.4125
# Epoch 23/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1611 - accuracy: 0.9498
# Epoch 00023: val_loss did not improve from 0.58257
# 187/187 [==============================] - 56s 298ms/step - loss: 0.1611 - accuracy: 0.9498 - val_loss: 6.9799 - val_accuracy: 0.4062
# Epoch 24/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1348 - accuracy: 0.9582
# Epoch 00024: val_loss did not improve from 0.58257
# 187/187 [==============================] - 65s 349ms/step - loss: 0.1348 - accuracy: 0.9582 - val_loss: 5.8036 - val_accuracy: 0.4594
# Epoch 25/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1200 - accuracy: 0.9619
# Epoch 00025: val_loss did not improve from 0.58257
# 187/187 [==============================] - 56s 299ms/step - loss: 0.1200 - accuracy: 0.9619 - val_loss: 4.9582 - val_accuracy: 0.5469
# Epoch 26/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1415 - accuracy: 0.9535
# Epoch 00026: val_loss did not improve from 0.58257
# 187/187 [==============================] - 65s 347ms/step - loss: 0.1415 - accuracy: 0.9535 - val_loss: 3.2710 - val_accuracy: 0.5875
# Epoch 27/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0968 - accuracy: 0.9666
# Epoch 00027: val_loss did not improve from 0.58257
# 187/187 [==============================] - 55s 295ms/step - loss: 0.0968 - accuracy: 0.9666 - val_loss: 2.4106 - val_accuracy: 0.6031
# Epoch 28/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1024 - accuracy: 0.9672
# Epoch 00028: val_loss did not improve from 0.58257
# 187/187 [==============================] - 56s 297ms/step - loss: 0.1024 - accuracy: 0.9672 - val_loss: 2.8602 - val_accuracy: 0.5844
# Epoch 29/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0885 - accuracy: 0.9689
# Epoch 00029: val_loss did not improve from 0.58257
# 187/187 [==============================] - 65s 347ms/step - loss: 0.0885 - accuracy: 0.9689 - val_loss: 2.0267 - val_accuracy: 0.7312
# Epoch 30/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1258 - accuracy: 0.9635
# Epoch 00030: val_loss improved from 0.58257 to 0.55119, saving model to clf-MobileNetV2-weights.hdf5
# 187/187 [==============================] - 56s 301ms/step - loss: 0.1258 - accuracy: 0.9635 - val_loss: 0.5512 - val_accuracy: 0.8156
# Epoch 31/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1149 - accuracy: 0.9642
# Epoch 00031: val_loss did not improve from 0.55119
# 187/187 [==============================] - 66s 351ms/step - loss: 0.1149 - accuracy: 0.9642 - val_loss: 1.1388 - val_accuracy: 0.7406
# Epoch 32/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1154 - accuracy: 0.9656
# Epoch 00032: val_loss did not improve from 0.55119
# 187/187 [==============================] - 56s 301ms/step - loss: 0.1154 - accuracy: 0.9656 - val_loss: 2.5280 - val_accuracy: 0.5469
# Epoch 33/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1163 - accuracy: 0.9639
# Epoch 00033: val_loss did not improve from 0.55119
# 187/187 [==============================] - 65s 347ms/step - loss: 0.1163 - accuracy: 0.9639 - val_loss: 3.3950 - val_accuracy: 0.5219
# Epoch 34/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0998 - accuracy: 0.9712
# Epoch 00034: val_loss did not improve from 0.55119
# 187/187 [==============================] - 56s 302ms/step - loss: 0.0998 - accuracy: 0.9712 - val_loss: 0.9266 - val_accuracy: 0.7312
# Epoch 35/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0870 - accuracy: 0.9722
# Epoch 00035: val_loss did not improve from 0.55119
# 187/187 [==============================] - 56s 297ms/step - loss: 0.0870 - accuracy: 0.9722 - val_loss: 0.7597 - val_accuracy: 0.8687
# Epoch 36/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1156 - accuracy: 0.9672
# Epoch 00036: val_loss did not improve from 0.55119
# 187/187 [==============================] - 65s 350ms/step - loss: 0.1156 - accuracy: 0.9672 - val_loss: 1.4086 - val_accuracy: 0.7344
# Epoch 37/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1093 - accuracy: 0.9686
# Epoch 00037: val_loss improved from 0.55119 to 0.33290, saving model to clf-MobileNetV2-weights.hdf5
# 187/187 [==============================] - 56s 301ms/step - loss: 0.1093 - accuracy: 0.9686 - val_loss: 0.3329 - val_accuracy: 0.8813
# Epoch 38/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0849 - accuracy: 0.9729
# Epoch 00038: val_loss did not improve from 0.33290
# 187/187 [==============================] - 66s 354ms/step - loss: 0.0849 - accuracy: 0.9729 - val_loss: 0.5099 - val_accuracy: 0.9281
# Epoch 39/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0940 - accuracy: 0.9706
# Epoch 00039: val_loss did not improve from 0.33290
# 187/187 [==============================] - 56s 299ms/step - loss: 0.0940 - accuracy: 0.9706 - val_loss: 1.2415 - val_accuracy: 0.7844
# Epoch 40/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0890 - accuracy: 0.9709
# Epoch 00040: val_loss did not improve from 0.33290
# 187/187 [==============================] - 56s 300ms/step - loss: 0.0890 - accuracy: 0.9709 - val_loss: 2.5352 - val_accuracy: 0.5719
# Epoch 41/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0958 - accuracy: 0.9682
# Epoch 00041: val_loss did not improve from 0.33290
# 187/187 [==============================] - 66s 351ms/step - loss: 0.0958 - accuracy: 0.9682 - val_loss: 1.5479 - val_accuracy: 0.7594
# Epoch 42/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0961 - accuracy: 0.9702
# Epoch 00042: val_loss did not improve from 0.33290
# 187/187 [==============================] - 55s 294ms/step - loss: 0.0961 - accuracy: 0.9702 - val_loss: 0.6621 - val_accuracy: 0.8219
# Epoch 43/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0882 - accuracy: 0.9696
# Epoch 00043: val_loss improved from 0.33290 to 0.22361, saving model to clf-MobileNetV2-weights.hdf5
# 187/187 [==============================] - 66s 355ms/step - loss: 0.0882 - accuracy: 0.9696 - val_loss: 0.2236 - val_accuracy: 0.9281
# Epoch 44/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0778 - accuracy: 0.9806
# Epoch 00044: val_loss did not improve from 0.22361
# 187/187 [==============================] - 56s 298ms/step - loss: 0.0778 - accuracy: 0.9806 - val_loss: 0.6288 - val_accuracy: 0.8125
# Epoch 45/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0822 - accuracy: 0.9746
# Epoch 00045: val_loss did not improve from 0.22361
# 187/187 [==============================] - 64s 343ms/step - loss: 0.0822 - accuracy: 0.9746 - val_loss: 2.0862 - val_accuracy: 0.6875
# Epoch 46/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1437 - accuracy: 0.9632
# Epoch 00046: val_loss did not improve from 0.22361
# 187/187 [==============================] - 58s 308ms/step - loss: 0.1437 - accuracy: 0.9632 - val_loss: 1.5016 - val_accuracy: 0.7125
# Epoch 47/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1017 - accuracy: 0.9615
# Epoch 00047: val_loss did not improve from 0.22361
# 187/187 [==============================] - 56s 301ms/step - loss: 0.1017 - accuracy: 0.9615 - val_loss: 0.7521 - val_accuracy: 0.7594
# Epoch 48/50
# 187/187 [==============================] - ETA: 0s - loss: 0.0816 - accuracy: 0.9726
# Epoch 00048: val_loss did not improve from 0.22361
# 187/187 [==============================] - 67s 356ms/step - loss: 0.0816 - accuracy: 0.9726 - val_loss: 0.7958 - val_accuracy: 0.9187
# Epoch 49/50
# 187/187 [==============================] - ETA: 0s - loss: 0.1842 - accuracy: 0.9462
# Epoch 00049: val_loss did not improve from 0.22361
# 187/187 [==============================] - 56s 299ms/step - loss: 0.1842 - accuracy: 0.9462 - val_loss: 2.0205 - val_accuracy: 0.7594
# Epoch 50/50
# 187/187 [==============================] - ETA: 0s - loss: 0.2902 - accuracy: 0.9107
# Epoch 00050: val_loss did not improve from 0.22361
# 187/187 [==============================] - 66s 352ms/step - loss: 0.2902 - accuracy: 0.9107 - val_loss: 11.4562 - val_accuracy: 0.3625
# 37/37 [==============================] - 1s 37ms/step - loss: 10.4141 - accuracy: 0.3237
# Test accuracy : 32.37287998199463 %
# 0.32372881355932204
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       399
#            1       0.32      1.00      0.49       191
#
#     accuracy                           0.32       590
#    macro avg       0.16      0.50      0.24       590
# weighted avg       0.10      0.32      0.16       590
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# false positive 1
# false positive 2
# false positive 3
# false positive 4
# false positive 5
# false positive 6
# false positive 7
# false positive 8
# false positive 9
# false positive 10
# false positive 12
# false positive 13
# false positive 14
# false positive 16
# false positive 18
# false positive 19
# false positive 20
# false positive 21
# false positive 22
# false positive 26
# false positive 28
# false positive 30
# false positive 32
# false positive 33
# false positive 34
# false positive 35
# false positive 36
# false positive 37
# false positive 38
# false positive 39
# false positive 40
# false positive 41
# false positive 45
# false positive 47
# false positive 50
# false positive 52
# false positive 54
# false positive 55
# false positive 56
# false positive 57
# false positive 58
# false positive 59
# false positive 60
# false positive 61
# false positive 66
# false positive 67
# false positive 68
# false positive 69
# false positive 71
# false positive 72
# false positive 73
# false positive 74
# false positive 75
# false positive 76
# false positive 80
# false positive 82
# false positive 84
# false positive 85
# false positive 86
# false positive 87
# false positive 88
# false positive 89
# false positive 90
# false positive 91
# false positive 92
# false positive 93
# false positive 94
# false positive 95
# false positive 96
# false positive 97
# false positive 98
# false positive 100
# false positive 101
# false positive 102
# false positive 104
# false positive 107
# false positive 108
# false positive 109
# false positive 110
# false positive 111
# false positive 112
# false positive 114
# false positive 115
# false positive 116
# false positive 117
# false positive 119
# false positive 120
# false positive 122
# false positive 123
# false positive 124
# false positive 125
# false positive 126
# false positive 127
# false positive 128
# false positive 129
# false positive 130
# false positive 133
# false positive 134
# false positive 135
# false positive 136
# false positive 139
# false positive 140
# false positive 141
# false positive 144
# false positive 145
# false positive 146
# false positive 147
# false positive 149
# false positive 150
# false positive 153
# false positive 154
# false positive 155
# false positive 156
# false positive 157
# false positive 158
# false positive 159
# false positive 161
# false positive 163
# false positive 165
# false positive 166
# false positive 167
# false positive 168
# false positive 169
# false positive 170
# false positive 172
# false positive 175
# false positive 176
# false positive 179
# false positive 180
# false positive 181
# false positive 183
# false positive 185
# false positive 186
# false positive 187
# false positive 188
# false positive 189
# false positive 190
# false positive 191
# false positive 193
# false positive 196
# false positive 197
# false positive 198
# false positive 199
# false positive 201
# false positive 204
# false positive 206
# false positive 207
# false positive 208
# false positive 210
# false positive 213
# false positive 215
# false positive 217
# false positive 220
# false positive 221
# false positive 222
# false positive 224
# false positive 225
# false positive 226
# false positive 230
# false positive 231
# false positive 232
# false positive 233
# false positive 234
# false positive 235
# false positive 236
# false positive 238
# false positive 239
# false positive 240
# false positive 241
# false positive 242
# false positive 244
# false positive 246
# false positive 249
# false positive 253
# false positive 254
# false positive 258
# false positive 259
# false positive 260
# false positive 261
# false positive 263
# false positive 264
# false positive 267
# false positive 268
# false positive 269
# false positive 270
# false positive 271
# false positive 273
# false positive 274
# false positive 275
# false positive 277
# false positive 278
# false positive 279
# false positive 280
# false positive 282
# false positive 287
# false positive 289
# false positive 292
# false positive 294
# false positive 295
# false positive 296
# false positive 297
# false positive 302
# false positive 305
# false positive 306
# false positive 307
# false positive 308
# false positive 310
# false positive 311
# false positive 314
# false positive 315
# false positive 316
# false positive 318
# false positive 319
# false positive 320
# false positive 322
# false positive 325
# false positive 327
# false positive 328
# false positive 329
# false positive 331
# false positive 332
# false positive 334
# false positive 336
# false positive 337
# false positive 340
# false positive 341
# false positive 342
# false positive 343
# false positive 346
# false positive 347
# false positive 348
# false positive 349
# false positive 350
# false positive 351
# false positive 352
# false positive 353
# false positive 354
# false positive 355
# false positive 359
# false positive 360
# false positive 361
# false positive 363
# false positive 366
# false positive 367
# false positive 368
# false positive 369
# false positive 370
# false positive 371
# false positive 372
# false positive 373
# false positive 376
# false positive 378
# false positive 379
# false positive 380
# false positive 381
# false positive 382
# false positive 383
# false positive 384
# false positive 385
# false positive 389
# false positive 390
# false positive 391
# false positive 392
# false positive 393
# false positive 394
# false positive 395
# false positive 396
# false positive 397
# false positive 398
# false positive 399
# false positive 400
# false positive 401
# false positive 402
# false positive 404
# false positive 405
# false positive 406
# false positive 410
# false positive 413
# false positive 414
# false positive 416
# false positive 417
# false positive 418
# false positive 419
# false positive 420
# false positive 422
# false positive 423
# false positive 424
# false positive 425
# false positive 426
# false positive 427
# false positive 428
# false positive 431
# false positive 432
# false positive 433
# false positive 435
# false positive 436
# false positive 437
# false positive 438
# false positive 440
# false positive 441
# false positive 443
# false positive 445
# false positive 448
# false positive 449
# false positive 450
# false positive 453
# false positive 454
# false positive 456
# false positive 458
# false positive 459
# false positive 460
# false positive 461
# false positive 462
# false positive 463
# false positive 464
# false positive 467
# false positive 468
# false positive 469
# false positive 473
# false positive 474
# false positive 475
# false positive 476
# false positive 478
# false positive 479
# false positive 480
# false positive 481
# false positive 482
# false positive 483
# false positive 485
# false positive 487
# false positive 488
# false positive 490
# false positive 492
# false positive 493
# false positive 494
# false positive 495
# false positive 496
# false positive 498
# false positive 501
# false positive 502
# false positive 504
# false positive 505
# false positive 506
# false positive 507
# false positive 508
# false positive 510
# false positive 512
# false positive 513
# false positive 514
# false positive 515
# false positive 516
# false positive 519
# false positive 520
# false positive 521
# false positive 522
# false positive 523
# false positive 524
# false positive 526
# false positive 527
# false positive 530
# false positive 531
# false positive 532
# false positive 533
# false positive 535
# false positive 536
# false positive 538
# false positive 539
# false positive 544
# false positive 545
# false positive 546
# false positive 547
# false positive 548
# false positive 549
# false positive 550
# false positive 553
# false positive 554
# false positive 556
# false positive 558
# false positive 560
# false positive 563
# false positive 564
# false positive 565
# false positive 566
# false positive 567
# false positive 568
# false positive 570
# false positive 573
# false positive 574
# false positive 576
# false positive 578
# false positive 581
# false positive 582
# false positive 583
# false positive 584
# false positive 585
# false positive 586
# false positive 587
# false positive 588
# false positive 589

# %% [markdown]
# the predictions made by AI are almost correct :)
